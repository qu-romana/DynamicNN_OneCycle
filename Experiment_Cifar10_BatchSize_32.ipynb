# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms

# Define the basic block for ResNet
class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_channels, out_channels, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(
            in_channels, out_channels, kernel_size=3, stride=stride, padding=1, bias=False
        )
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.conv2 = nn.Conv2d(
            out_channels, out_channels, kernel_size=3, stride=1, padding=1, bias=False
        )
        self.bn2 = nn.BatchNorm2d(out_channels)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_channels != out_channels:
            self.shortcut = nn.Sequential(
                nn.Conv2d(
                    in_channels, out_channels, kernel_size=1, stride=stride, bias=False
                ),
                nn.BatchNorm2d(out_channels),
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out

# Define ResNet
class DynamicSparseResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):  # For CIFAR-10, num_classes=10
        super(DynamicSparseResNet, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(
            3, 64, kernel_size=3, stride=1, padding=1, bias=False  # CIFAR-10 images have 3 channels
        )
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.linear = nn.Linear(512 * block.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        layers = []
        strides = [stride] + [1] * (num_blocks - 1)
        for s in strides:
            layers.append(block(self.in_planes, planes, s))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))  # Output size: 32x32
        out = self.layer1(out)                 # Output size: 32x32
        out = self.layer2(out)                 # Output size: 16x16
        out = self.layer3(out)                 # Output size: 8x8
        out = self.layer4(out)                 # Output size: 4x4
        out = F.avg_pool2d(out, 4)             # Output size: 1x1
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out

def ResNet18(num_classes=10):
    return DynamicSparseResNet(BasicBlock, [2, 2, 2, 2], num_classes=num_classes)

def initialize_weights(model):
    for m in model.modules():
        if isinstance(m, (nn.Conv2d, nn.Linear)):
            nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
            if m.bias is not None:
                nn.init.zeros_(m.bias)
        elif isinstance(m, nn.BatchNorm2d):
            nn.init.ones_(m.weight)
            nn.init.zeros_(m.bias)

def apply_dynamic_supermask(model, sparsity_rate):
    masks = {}
    for name, param in model.named_parameters():
        if 'weight' in name:
            weight_flat = param.data.abs().flatten()
            k = int(weight_flat.shape[0] * (1 - sparsity_rate))
            if k == 0:
                threshold = torch.max(weight_flat) + 1
            else:
                threshold = torch.topk(weight_flat, k, largest=True, sorted=True)[0][-1]
            mask = (param.data.abs() >= threshold).float()
            masks[name] = mask.view(param.size()).to(param.device)
    return masks

def dynamic_weight_update(model, masks):
    for name, param in model.named_parameters():
        if 'weight' in name and param.grad is not None:
            mask = masks[name]
            param.grad.data.mul_(mask)

def train_with_dynamic_pruning(model, train_loader, val_loader, epochs=200, device='cuda'):
    criterion = nn.CrossEntropyLoss(label_smoothing=0.1)
    optimizer = torch.optim.SGD(
        model.parameters(), lr=0.1, momentum=0.9, weight_decay=5e-4
    )
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=epochs)

    initial_sparsity = 0.0
    final_sparsity = 0.8
    sparsity_increment = (final_sparsity - initial_sparsity) / epochs

    train_losses = []
    val_losses = []
    train_acc = []
    val_acc = []

    initialize_weights(model)

    for epoch in range(epochs):
        model.train()
        running_loss = 0
        correct = 0
        total = 0

        current_sparsity = initial_sparsity + sparsity_increment * epoch
        masks = apply_dynamic_supermask(model, current_sparsity)

        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()

            dynamic_weight_update(model, masks)
            optimizer.step()

            running_loss += loss.item() * images.size(0)
            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()

        train_loss = running_loss / total
        train_accuracy = 100.0 * correct / total

        # Validation
        val_loss, val_accuracy = evaluate(model, val_loader, criterion, device)

        train_losses.append(train_loss)
        val_losses.append(val_loss)
        train_acc.append(train_accuracy)
        val_acc.append(val_accuracy)

        scheduler.step()

        print(
            f"Epoch: {epoch+1}/{epochs}"
            f" | Train Loss: {train_loss:.4f}, Train Acc: {train_accuracy:.2f}%"
            f" | Val Loss: {val_loss:.4f}, Val Acc: {val_accuracy:.2f}%"
            f" | Sparsity: {current_sparsity:.2f}"
        )

    return train_losses, val_losses, train_acc, val_acc

def evaluate(model, data_loader, criterion, device):
    model.eval()
    loss_total = 0
    correct = 0
    total = 0

    with torch.no_grad():
        for images, labels in data_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)

            loss_total += loss.item() * images.size(0)
            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()

    avg_loss = loss_total / total
    accuracy = 100.0 * correct / total
    return avg_loss, accuracy

def main():
    torch.manual_seed(42)

    # Data augmentation for CIFAR-10
    transform = transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(15),
        transforms.ColorJitter(
            brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1
        ),
        transforms.ToTensor(),
        transforms.RandomErasing(),
        transforms.Normalize(
            (0.4914, 0.4822, 0.4465),
            (0.2470, 0.2435, 0.2616)
        ),
    ])

    # Load the full CIFAR-10 dataset (both train and test sets)
    train_dataset = torchvision.datasets.CIFAR10(
        root='./data', train=True, download=True, transform=transform
    )
    test_dataset = torchvision.datasets.CIFAR10(
        root='./data', train=False, download=True, transform=transform
    )

    # Combine train and test datasets
    full_dataset = torch.utils.data.ConcatDataset([train_dataset, test_dataset])

    # Calculate sizes for splits
    total_size = len(full_dataset)
    train_size = int(0.8 * total_size)
    val_size = int(0.1 * total_size)
    test_size = total_size - train_size - val_size

    # Split the dataset
    train_dataset, val_dataset, test_dataset = torch.utils.data.random_split(
        full_dataset, [train_size, val_size, test_size]
    )

    # Set up DataLoader for training, validation, and testing data
    batch_size = 32
    train_loader = torch.utils.data.DataLoader(
        train_dataset,
        batch_size=batch_size,
        shuffle=True,
        num_workers=4,
        pin_memory=True,
    )
    val_loader = torch.utils.data.DataLoader(
        val_dataset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=4,
        pin_memory=True,
    )
    test_loader = torch.utils.data.DataLoader(
        test_dataset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=4,
        pin_memory=True,
    )

    # Set device to GPU if available
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model = ResNet18(num_classes=10).to(device)

    # Train and validate the model with dynamic pruning
    train_losses, val_losses, train_acc, val_acc = train_with_dynamic_pruning(
        model, train_loader, val_loader, epochs=200, device=device
    )

    # Plot training results
    import matplotlib.pyplot as plt
    plt.figure(figsize=(12, 4))

    plt.subplot(1, 2, 1)
    plt.plot(train_losses, label='Train Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.title('CIFAR-10 Training and Validation Loss')

    plt.subplot(1, 2, 2)
    plt.plot(train_acc, label='Train Accuracy')
    plt.plot(val_acc, label='Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy (%)')
    plt.legend()
    plt.title('CIFAR-10 Training and Validation Accuracy')

    plt.tight_layout()
    plt.show()

    # Evaluate on the test set
    criterion = nn.CrossEntropyLoss(label_smoothing=0.1)
    test_loss, test_accuracy = evaluate(model, test_loader, criterion, device)

    # Print final metrics
    print("\nFinal Results:")
    print(f"Final Training Loss: {train_losses[-1]:.4f}")
    print(f"Final Validation Loss: {val_losses[-1]:.4f}")
    print(f"Final Training Accuracy: {train_acc[-1]:.2f}%")
    print(f"Final Validation Accuracy: {val_acc[-1]:.2f}%")
    print(f"Final Test Loss: {test_loss:.4f}")
    print(f"Final Test Accuracy: {test_accuracy:.2f}%")

if __name__ == "__main__":
    main()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch: 1/200 | Train Loss: 2.3708, Train Acc: 23.64% | Val Loss: 1.9455, Val Acc: 30.78% | Sparsity: 0.00
# Epoch: 2/200 | Train Loss: 1.8517, Train Acc: 36.45% | Val Loss: 1.8654, Val Acc: 36.00% | Sparsity: 0.00
# Epoch: 3/200 | Train Loss: 1.6802, Train Acc: 45.25% | Val Loss: 1.8996, Val Acc: 40.35% | Sparsity: 0.01
# Epoch: 4/200 | Train Loss: 1.5291, Train Acc: 53.25% | Val Loss: 2.0082, Val Acc: 40.47% | Sparsity: 0.01
# Epoch: 5/200 | Train Loss: 1.4425, Train Acc: 57.74% | Val Loss: 1.6401, Val Acc: 51.27% | Sparsity: 0.02
# Epoch: 6/200 | Train Loss: 1.3860, Train Acc: 60.57% | Val Loss: 1.7186, Val Acc: 49.85% | Sparsity: 0.02
# Epoch: 7/200 | Train Loss: 1.3542, Train Acc: 62.14% | Val Loss: 1.3749, Val Acc: 61.45% | Sparsity: 0.02
# Epoch: 8/200 | Train Loss: 1.3286, Train Acc: 63.27% | Val Loss: 1.6817, Val Acc: 47.18% | Sparsity: 0.03
# Epoch: 9/200 | Train Loss: 1.3230, Train Acc: 63.50% | Val Loss: 1.4079, Val Acc: 59.97% | Sparsity: 0.03
# Epoch: 10/200 | Train Loss: 1.3145, Train Acc: 64.04% | Val Loss: 1.3760, Val Acc: 60.70% | Sparsity: 0.04
# Epoch: 11/200 | Train Loss: 1.3012, Train Acc: 64.52% | Val Loss: 1.3153, Val Acc: 63.95% | Sparsity: 0.04
# Epoch: 12/200 | Train Loss: 1.2931, Train Acc: 64.82% | Val Loss: 1.3743, Val Acc: 61.57% | Sparsity: 0.04
# Epoch: 13/200 | Train Loss: 1.2894, Train Acc: 65.14% | Val Loss: 1.4633, Val Acc: 56.75% | Sparsity: 0.05
# Epoch: 14/200 | Train Loss: 1.2875, Train Acc: 65.28% | Val Loss: 1.4363, Val Acc: 58.85% | Sparsity: 0.05
# Epoch: 15/200 | Train Loss: 1.2819, Train Acc: 65.52% | Val Loss: 1.4107, Val Acc: 59.35% | Sparsity: 0.06
# Epoch: 16/200 | Train Loss: 1.2777, Train Acc: 65.70% | Val Loss: 1.3527, Val Acc: 62.10% | Sparsity: 0.06
# Epoch: 17/200 | Train Loss: 1.2754, Train Acc: 65.60% | Val Loss: 1.3320, Val Acc: 61.75% | Sparsity: 0.06
# Epoch: 18/200 | Train Loss: 1.2733, Train Acc: 65.74% | Val Loss: 1.3746, Val Acc: 61.35% | Sparsity: 0.07
# Epoch: 19/200 | Train Loss: 1.2682, Train Acc: 66.24% | Val Loss: 1.3140, Val Acc: 64.18% | Sparsity: 0.07
# Epoch: 20/200 | Train Loss: 1.2628, Train Acc: 66.24% | Val Loss: 1.3658, Val Acc: 62.60% | Sparsity: 0.08
# Epoch: 21/200 | Train Loss: 1.2608, Train Acc: 66.71% | Val Loss: 1.3206, Val Acc: 63.53% | Sparsity: 0.08
# Epoch: 22/200 | Train Loss: 1.2600, Train Acc: 66.52% | Val Loss: 1.3190, Val Acc: 64.03% | Sparsity: 0.08
# Epoch: 23/200 | Train Loss: 1.2560, Train Acc: 66.82% | Val Loss: 1.5460, Val Acc: 56.65% | Sparsity: 0.09
# Epoch: 24/200 | Train Loss: 1.2543, Train Acc: 66.66% | Val Loss: 1.3031, Val Acc: 64.97% | Sparsity: 0.09
# Epoch: 25/200 | Train Loss: 1.2512, Train Acc: 66.84% | Val Loss: 1.3500, Val Acc: 62.62% | Sparsity: 0.10
# Epoch: 26/200 | Train Loss: 1.2501, Train Acc: 67.06% | Val Loss: 1.5655, Val Acc: 54.88% | Sparsity: 0.10
# Epoch: 27/200 | Train Loss: 1.2527, Train Acc: 67.11% | Val Loss: 1.3034, Val Acc: 64.35% | Sparsity: 0.10
# Epoch: 28/200 | Train Loss: 1.2432, Train Acc: 67.16% | Val Loss: 1.5348, Val Acc: 56.52% | Sparsity: 0.11
# Epoch: 29/200 | Train Loss: 1.2434, Train Acc: 67.07% | Val Loss: 1.4536, Val Acc: 59.47% | Sparsity: 0.11
# Epoch: 30/200 | Train Loss: 1.2453, Train Acc: 67.26% | Val Loss: 1.3692, Val Acc: 62.43% | Sparsity: 0.12
# Epoch: 31/200 | Train Loss: 1.2428, Train Acc: 67.22% | Val Loss: 1.3556, Val Acc: 62.52% | Sparsity: 0.12
# Epoch: 32/200 | Train Loss: 1.2385, Train Acc: 67.53% | Val Loss: 1.4893, Val Acc: 55.78% | Sparsity: 0.12
# Epoch: 33/200 | Train Loss: 1.2372, Train Acc: 67.47% | Val Loss: 1.2667, Val Acc: 66.05% | Sparsity: 0.13
# Epoch: 34/200 | Train Loss: 1.2368, Train Acc: 67.51% | Val Loss: 1.7413, Val Acc: 47.88% | Sparsity: 0.13
# Epoch: 35/200 | Train Loss: 1.2426, Train Acc: 67.32% | Val Loss: 1.5051, Val Acc: 57.98% | Sparsity: 0.14
# Epoch: 36/200 | Train Loss: 1.2357, Train Acc: 67.80% | Val Loss: 1.3639, Val Acc: 61.30% | Sparsity: 0.14
# Epoch: 37/200 | Train Loss: 1.2333, Train Acc: 67.90% | Val Loss: 1.3063, Val Acc: 64.47% | Sparsity: 0.14
# Epoch: 38/200 | Train Loss: 1.2366, Train Acc: 67.66% | Val Loss: 1.6493, Val Acc: 51.60% | Sparsity: 0.15
# Epoch: 39/200 | Train Loss: 1.2319, Train Acc: 68.01% | Val Loss: 1.4043, Val Acc: 60.80% | Sparsity: 0.15
# Epoch: 40/200 | Train Loss: 1.2315, Train Acc: 67.86% | Val Loss: 1.3276, Val Acc: 64.20% | Sparsity: 0.16
# Epoch: 41/200 | Train Loss: 1.2294, Train Acc: 68.00% | Val Loss: 1.3323, Val Acc: 61.90% | Sparsity: 0.16
# Epoch: 42/200 | Train Loss: 1.2244, Train Acc: 68.13% | Val Loss: 1.4699, Val Acc: 59.53% | Sparsity: 0.16
# Epoch: 43/200 | Train Loss: 1.2246, Train Acc: 68.23% | Val Loss: 1.5347, Val Acc: 57.52% | Sparsity: 0.17
# Epoch: 44/200 | Train Loss: 1.2265, Train Acc: 67.80% | Val Loss: 1.3362, Val Acc: 63.72% | Sparsity: 0.17
# Epoch: 45/200 | Train Loss: 1.2218, Train Acc: 68.42% | Val Loss: 1.2729, Val Acc: 66.08% | Sparsity: 0.18
# Epoch: 46/200 | Train Loss: 1.2170, Train Acc: 68.51% | Val Loss: 1.2832, Val Acc: 65.08% | Sparsity: 0.18
# Epoch: 47/200 | Train Loss: 1.2197, Train Acc: 68.36% | Val Loss: 1.3511, Val Acc: 62.92% | Sparsity: 0.18
# Epoch: 48/200 | Train Loss: 1.2190, Train Acc: 68.37% | Val Loss: 1.2358, Val Acc: 66.82% | Sparsity: 0.19
# Epoch: 49/200 | Train Loss: 1.2143, Train Acc: 68.66% | Val Loss: 1.3378, Val Acc: 63.67% | Sparsity: 0.19
# Epoch: 50/200 | Train Loss: 1.2183, Train Acc: 68.52% | Val Loss: 1.3491, Val Acc: 61.57% | Sparsity: 0.20
# Epoch: 51/200 | Train Loss: 1.2117, Train Acc: 68.85% | Val Loss: 1.3543, Val Acc: 62.60% | Sparsity: 0.20
# Epoch: 52/200 | Train Loss: 1.2143, Train Acc: 68.57% | Val Loss: 1.2677, Val Acc: 66.53% | Sparsity: 0.20
# Epoch: 53/200 | Train Loss: 1.2131, Train Acc: 68.62% | Val Loss: 1.4257, Val Acc: 60.95% | Sparsity: 0.21
# Epoch: 54/200 | Train Loss: 1.2129, Train Acc: 68.65% | Val Loss: 1.3642, Val Acc: 61.62% | Sparsity: 0.21
# Epoch: 55/200 | Train Loss: 1.2095, Train Acc: 68.56% | Val Loss: 1.3683, Val Acc: 61.97% | Sparsity: 0.22
# Epoch: 56/200 | Train Loss: 1.2053, Train Acc: 68.95% | Val Loss: 1.2932, Val Acc: 64.80% | Sparsity: 0.22
# Epoch: 57/200 | Train Loss: 1.2022, Train Acc: 69.09% | Val Loss: 1.5549, Val Acc: 53.15% | Sparsity: 0.22
# Epoch: 58/200 | Train Loss: 1.2038, Train Acc: 69.01% | Val Loss: 1.3930, Val Acc: 61.83% | Sparsity: 0.23
# Epoch: 59/200 | Train Loss: 1.1984, Train Acc: 69.39% | Val Loss: 1.2700, Val Acc: 66.13% | Sparsity: 0.23
# Epoch: 60/200 | Train Loss: 1.1966, Train Acc: 69.46% | Val Loss: 1.2559, Val Acc: 66.37% | Sparsity: 0.24
# Epoch: 61/200 | Train Loss: 1.1996, Train Acc: 69.15% | Val Loss: 1.2987, Val Acc: 64.58% | Sparsity: 0.24
# Epoch: 62/200 | Train Loss: 1.1912, Train Acc: 69.69% | Val Loss: 1.2924, Val Acc: 65.20% | Sparsity: 0.24
# Epoch: 63/200 | Train Loss: 1.1946, Train Acc: 69.37% | Val Loss: 1.2799, Val Acc: 65.70% | Sparsity: 0.25
# Epoch: 64/200 | Train Loss: 1.1861, Train Acc: 70.04% | Val Loss: 1.2818, Val Acc: 66.45% | Sparsity: 0.25
# Epoch: 65/200 | Train Loss: 1.1841, Train Acc: 70.16% | Val Loss: 1.2551, Val Acc: 67.12% | Sparsity: 0.26
# Epoch: 66/200 | Train Loss: 1.1876, Train Acc: 69.81% | Val Loss: 1.2256, Val Acc: 67.28% | Sparsity: 0.26
# Epoch: 67/200 | Train Loss: 1.1857, Train Acc: 69.95% | Val Loss: 1.2713, Val Acc: 66.63% | Sparsity: 0.26
# Epoch: 68/200 | Train Loss: 1.1820, Train Acc: 70.08% | Val Loss: 1.2695, Val Acc: 65.85% | Sparsity: 0.27
# Epoch: 69/200 | Train Loss: 1.1768, Train Acc: 70.59% | Val Loss: 1.2320, Val Acc: 67.70% | Sparsity: 0.27
# Epoch: 70/200 | Train Loss: 1.1767, Train Acc: 70.23% | Val Loss: 1.2629, Val Acc: 67.25% | Sparsity: 0.28
# Epoch: 71/200 | Train Loss: 1.1725, Train Acc: 70.55% | Val Loss: 1.2412, Val Acc: 67.32% | Sparsity: 0.28
# Epoch: 72/200 | Train Loss: 1.1712, Train Acc: 70.47% | Val Loss: 1.2547, Val Acc: 66.45% | Sparsity: 0.28
# Epoch: 73/200 | Train Loss: 1.1703, Train Acc: 70.63% | Val Loss: 1.3514, Val Acc: 62.28% | Sparsity: 0.29
# Epoch: 74/200 | Train Loss: 1.1730, Train Acc: 70.56% | Val Loss: 1.2402, Val Acc: 68.00% | Sparsity: 0.29
# Epoch: 75/200 | Train Loss: 1.1638, Train Acc: 70.71% | Val Loss: 1.3431, Val Acc: 63.97% | Sparsity: 0.30
# Epoch: 76/200 | Train Loss: 1.1712, Train Acc: 70.30% | Val Loss: 1.3587, Val Acc: 61.57% | Sparsity: 0.30
# Epoch: 77/200 | Train Loss: 1.1614, Train Acc: 70.97% | Val Loss: 1.2716, Val Acc: 65.42% | Sparsity: 0.30
# Epoch: 78/200 | Train Loss: 1.1621, Train Acc: 70.84% | Val Loss: 1.4055, Val Acc: 61.00% | Sparsity: 0.31
# Epoch: 79/200 | Train Loss: 1.1567, Train Acc: 71.07% | Val Loss: 1.2795, Val Acc: 66.20% | Sparsity: 0.31
# Epoch: 80/200 | Train Loss: 1.1555, Train Acc: 71.26% | Val Loss: 1.1869, Val Acc: 69.85% | Sparsity: 0.32
# Epoch: 81/200 | Train Loss: 1.1570, Train Acc: 71.23% | Val Loss: 1.2562, Val Acc: 67.53% | Sparsity: 0.32
# Epoch: 82/200 | Train Loss: 1.1528, Train Acc: 71.34% | Val Loss: 1.3046, Val Acc: 64.35% | Sparsity: 0.32
# Epoch: 83/200 | Train Loss: 1.1468, Train Acc: 71.73% | Val Loss: 1.2589, Val Acc: 67.25% | Sparsity: 0.33
# Epoch: 84/200 | Train Loss: 1.1468, Train Acc: 71.70% | Val Loss: 1.2081, Val Acc: 68.60% | Sparsity: 0.33
# Epoch: 85/200 | Train Loss: 1.1429, Train Acc: 71.72% | Val Loss: 1.4485, Val Acc: 60.37% | Sparsity: 0.34
# Epoch: 86/200 | Train Loss: 1.1471, Train Acc: 71.50% | Val Loss: 1.2909, Val Acc: 65.00% | Sparsity: 0.34
# Epoch: 87/200 | Train Loss: 1.1348, Train Acc: 72.20% | Val Loss: 1.2070, Val Acc: 69.33% | Sparsity: 0.34
# Epoch: 88/200 | Train Loss: 1.1348, Train Acc: 72.29% | Val Loss: 1.2709, Val Acc: 67.03% | Sparsity: 0.35
# Epoch: 89/200 | Train Loss: 1.1370, Train Acc: 72.15% | Val Loss: 1.2512, Val Acc: 66.87% | Sparsity: 0.35
# Epoch: 90/200 | Train Loss: 1.1294, Train Acc: 72.39% | Val Loss: 1.1768, Val Acc: 69.88% | Sparsity: 0.36
# Epoch: 91/200 | Train Loss: 1.1284, Train Acc: 72.42% | Val Loss: 1.1672, Val Acc: 70.75% | Sparsity: 0.36
# Epoch: 92/200 | Train Loss: 1.1289, Train Acc: 72.39% | Val Loss: 1.1567, Val Acc: 71.17% | Sparsity: 0.36
# Epoch: 93/200 | Train Loss: 1.1260, Train Acc: 72.48% | Val Loss: 1.2011, Val Acc: 69.28% | Sparsity: 0.37
# Epoch: 94/200 | Train Loss: 1.1216, Train Acc: 72.88% | Val Loss: 1.1815, Val Acc: 69.77% | Sparsity: 0.37
# Epoch: 95/200 | Train Loss: 1.1202, Train Acc: 72.91% | Val Loss: 1.1472, Val Acc: 71.58% | Sparsity: 0.38
# Epoch: 96/200 | Train Loss: 1.1168, Train Acc: 72.90% | Val Loss: 1.3331, Val Acc: 64.17% | Sparsity: 0.38
# Epoch: 97/200 | Train Loss: 1.1100, Train Acc: 73.25% | Val Loss: 1.2189, Val Acc: 68.37% | Sparsity: 0.38
# Epoch: 98/200 | Train Loss: 1.1114, Train Acc: 73.00% | Val Loss: 1.1829, Val Acc: 70.48% | Sparsity: 0.39
# Epoch: 99/200 | Train Loss: 1.1099, Train Acc: 73.45% | Val Loss: 1.1652, Val Acc: 70.62% | Sparsity: 0.39
# Epoch: 100/200 | Train Loss: 1.1002, Train Acc: 73.62% | Val Loss: 1.1465, Val Acc: 72.20% | Sparsity: 0.40
# Epoch: 101/200 | Train Loss: 1.1030, Train Acc: 73.42% | Val Loss: 1.2115, Val Acc: 69.03% | Sparsity: 0.40
# Epoch: 102/200 | Train Loss: 1.0975, Train Acc: 73.72% | Val Loss: 1.2014, Val Acc: 69.65% | Sparsity: 0.40
# Epoch: 103/200 | Train Loss: 1.0952, Train Acc: 73.85% | Val Loss: 1.1711, Val Acc: 70.85% | Sparsity: 0.41
# Epoch: 104/200 | Train Loss: 1.0920, Train Acc: 74.18% | Val Loss: 1.2068, Val Acc: 68.55% | Sparsity: 0.41
# Epoch: 105/200 | Train Loss: 1.0880, Train Acc: 74.54% | Val Loss: 1.1295, Val Acc: 72.17% | Sparsity: 0.42
# Epoch: 106/200 | Train Loss: 1.0876, Train Acc: 74.19% | Val Loss: 1.2540, Val Acc: 67.50% | Sparsity: 0.42
# Epoch: 107/200 | Train Loss: 1.0796, Train Acc: 74.66% | Val Loss: 1.2260, Val Acc: 68.50% | Sparsity: 0.42
# Epoch: 108/200 | Train Loss: 1.0803, Train Acc: 74.62% | Val Loss: 1.2021, Val Acc: 69.75% | Sparsity: 0.43
# Epoch: 109/200 | Train Loss: 1.0783, Train Acc: 74.70% | Val Loss: 1.1519, Val Acc: 71.78% | Sparsity: 0.43
# Epoch: 110/200 | Train Loss: 1.0758, Train Acc: 74.82% | Val Loss: 1.1574, Val Acc: 71.57% | Sparsity: 0.44
# Epoch: 111/200 | Train Loss: 1.0685, Train Acc: 75.22% | Val Loss: 1.1235, Val Acc: 72.63% | Sparsity: 0.44
# Epoch: 112/200 | Train Loss: 1.0705, Train Acc: 75.09% | Val Loss: 1.0886, Val Acc: 74.10% | Sparsity: 0.44
# Epoch: 113/200 | Train Loss: 1.0674, Train Acc: 75.13% | Val Loss: 1.2989, Val Acc: 65.72% | Sparsity: 0.45
# Epoch: 114/200 | Train Loss: 1.0629, Train Acc: 75.54% | Val Loss: 1.1264, Val Acc: 72.77% | Sparsity: 0.45
# Epoch: 115/200 | Train Loss: 1.0595, Train Acc: 75.64% | Val Loss: 1.2378, Val Acc: 67.40% | Sparsity: 0.46
# Epoch: 116/200 | Train Loss: 1.0595, Train Acc: 75.49% | Val Loss: 1.2048, Val Acc: 69.53% | Sparsity: 0.46
# Epoch: 117/200 | Train Loss: 1.0524, Train Acc: 75.85% | Val Loss: 1.0590, Val Acc: 75.78% | Sparsity: 0.46
# Epoch: 118/200 | Train Loss: 1.0459, Train Acc: 76.25% | Val Loss: 1.0807, Val Acc: 74.62% | Sparsity: 0.47
# Epoch: 119/200 | Train Loss: 1.0470, Train Acc: 76.30% | Val Loss: 1.1360, Val Acc: 72.62% | Sparsity: 0.47
# Epoch: 120/200 | Train Loss: 1.0454, Train Acc: 76.20% | Val Loss: 1.0579, Val Acc: 75.68% | Sparsity: 0.48
# Epoch: 121/200 | Train Loss: 1.0386, Train Acc: 76.46% | Val Loss: 1.1261, Val Acc: 72.65% | Sparsity: 0.48
# Epoch: 122/200 | Train Loss: 1.0361, Train Acc: 76.55% | Val Loss: 1.1577, Val Acc: 71.55% | Sparsity: 0.48
# Epoch: 123/200 | Train Loss: 1.0309, Train Acc: 76.81% | Val Loss: 1.0733, Val Acc: 74.32% | Sparsity: 0.49
# Epoch: 124/200 | Train Loss: 1.0291, Train Acc: 76.75% | Val Loss: 1.0820, Val Acc: 74.65% | Sparsity: 0.49
# Epoch: 125/200 | Train Loss: 1.0255, Train Acc: 77.04% | Val Loss: 1.0790, Val Acc: 74.55% | Sparsity: 0.50
# Epoch: 126/200 | Train Loss: 1.0217, Train Acc: 77.03% | Val Loss: 1.0887, Val Acc: 74.45% | Sparsity: 0.50
# Epoch: 127/200 | Train Loss: 1.0187, Train Acc: 77.38% | Val Loss: 1.0776, Val Acc: 74.22% | Sparsity: 0.50
# Epoch: 128/200 | Train Loss: 1.0153, Train Acc: 77.50% | Val Loss: 1.0843, Val Acc: 74.62% | Sparsity: 0.51
# Epoch: 129/200 | Train Loss: 1.0104, Train Acc: 77.61% | Val Loss: 1.0446, Val Acc: 75.37% | Sparsity: 0.51
# Epoch: 130/200 | Train Loss: 1.0113, Train Acc: 77.56% | Val Loss: 1.1231, Val Acc: 72.65% | Sparsity: 0.52
# Epoch: 131/200 | Train Loss: 1.0043, Train Acc: 77.91% | Val Loss: 1.0585, Val Acc: 75.35% | Sparsity: 0.52
# Epoch: 132/200 | Train Loss: 0.9998, Train Acc: 77.99% | Val Loss: 1.0859, Val Acc: 74.47% | Sparsity: 0.52
# Epoch: 133/200 | Train Loss: 0.9961, Train Acc: 78.22% | Val Loss: 1.0538, Val Acc: 75.52% | Sparsity: 0.53
# Epoch: 134/200 | Train Loss: 0.9922, Train Acc: 78.60% | Val Loss: 1.0134, Val Acc: 77.42% | Sparsity: 0.53
# Epoch: 135/200 | Train Loss: 0.9917, Train Acc: 78.47% | Val Loss: 1.1146, Val Acc: 73.53% | Sparsity: 0.54
# Epoch: 136/200 | Train Loss: 0.9807, Train Acc: 78.98% | Val Loss: 1.0774, Val Acc: 74.53% | Sparsity: 0.54
# Epoch: 137/200 | Train Loss: 0.9813, Train Acc: 78.86% | Val Loss: 1.0325, Val Acc: 76.07% | Sparsity: 0.54
# Epoch: 138/200 | Train Loss: 0.9788, Train Acc: 79.07% | Val Loss: 0.9996, Val Acc: 78.57% | Sparsity: 0.55
# Epoch: 139/200 | Train Loss: 0.9742, Train Acc: 79.21% | Val Loss: 1.0472, Val Acc: 76.25% | Sparsity: 0.55
# Epoch: 140/200 | Train Loss: 0.9667, Train Acc: 79.65% | Val Loss: 1.0294, Val Acc: 76.47% | Sparsity: 0.56
# Epoch: 141/200 | Train Loss: 0.9643, Train Acc: 79.70% | Val Loss: 1.0429, Val Acc: 76.52% | Sparsity: 0.56
# Epoch: 142/200 | Train Loss: 0.9575, Train Acc: 80.13% | Val Loss: 0.9880, Val Acc: 78.52% | Sparsity: 0.56
# Epoch: 143/200 | Train Loss: 0.9597, Train Acc: 79.92% | Val Loss: 0.9935, Val Acc: 78.35% | Sparsity: 0.57
# Epoch: 144/200 | Train Loss: 0.9564, Train Acc: 80.08% | Val Loss: 0.9768, Val Acc: 79.12% | Sparsity: 0.57
# Epoch: 145/200 | Train Loss: 0.9503, Train Acc: 80.25% | Val Loss: 0.9830, Val Acc: 78.28% | Sparsity: 0.58
# Epoch: 146/200 | Train Loss: 0.9483, Train Acc: 80.33% | Val Loss: 0.9788, Val Acc: 78.78% | Sparsity: 0.58
# Epoch: 147/200 | Train Loss: 0.9385, Train Acc: 80.91% | Val Loss: 0.9426, Val Acc: 80.08% | Sparsity: 0.58
# Epoch: 148/200 | Train Loss: 0.9366, Train Acc: 80.83% | Val Loss: 1.0486, Val Acc: 75.90% | Sparsity: 0.59
# Epoch: 149/200 | Train Loss: 0.9312, Train Acc: 81.26% | Val Loss: 0.9819, Val Acc: 78.98% | Sparsity: 0.59
# Epoch: 150/200 | Train Loss: 0.9261, Train Acc: 81.45% | Val Loss: 0.9377, Val Acc: 80.93% | Sparsity: 0.60
# Epoch: 151/200 | Train Loss: 0.9256, Train Acc: 81.39% | Val Loss: 0.9734, Val Acc: 79.28% | Sparsity: 0.60
# Epoch: 152/200 | Train Loss: 0.9184, Train Acc: 81.68% | Val Loss: 0.9726, Val Acc: 79.50% | Sparsity: 0.60
# Epoch: 153/200 | Train Loss: 0.9180, Train Acc: 81.58% | Val Loss: 0.9428, Val Acc: 80.27% | Sparsity: 0.61
# Epoch: 154/200 | Train Loss: 0.9155, Train Acc: 81.85% | Val Loss: 0.9201, Val Acc: 81.32% | Sparsity: 0.61
# Epoch: 155/200 | Train Loss: 0.9082, Train Acc: 82.02% | Val Loss: 0.9598, Val Acc: 80.42% | Sparsity: 0.62
# Epoch: 156/200 | Train Loss: 0.8970, Train Acc: 82.58% | Val Loss: 0.9451, Val Acc: 80.75% | Sparsity: 0.62
# Epoch: 157/200 | Train Loss: 0.8973, Train Acc: 82.50% | Val Loss: 0.9148, Val Acc: 81.32% | Sparsity: 0.62
# Epoch: 158/200 | Train Loss: 0.8917, Train Acc: 82.80% | Val Loss: 0.9420, Val Acc: 80.95% | Sparsity: 0.63
# Epoch: 159/200 | Train Loss: 0.8820, Train Acc: 83.37% | Val Loss: 0.9116, Val Acc: 81.60% | Sparsity: 0.63
# Epoch: 160/200 | Train Loss: 0.8769, Train Acc: 83.55% | Val Loss: 0.9542, Val Acc: 80.22% | Sparsity: 0.64
# Epoch: 161/200 | Train Loss: 0.8731, Train Acc: 83.66% | Val Loss: 0.9631, Val Acc: 79.83% | Sparsity: 0.64
# Epoch: 162/200 | Train Loss: 0.8711, Train Acc: 83.63% | Val Loss: 0.9561, Val Acc: 79.95% | Sparsity: 0.64
# Epoch: 163/200 | Train Loss: 0.8616, Train Acc: 84.16% | Val Loss: 0.9025, Val Acc: 82.07% | Sparsity: 0.65
# Epoch: 164/200 | Train Loss: 0.8591, Train Acc: 84.33% | Val Loss: 0.9057, Val Acc: 81.60% | Sparsity: 0.65
# Epoch: 165/200 | Train Loss: 0.8502, Train Acc: 84.72% | Val Loss: 0.8964, Val Acc: 82.58% | Sparsity: 0.66
# Epoch: 166/200 | Train Loss: 0.8454, Train Acc: 84.85% | Val Loss: 0.8932, Val Acc: 82.60% | Sparsity: 0.66
# Epoch: 167/200 | Train Loss: 0.8431, Train Acc: 84.93% | Val Loss: 0.8914, Val Acc: 82.90% | Sparsity: 0.66
# Epoch: 168/200 | Train Loss: 0.8364, Train Acc: 85.33% | Val Loss: 0.8774, Val Acc: 83.83% | Sparsity: 0.67
# Epoch: 169/200 | Train Loss: 0.8276, Train Acc: 85.72% | Val Loss: 0.8691, Val Acc: 83.93% | Sparsity: 0.67
# Epoch: 170/200 | Train Loss: 0.8224, Train Acc: 85.96% | Val Loss: 0.8784, Val Acc: 83.33% | Sparsity: 0.68
# Epoch: 171/200 | Train Loss: 0.8161, Train Acc: 86.42% | Val Loss: 0.8539, Val Acc: 83.85% | Sparsity: 0.68
# Epoch: 172/200 | Train Loss: 0.8063, Train Acc: 86.77% | Val Loss: 0.8572, Val Acc: 84.00% | Sparsity: 0.68
# Epoch: 173/200 | Train Loss: 0.8031, Train Acc: 86.94% | Val Loss: 0.8476, Val Acc: 84.90% | Sparsity: 0.69
# Epoch: 174/200 | Train Loss: 0.7949, Train Acc: 87.15% | Val Loss: 0.8409, Val Acc: 84.82% | Sparsity: 0.69
# Epoch: 175/200 | Train Loss: 0.7915, Train Acc: 87.37% | Val Loss: 0.8600, Val Acc: 83.85% | Sparsity: 0.70
# Epoch: 176/200 | Train Loss: 0.7801, Train Acc: 87.90% | Val Loss: 0.8424, Val Acc: 85.17% | Sparsity: 0.70
# Epoch: 177/200 | Train Loss: 0.7717, Train Acc: 88.12% | Val Loss: 0.8490, Val Acc: 84.47% | Sparsity: 0.70
# Epoch: 178/200 | Train Loss: 0.7695, Train Acc: 88.30% | Val Loss: 0.8245, Val Acc: 85.23% | Sparsity: 0.71
# Epoch: 179/200 | Train Loss: 0.7607, Train Acc: 88.62% | Val Loss: 0.8308, Val Acc: 85.67% | Sparsity: 0.71
# Epoch: 180/200 | Train Loss: 0.7514, Train Acc: 89.03% | Val Loss: 0.8176, Val Acc: 86.25% | Sparsity: 0.72
# Epoch: 181/200 | Train Loss: 0.7495, Train Acc: 89.15% | Val Loss: 0.8018, Val Acc: 86.68% | Sparsity: 0.72
# Epoch: 182/200 | Train Loss: 0.7346, Train Acc: 89.88% | Val Loss: 0.7989, Val Acc: 86.57% | Sparsity: 0.72
# Epoch: 183/200 | Train Loss: 0.7275, Train Acc: 90.19% | Val Loss: 0.7932, Val Acc: 87.12% | Sparsity: 0.73
# Epoch: 184/200 | Train Loss: 0.7203, Train Acc: 90.48% | Val Loss: 0.8062, Val Acc: 86.42% | Sparsity: 0.73
# Epoch: 185/200 | Train Loss: 0.7168, Train Acc: 90.69% | Val Loss: 0.7887, Val Acc: 87.28% | Sparsity: 0.74
# Epoch: 186/200 | Train Loss: 0.7085, Train Acc: 91.05% | Val Loss: 0.7677, Val Acc: 88.22% | Sparsity: 0.74
# Epoch: 187/200 | Train Loss: 0.7007, Train Acc: 91.25% | Val Loss: 0.7849, Val Acc: 87.67% | Sparsity: 0.74
# Epoch: 188/200 | Train Loss: 0.6913, Train Acc: 91.74% | Val Loss: 0.7628, Val Acc: 88.40% | Sparsity: 0.75
# Epoch: 189/200 | Train Loss: 0.6864, Train Acc: 92.04% | Val Loss: 0.7654, Val Acc: 88.15% | Sparsity: 0.75
# Epoch: 190/200 | Train Loss: 0.6837, Train Acc: 92.11% | Val Loss: 0.7550, Val Acc: 88.67% | Sparsity: 0.76
# Epoch: 191/200 | Train Loss: 0.6753, Train Acc: 92.46% | Val Loss: 0.7639, Val Acc: 88.05% | Sparsity: 0.76
# Epoch: 192/200 | Train Loss: 0.6705, Train Acc: 92.65% | Val Loss: 0.7576, Val Acc: 88.52% | Sparsity: 0.76
# Epoch: 193/200 | Train Loss: 0.6678, Train Acc: 92.85% | Val Loss: 0.7515, Val Acc: 88.70% | Sparsity: 0.77
# Epoch: 194/200 | Train Loss: 0.6653, Train Acc: 92.88% | Val Loss: 0.7469, Val Acc: 89.13% | Sparsity: 0.77
# Epoch: 195/200 | Train Loss: 0.6617, Train Acc: 93.09% | Val Loss: 0.7497, Val Acc: 89.28% | Sparsity: 0.78
# Epoch: 196/200 | Train Loss: 0.6588, Train Acc: 93.25% | Val Loss: 0.7395, Val Acc: 89.60% | Sparsity: 0.78
# Epoch: 197/200 | Train Loss: 0.6551, Train Acc: 93.52% | Val Loss: 0.7468, Val Acc: 89.62% | Sparsity: 0.78
# Epoch: 198/200 | Train Loss: 0.6553, Train Acc: 93.33% | Val Loss: 0.7367, Val Acc: 89.82% | Sparsity: 0.79
# Epoch: 199/200 | Train Loss: 0.6537, Train Acc: 93.43% | Val Loss: 0.7422, Val Acc: 89.23% | Sparsity: 0.79
# Epoch: 200/200 | Train Loss: 0.6526, Train Acc: 93.48% | Val Loss: 0.7406, Val Acc: 89.48% | Sparsity: 0.80
# Final Results:
# Final Training Loss: 0.6526
# Final Validation Loss: 0.7406
# Final Training Accuracy: 93.48%
# Final Validation Accuracy: 89.48%
# Final Test Loss: 0.7430
# Final Test Accuracy: 89.45%
