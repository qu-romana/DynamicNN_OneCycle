# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms

# Define the basic block for ResNet
class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_channels, out_channels, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(
            in_channels, out_channels, kernel_size=3, stride=stride, padding=1, bias=False
        )
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.conv2 = nn.Conv2d(
            out_channels, out_channels, kernel_size=3, stride=1, padding=1, bias=False
        )
        self.bn2 = nn.BatchNorm2d(out_channels)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_channels != out_channels:
            self.shortcut = nn.Sequential(
                nn.Conv2d(
                    in_channels, out_channels, kernel_size=1, stride=stride, bias=False
                ),
                nn.BatchNorm2d(out_channels),
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out

# Define ResNet
class DynamicSparseResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):  # For CIFAR-10, num_classes=10
        super(DynamicSparseResNet, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(
            3, 64, kernel_size=3, stride=1, padding=1, bias=False  # CIFAR-10 images have 3 channels
        )
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.linear = nn.Linear(512 * block.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        layers = []
        strides = [stride] + [1] * (num_blocks - 1)
        for s in strides:
            layers.append(block(self.in_planes, planes, s))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))  # Output size: 32x32
        out = self.layer1(out)                 # Output size: 32x32
        out = self.layer2(out)                 # Output size: 16x16
        out = self.layer3(out)                 # Output size: 8x8
        out = self.layer4(out)                 # Output size: 4x4
        out = F.avg_pool2d(out, 4)             # Output size: 1x1
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out

def ResNet18(num_classes=10):
    return DynamicSparseResNet(BasicBlock, [2, 2, 2, 2], num_classes=num_classes)

def initialize_weights(model):
    for m in model.modules():
        if isinstance(m, (nn.Conv2d, nn.Linear)):
            nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
            if m.bias is not None:
                nn.init.zeros_(m.bias)
        elif isinstance(m, nn.BatchNorm2d):
            nn.init.ones_(m.weight)
            nn.init.zeros_(m.bias)

def apply_dynamic_supermask(model, sparsity_rate):
    masks = {}
    for name, param in model.named_parameters():
        if 'weight' in name:
            weight_flat = param.data.abs().flatten()
            k = int(weight_flat.shape[0] * (1 - sparsity_rate))
            if k == 0:
                threshold = torch.max(weight_flat) + 1
            else:
                threshold = torch.topk(weight_flat, k, largest=True, sorted=True)[0][-1]
            mask = (param.data.abs() >= threshold).float()
            masks[name] = mask.view(param.size()).to(param.device)
    return masks

def dynamic_weight_update(model, masks):
    for name, param in model.named_parameters():
        if 'weight' in name and param.grad is not None:
            mask = masks[name]
            param.grad.data.mul_(mask)

def train_with_dynamic_pruning(model, train_loader, val_loader, epochs=200, device='cuda'):
    criterion = nn.CrossEntropyLoss(label_smoothing=0.1)
    optimizer = torch.optim.SGD(
        model.parameters(), lr=0.1, momentum=0.9, weight_decay=5e-4
    )
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=epochs)

    initial_sparsity = 0.0
    final_sparsity = 0.8
    sparsity_increment = (final_sparsity - initial_sparsity) / epochs

    train_losses = []
    val_losses = []
    train_acc = []
    val_acc = []

    initialize_weights(model)

    for epoch in range(epochs):
        model.train()
        running_loss = 0
        correct = 0
        total = 0

        current_sparsity = initial_sparsity + sparsity_increment * epoch
        masks = apply_dynamic_supermask(model, current_sparsity)

        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()

            dynamic_weight_update(model, masks)
            optimizer.step()

            running_loss += loss.item() * images.size(0)
            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()

        train_loss = running_loss / total
        train_accuracy = 100.0 * correct / total

        # Validation
        val_loss, val_accuracy = evaluate(model, val_loader, criterion, device)

        train_losses.append(train_loss)
        val_losses.append(val_loss)
        train_acc.append(train_accuracy)
        val_acc.append(val_accuracy)

        scheduler.step()

        print(
            f"Epoch: {epoch+1}/{epochs}"
            f" | Train Loss: {train_loss:.4f}, Train Acc: {train_accuracy:.2f}%"
            f" | Val Loss: {val_loss:.4f}, Val Acc: {val_accuracy:.2f}%"
            f" | Sparsity: {current_sparsity:.2f}"
        )

    return train_losses, val_losses, train_acc, val_acc

def evaluate(model, data_loader, criterion, device):
    model.eval()
    loss_total = 0
    correct = 0
    total = 0

    with torch.no_grad():
        for images, labels in data_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)

            loss_total += loss.item() * images.size(0)
            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()

    avg_loss = loss_total / total
    accuracy = 100.0 * correct / total
    return avg_loss, accuracy

def main():
    torch.manual_seed(42)

    # Data augmentation for CIFAR-10
    transform = transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(15),
        transforms.ColorJitter(
            brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1
        ),
        transforms.ToTensor(),
        transforms.RandomErasing(),
        transforms.Normalize(
            (0.4914, 0.4822, 0.4465),
            (0.2470, 0.2435, 0.2616)
        ),
    ])

    # Load the full CIFAR-10 dataset (both train and test sets)
    train_dataset = torchvision.datasets.CIFAR10(
        root='./data', train=True, download=True, transform=transform
    )
    test_dataset = torchvision.datasets.CIFAR10(
        root='./data', train=False, download=True, transform=transform
    )

    # Combine train and test datasets
    full_dataset = torch.utils.data.ConcatDataset([train_dataset, test_dataset])

    # Calculate sizes for splits
    total_size = len(full_dataset)
    train_size = int(0.8 * total_size)
    val_size = int(0.1 * total_size)
    test_size = total_size - train_size - val_size

    # Split the dataset
    train_dataset, val_dataset, test_dataset = torch.utils.data.random_split(
        full_dataset, [train_size, val_size, test_size]
    )

    # Set up DataLoader for training, validation, and testing data
    batch_size = 128
    train_loader = torch.utils.data.DataLoader(
        train_dataset,
        batch_size=batch_size,
        shuffle=True,
        num_workers=4,
        pin_memory=True,
    )
    val_loader = torch.utils.data.DataLoader(
        val_dataset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=4,
        pin_memory=True,
    )
    test_loader = torch.utils.data.DataLoader(
        test_dataset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=4,
        pin_memory=True,
    )

    # Set device to GPU if available
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model = ResNet18(num_classes=10).to(device)

    # Train and validate the model with dynamic pruning
    train_losses, val_losses, train_acc, val_acc = train_with_dynamic_pruning(
        model, train_loader, val_loader, epochs=200, device=device
    )

    # Plot training results
    import matplotlib.pyplot as plt
    plt.figure(figsize=(12, 4))

    plt.subplot(1, 2, 1)
    plt.plot(train_losses, label='Train Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.title('CIFAR-10 Training and Validation Loss')

    plt.subplot(1, 2, 2)
    plt.plot(train_acc, label='Train Accuracy')
    plt.plot(val_acc, label='Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy (%)')
    plt.legend()
    plt.title('CIFAR-10 Training and Validation Accuracy')

    plt.tight_layout()
    plt.show()

    # Evaluate on the test set
    criterion = nn.CrossEntropyLoss(label_smoothing=0.1)
    test_loss, test_accuracy = evaluate(model, test_loader, criterion, device)

    # Print final metrics
    print("\nFinal Results:")
    print(f"Final Training Loss: {train_losses[-1]:.4f}")
    print(f"Final Validation Loss: {val_losses[-1]:.4f}")
    print(f"Final Training Accuracy: {train_acc[-1]:.2f}%")
    print(f"Final Validation Accuracy: {val_acc[-1]:.2f}%")
    print(f"Final Test Loss: {test_loss:.4f}")
    print(f"Final Test Accuracy: {test_accuracy:.2f}%")

if __name__ == "__main__":
    main()
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170M/170M [00:04<00:00, 42.2MB/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
# Epoch: 1/200 | Train Loss: 3.2626, Train Acc: 18.21% | Val Loss: 2.0893, Val Acc: 24.87% | Sparsity: 0.00
# Epoch: 2/200 | Train Loss: 1.9854, Train Acc: 29.79% | Val Loss: 1.9521, Val Acc: 31.60% | Sparsity: 0.00
# Epoch: 3/200 | Train Loss: 1.8396, Train Acc: 37.06% | Val Loss: 1.8395, Val Acc: 38.02% | Sparsity: 0.01
# Epoch: 4/200 | Train Loss: 1.7210, Train Acc: 42.72% | Val Loss: 1.8566, Val Acc: 37.95% | Sparsity: 0.01
# Epoch: 5/200 | Train Loss: 1.6261, Train Acc: 47.92% | Val Loss: 1.6241, Val Acc: 48.33% | Sparsity: 0.02
# Epoch: 6/200 | Train Loss: 1.5266, Train Acc: 52.94% | Val Loss: 1.6571, Val Acc: 47.98% | Sparsity: 0.02
# Epoch: 7/200 | Train Loss: 1.4474, Train Acc: 56.90% | Val Loss: 1.5254, Val Acc: 53.77% | Sparsity: 0.02
# Epoch: 8/200 | Train Loss: 1.3883, Train Acc: 59.95% | Val Loss: 1.5000, Val Acc: 54.80% | Sparsity: 0.03
# Epoch: 9/200 | Train Loss: 1.3281, Train Acc: 62.95% | Val Loss: 1.3994, Val Acc: 59.18% | Sparsity: 0.03
# Epoch: 10/200 | Train Loss: 1.2683, Train Acc: 65.53% | Val Loss: 1.3649, Val Acc: 62.20% | Sparsity: 0.04
# Epoch: 11/200 | Train Loss: 1.2229, Train Acc: 67.89% | Val Loss: 1.3472, Val Acc: 62.07% | Sparsity: 0.04
# Epoch: 12/200 | Train Loss: 1.1788, Train Acc: 69.91% | Val Loss: 1.2534, Val Acc: 65.52% | Sparsity: 0.04
# Epoch: 13/200 | Train Loss: 1.1523, Train Acc: 71.10% | Val Loss: 1.2939, Val Acc: 65.15% | Sparsity: 0.05
# Epoch: 14/200 | Train Loss: 1.1347, Train Acc: 71.72% | Val Loss: 1.2007, Val Acc: 68.52% | Sparsity: 0.05
# Epoch: 15/200 | Train Loss: 1.1099, Train Acc: 73.06% | Val Loss: 1.2431, Val Acc: 66.68% | Sparsity: 0.06
# Epoch: 16/200 | Train Loss: 1.0980, Train Acc: 73.30% | Val Loss: 1.2611, Val Acc: 67.87% | Sparsity: 0.06
# Epoch: 17/200 | Train Loss: 1.0840, Train Acc: 74.10% | Val Loss: 1.3133, Val Acc: 64.33% | Sparsity: 0.06
# Epoch: 18/200 | Train Loss: 1.0699, Train Acc: 74.80% | Val Loss: 1.1259, Val Acc: 72.38% | Sparsity: 0.07
# Epoch: 19/200 | Train Loss: 1.0592, Train Acc: 75.54% | Val Loss: 1.3613, Val Acc: 63.77% | Sparsity: 0.07
# Epoch: 20/200 | Train Loss: 1.0569, Train Acc: 75.36% | Val Loss: 1.2000, Val Acc: 68.87% | Sparsity: 0.08
# Epoch: 21/200 | Train Loss: 1.0417, Train Acc: 76.06% | Val Loss: 1.1417, Val Acc: 72.12% | Sparsity: 0.08
# Epoch: 22/200 | Train Loss: 1.0361, Train Acc: 76.56% | Val Loss: 1.1426, Val Acc: 71.25% | Sparsity: 0.08
# Epoch: 23/200 | Train Loss: 1.0284, Train Acc: 76.58% | Val Loss: 1.1537, Val Acc: 71.92% | Sparsity: 0.09
# Epoch: 24/200 | Train Loss: 1.0257, Train Acc: 76.71% | Val Loss: 1.1634, Val Acc: 70.97% | Sparsity: 0.09
# Epoch: 25/200 | Train Loss: 1.0200, Train Acc: 77.04% | Val Loss: 1.1534, Val Acc: 71.23% | Sparsity: 0.10
# Epoch: 26/200 | Train Loss: 1.0072, Train Acc: 77.64% | Val Loss: 1.1296, Val Acc: 72.13% | Sparsity: 0.10
# Epoch: 27/200 | Train Loss: 1.0114, Train Acc: 77.40% | Val Loss: 1.1050, Val Acc: 73.12% | Sparsity: 0.10
# Epoch: 28/200 | Train Loss: 1.0022, Train Acc: 77.98% | Val Loss: 1.0850, Val Acc: 74.73% | Sparsity: 0.11
# Epoch: 29/200 | Train Loss: 0.9991, Train Acc: 78.04% | Val Loss: 1.1318, Val Acc: 72.25% | Sparsity: 0.11
# Epoch: 30/200 | Train Loss: 0.9933, Train Acc: 78.38% | Val Loss: 1.1101, Val Acc: 73.97% | Sparsity: 0.12
# Epoch: 31/200 | Train Loss: 0.9916, Train Acc: 78.14% | Val Loss: 1.1991, Val Acc: 69.97% | Sparsity: 0.12
# Epoch: 32/200 | Train Loss: 0.9886, Train Acc: 78.48% | Val Loss: 1.1273, Val Acc: 72.42% | Sparsity: 0.12
# Epoch: 33/200 | Train Loss: 0.9865, Train Acc: 78.70% | Val Loss: 1.1064, Val Acc: 73.92% | Sparsity: 0.13
# Epoch: 34/200 | Train Loss: 0.9772, Train Acc: 79.02% | Val Loss: 1.0807, Val Acc: 74.97% | Sparsity: 0.13
# Epoch: 35/200 | Train Loss: 0.9733, Train Acc: 78.99% | Val Loss: 1.0552, Val Acc: 76.63% | Sparsity: 0.14
# Epoch: 36/200 | Train Loss: 0.9784, Train Acc: 78.95% | Val Loss: 1.0617, Val Acc: 75.17% | Sparsity: 0.14
# Epoch: 37/200 | Train Loss: 0.9711, Train Acc: 79.41% | Val Loss: 1.1568, Val Acc: 71.52% | Sparsity: 0.14
# Epoch: 38/200 | Train Loss: 0.9701, Train Acc: 79.21% | Val Loss: 1.1539, Val Acc: 70.63% | Sparsity: 0.15
# Epoch: 39/200 | Train Loss: 0.9636, Train Acc: 79.72% | Val Loss: 1.0933, Val Acc: 73.67% | Sparsity: 0.15
# Epoch: 40/200 | Train Loss: 0.9663, Train Acc: 79.41% | Val Loss: 1.1151, Val Acc: 73.55% | Sparsity: 0.16
# Epoch: 41/200 | Train Loss: 0.9594, Train Acc: 79.74% | Val Loss: 1.1427, Val Acc: 72.85% | Sparsity: 0.16
# Epoch: 42/200 | Train Loss: 0.9569, Train Acc: 79.99% | Val Loss: 1.0722, Val Acc: 74.60% | Sparsity: 0.16
# Epoch: 43/200 | Train Loss: 0.9569, Train Acc: 79.91% | Val Loss: 1.1469, Val Acc: 71.27% | Sparsity: 0.17
# Epoch: 44/200 | Train Loss: 0.9571, Train Acc: 80.05% | Val Loss: 1.0952, Val Acc: 74.03% | Sparsity: 0.17
# Epoch: 45/200 | Train Loss: 0.9538, Train Acc: 80.16% | Val Loss: 1.0718, Val Acc: 75.25% | Sparsity: 0.18
# Epoch: 46/200 | Train Loss: 0.9554, Train Acc: 79.97% | Val Loss: 1.0867, Val Acc: 74.20% | Sparsity: 0.18
# Epoch: 47/200 | Train Loss: 0.9463, Train Acc: 80.44% | Val Loss: 1.0789, Val Acc: 74.38% | Sparsity: 0.18
# Epoch: 48/200 | Train Loss: 0.9483, Train Acc: 80.32% | Val Loss: 1.0525, Val Acc: 76.08% | Sparsity: 0.19
# Epoch: 49/200 | Train Loss: 0.9435, Train Acc: 80.49% | Val Loss: 1.1463, Val Acc: 71.40% | Sparsity: 0.19
# Epoch: 50/200 | Train Loss: 0.9422, Train Acc: 80.52% | Val Loss: 1.2045, Val Acc: 70.50% | Sparsity: 0.20
# Epoch: 51/200 | Train Loss: 0.9415, Train Acc: 80.44% | Val Loss: 1.0952, Val Acc: 74.03% | Sparsity: 0.20
# Epoch: 52/200 | Train Loss: 0.9345, Train Acc: 80.81% | Val Loss: 1.0838, Val Acc: 74.67% | Sparsity: 0.20
# Epoch: 53/200 | Train Loss: 0.9344, Train Acc: 81.03% | Val Loss: 1.0622, Val Acc: 75.02% | Sparsity: 0.21
# Epoch: 54/200 | Train Loss: 0.9370, Train Acc: 80.75% | Val Loss: 1.1321, Val Acc: 72.53% | Sparsity: 0.21
# Epoch: 55/200 | Train Loss: 0.9285, Train Acc: 81.23% | Val Loss: 1.0489, Val Acc: 76.03% | Sparsity: 0.22
# Epoch: 56/200 | Train Loss: 0.9347, Train Acc: 80.91% | Val Loss: 1.0656, Val Acc: 75.92% | Sparsity: 0.22
# Epoch: 57/200 | Train Loss: 0.9272, Train Acc: 81.36% | Val Loss: 1.0832, Val Acc: 74.68% | Sparsity: 0.22
# Epoch: 58/200 | Train Loss: 0.9298, Train Acc: 81.20% | Val Loss: 1.1062, Val Acc: 73.47% | Sparsity: 0.23
# Epoch: 59/200 | Train Loss: 0.9209, Train Acc: 81.63% | Val Loss: 1.0661, Val Acc: 75.13% | Sparsity: 0.23
# Epoch: 60/200 | Train Loss: 0.9261, Train Acc: 81.26% | Val Loss: 1.0348, Val Acc: 75.90% | Sparsity: 0.24
# Epoch: 61/200 | Train Loss: 0.9260, Train Acc: 81.30% | Val Loss: 1.0896, Val Acc: 74.25% | Sparsity: 0.24
# Epoch: 62/200 | Train Loss: 0.9187, Train Acc: 81.66% | Val Loss: 1.0159, Val Acc: 77.73% | Sparsity: 0.24
# Epoch: 63/200 | Train Loss: 0.9223, Train Acc: 81.61% | Val Loss: 1.1908, Val Acc: 70.68% | Sparsity: 0.25
# Epoch: 64/200 | Train Loss: 0.9159, Train Acc: 81.84% | Val Loss: 1.1123, Val Acc: 73.67% | Sparsity: 0.25
# Epoch: 65/200 | Train Loss: 0.9145, Train Acc: 81.99% | Val Loss: 0.9942, Val Acc: 78.05% | Sparsity: 0.26
# Epoch: 66/200 | Train Loss: 0.9125, Train Acc: 82.02% | Val Loss: 1.0575, Val Acc: 75.67% | Sparsity: 0.26
# Epoch: 67/200 | Train Loss: 0.9116, Train Acc: 81.81% | Val Loss: 1.0526, Val Acc: 76.12% | Sparsity: 0.26
# Epoch: 68/200 | Train Loss: 0.9105, Train Acc: 81.81% | Val Loss: 1.0434, Val Acc: 75.97% | Sparsity: 0.27
# Epoch: 69/200 | Train Loss: 0.9078, Train Acc: 81.88% | Val Loss: 1.0243, Val Acc: 76.92% | Sparsity: 0.27
# Epoch: 70/200 | Train Loss: 0.9076, Train Acc: 82.09% | Val Loss: 1.0227, Val Acc: 77.25% | Sparsity: 0.28
# Epoch: 71/200 | Train Loss: 0.9053, Train Acc: 82.24% | Val Loss: 1.0184, Val Acc: 77.25% | Sparsity: 0.28
# Epoch: 72/200 | Train Loss: 0.9010, Train Acc: 82.35% | Val Loss: 1.0109, Val Acc: 77.35% | Sparsity: 0.28
# Epoch: 73/200 | Train Loss: 0.8987, Train Acc: 82.62% | Val Loss: 0.9683, Val Acc: 79.98% | Sparsity: 0.29
# Epoch: 74/200 | Train Loss: 0.8967, Train Acc: 82.59% | Val Loss: 1.0455, Val Acc: 76.17% | Sparsity: 0.29
# Epoch: 75/200 | Train Loss: 0.8947, Train Acc: 82.70% | Val Loss: 1.0206, Val Acc: 77.65% | Sparsity: 0.30
# Epoch: 76/200 | Train Loss: 0.8952, Train Acc: 82.73% | Val Loss: 1.0049, Val Acc: 77.87% | Sparsity: 0.30
# Epoch: 77/200 | Train Loss: 0.8891, Train Acc: 82.96% | Val Loss: 1.0136, Val Acc: 77.40% | Sparsity: 0.30
# Epoch: 78/200 | Train Loss: 0.8891, Train Acc: 82.95% | Val Loss: 0.9898, Val Acc: 78.28% | Sparsity: 0.31
# Epoch: 79/200 | Train Loss: 0.8867, Train Acc: 82.95% | Val Loss: 1.0880, Val Acc: 74.42% | Sparsity: 0.31
# Epoch: 80/200 | Train Loss: 0.8893, Train Acc: 82.84% | Val Loss: 1.0245, Val Acc: 77.12% | Sparsity: 0.32
# Epoch: 81/200 | Train Loss: 0.8875, Train Acc: 82.86% | Val Loss: 0.9818, Val Acc: 78.70% | Sparsity: 0.32
# Epoch: 82/200 | Train Loss: 0.8838, Train Acc: 83.12% | Val Loss: 1.0194, Val Acc: 77.33% | Sparsity: 0.32
# Epoch: 83/200 | Train Loss: 0.8810, Train Acc: 83.25% | Val Loss: 0.9482, Val Acc: 80.18% | Sparsity: 0.33
# Epoch: 84/200 | Train Loss: 0.8809, Train Acc: 83.32% | Val Loss: 1.0292, Val Acc: 76.25% | Sparsity: 0.33
# Epoch: 85/200 | Train Loss: 0.8789, Train Acc: 83.29% | Val Loss: 1.0058, Val Acc: 77.37% | Sparsity: 0.34
# Epoch: 86/200 | Train Loss: 0.8746, Train Acc: 83.54% | Val Loss: 0.9818, Val Acc: 78.85% | Sparsity: 0.34
# Epoch: 87/200 | Train Loss: 0.8706, Train Acc: 83.86% | Val Loss: 1.0065, Val Acc: 77.55% | Sparsity: 0.34
# Epoch: 88/200 | Train Loss: 0.8706, Train Acc: 83.75% | Val Loss: 0.9942, Val Acc: 78.02% | Sparsity: 0.35
# Epoch: 89/200 | Train Loss: 0.8704, Train Acc: 83.70% | Val Loss: 0.9759, Val Acc: 79.23% | Sparsity: 0.35
# Epoch: 90/200 | Train Loss: 0.8677, Train Acc: 83.91% | Val Loss: 0.9591, Val Acc: 79.75% | Sparsity: 0.36
# Epoch: 91/200 | Train Loss: 0.8662, Train Acc: 83.98% | Val Loss: 1.0976, Val Acc: 73.97% | Sparsity: 0.36
# Epoch: 92/200 | Train Loss: 0.8624, Train Acc: 83.94% | Val Loss: 1.0748, Val Acc: 74.98% | Sparsity: 0.36
# Epoch: 93/200 | Train Loss: 0.8588, Train Acc: 84.27% | Val Loss: 0.9892, Val Acc: 78.97% | Sparsity: 0.37
# Epoch: 94/200 | Train Loss: 0.8592, Train Acc: 84.29% | Val Loss: 0.9852, Val Acc: 78.67% | Sparsity: 0.37
# Epoch: 95/200 | Train Loss: 0.8585, Train Acc: 84.37% | Val Loss: 0.9520, Val Acc: 79.98% | Sparsity: 0.38
# Epoch: 96/200 | Train Loss: 0.8561, Train Acc: 84.43% | Val Loss: 0.9770, Val Acc: 79.12% | Sparsity: 0.38
# Epoch: 97/200 | Train Loss: 0.8509, Train Acc: 84.57% | Val Loss: 0.9718, Val Acc: 79.27% | Sparsity: 0.38
# Epoch: 98/200 | Train Loss: 0.8524, Train Acc: 84.54% | Val Loss: 1.0003, Val Acc: 77.53% | Sparsity: 0.39
# Epoch: 99/200 | Train Loss: 0.8469, Train Acc: 84.65% | Val Loss: 0.9653, Val Acc: 79.57% | Sparsity: 0.39
# Epoch: 100/200 | Train Loss: 0.8469, Train Acc: 84.72% | Val Loss: 0.9443, Val Acc: 80.52% | Sparsity: 0.40
# Epoch: 101/200 | Train Loss: 0.8407, Train Acc: 85.07% | Val Loss: 0.9598, Val Acc: 80.43% | Sparsity: 0.40
# Epoch: 102/200 | Train Loss: 0.8423, Train Acc: 85.10% | Val Loss: 0.9093, Val Acc: 81.93% | Sparsity: 0.40
# Epoch: 103/200 | Train Loss: 0.8377, Train Acc: 85.21% | Val Loss: 0.9204, Val Acc: 81.58% | Sparsity: 0.41
# Epoch: 104/200 | Train Loss: 0.8394, Train Acc: 85.07% | Val Loss: 0.9608, Val Acc: 80.50% | Sparsity: 0.41
# Epoch: 105/200 | Train Loss: 0.8380, Train Acc: 85.19% | Val Loss: 0.9366, Val Acc: 81.15% | Sparsity: 0.42
# Epoch: 106/200 | Train Loss: 0.8350, Train Acc: 85.33% | Val Loss: 0.8970, Val Acc: 82.73% | Sparsity: 0.42
# Epoch: 107/200 | Train Loss: 0.8319, Train Acc: 85.29% | Val Loss: 0.9233, Val Acc: 81.53% | Sparsity: 0.42
# Epoch: 108/200 | Train Loss: 0.8228, Train Acc: 85.88% | Val Loss: 0.9985, Val Acc: 77.60% | Sparsity: 0.43
# Epoch: 109/200 | Train Loss: 0.8260, Train Acc: 85.66% | Val Loss: 0.9304, Val Acc: 80.92% | Sparsity: 0.43
# Epoch: 110/200 | Train Loss: 0.8241, Train Acc: 85.94% | Val Loss: 0.9699, Val Acc: 79.85% | Sparsity: 0.44
# Epoch: 111/200 | Train Loss: 0.8222, Train Acc: 85.80% | Val Loss: 0.9255, Val Acc: 81.15% | Sparsity: 0.44
# Epoch: 112/200 | Train Loss: 0.8216, Train Acc: 85.83% | Val Loss: 0.9890, Val Acc: 78.52% | Sparsity: 0.44
# Epoch: 113/200 | Train Loss: 0.8208, Train Acc: 86.11% | Val Loss: 0.9621, Val Acc: 80.03% | Sparsity: 0.45
# Epoch: 114/200 | Train Loss: 0.8211, Train Acc: 85.94% | Val Loss: 0.9024, Val Acc: 82.50% | Sparsity: 0.45
# Epoch: 115/200 | Train Loss: 0.8116, Train Acc: 86.40% | Val Loss: 0.9109, Val Acc: 82.07% | Sparsity: 0.46
# Epoch: 116/200 | Train Loss: 0.8115, Train Acc: 86.31% | Val Loss: 0.9274, Val Acc: 81.65% | Sparsity: 0.46
# Epoch: 117/200 | Train Loss: 0.8071, Train Acc: 86.51% | Val Loss: 0.9111, Val Acc: 82.30% | Sparsity: 0.46
# Epoch: 118/200 | Train Loss: 0.8045, Train Acc: 86.76% | Val Loss: 0.9588, Val Acc: 80.53% | Sparsity: 0.47
# Epoch: 119/200 | Train Loss: 0.8025, Train Acc: 86.85% | Val Loss: 0.9079, Val Acc: 82.07% | Sparsity: 0.47
# Epoch: 120/200 | Train Loss: 0.8026, Train Acc: 86.83% | Val Loss: 0.9153, Val Acc: 81.53% | Sparsity: 0.48
# Epoch: 121/200 | Train Loss: 0.7961, Train Acc: 87.05% | Val Loss: 0.9181, Val Acc: 81.67% | Sparsity: 0.48
# Epoch: 122/200 | Train Loss: 0.8017, Train Acc: 86.84% | Val Loss: 0.9013, Val Acc: 82.40% | Sparsity: 0.48
# Epoch: 123/200 | Train Loss: 0.7908, Train Acc: 87.33% | Val Loss: 0.9599, Val Acc: 80.42% | Sparsity: 0.49
# Epoch: 124/200 | Train Loss: 0.7955, Train Acc: 86.92% | Val Loss: 0.8838, Val Acc: 83.80% | Sparsity: 0.49
# Epoch: 125/200 | Train Loss: 0.7891, Train Acc: 87.22% | Val Loss: 0.9235, Val Acc: 81.27% | Sparsity: 0.50
# Epoch: 126/200 | Train Loss: 0.7883, Train Acc: 87.35% | Val Loss: 0.8844, Val Acc: 82.73% | Sparsity: 0.50
# Epoch: 127/200 | Train Loss: 0.7860, Train Acc: 87.34% | Val Loss: 0.8684, Val Acc: 83.97% | Sparsity: 0.50
# Epoch: 128/200 | Train Loss: 0.7794, Train Acc: 87.71% | Val Loss: 0.8734, Val Acc: 83.97% | Sparsity: 0.51
# Epoch: 129/200 | Train Loss: 0.7796, Train Acc: 87.80% | Val Loss: 0.9189, Val Acc: 81.32% | Sparsity: 0.51
# Epoch: 130/200 | Train Loss: 0.7779, Train Acc: 87.92% | Val Loss: 0.9145, Val Acc: 82.23% | Sparsity: 0.52
# Epoch: 131/200 | Train Loss: 0.7741, Train Acc: 87.90% | Val Loss: 0.8742, Val Acc: 83.47% | Sparsity: 0.52
# Epoch: 132/200 | Train Loss: 0.7691, Train Acc: 88.25% | Val Loss: 0.8884, Val Acc: 83.28% | Sparsity: 0.52
# Epoch: 133/200 | Train Loss: 0.7704, Train Acc: 88.24% | Val Loss: 0.9033, Val Acc: 82.05% | Sparsity: 0.53
# Epoch: 134/200 | Train Loss: 0.7668, Train Acc: 88.19% | Val Loss: 0.8725, Val Acc: 84.05% | Sparsity: 0.53
# Epoch: 135/200 | Train Loss: 0.7608, Train Acc: 88.59% | Val Loss: 0.8685, Val Acc: 83.98% | Sparsity: 0.54
# Epoch: 136/200 | Train Loss: 0.7558, Train Acc: 88.74% | Val Loss: 0.8723, Val Acc: 83.58% | Sparsity: 0.54
# Epoch: 137/200 | Train Loss: 0.7571, Train Acc: 88.72% | Val Loss: 0.8583, Val Acc: 84.47% | Sparsity: 0.54
# Epoch: 138/200 | Train Loss: 0.7488, Train Acc: 89.18% | Val Loss: 0.8920, Val Acc: 83.00% | Sparsity: 0.55
# Epoch: 139/200 | Train Loss: 0.7485, Train Acc: 89.14% | Val Loss: 0.9051, Val Acc: 82.32% | Sparsity: 0.55
# Epoch: 140/200 | Train Loss: 0.7488, Train Acc: 89.09% | Val Loss: 0.8540, Val Acc: 84.62% | Sparsity: 0.56
# Epoch: 141/200 | Train Loss: 0.7477, Train Acc: 89.21% | Val Loss: 0.8647, Val Acc: 84.18% | Sparsity: 0.56
# Epoch: 142/200 | Train Loss: 0.7404, Train Acc: 89.59% | Val Loss: 0.8781, Val Acc: 83.63% | Sparsity: 0.56
# Epoch: 143/200 | Train Loss: 0.7396, Train Acc: 89.48% | Val Loss: 0.8467, Val Acc: 84.68% | Sparsity: 0.57
# Epoch: 144/200 | Train Loss: 0.7330, Train Acc: 89.80% | Val Loss: 0.8634, Val Acc: 84.28% | Sparsity: 0.57
# Epoch: 145/200 | Train Loss: 0.7351, Train Acc: 89.61% | Val Loss: 0.8419, Val Acc: 85.33% | Sparsity: 0.58
# Epoch: 146/200 | Train Loss: 0.7307, Train Acc: 89.85% | Val Loss: 0.8458, Val Acc: 85.13% | Sparsity: 0.58
# Epoch: 147/200 | Train Loss: 0.7200, Train Acc: 90.35% | Val Loss: 0.8064, Val Acc: 86.87% | Sparsity: 0.58
# Epoch: 148/200 | Train Loss: 0.7200, Train Acc: 90.35% | Val Loss: 0.8572, Val Acc: 84.23% | Sparsity: 0.59
# Epoch: 149/200 | Train Loss: 0.7186, Train Acc: 90.49% | Val Loss: 0.8047, Val Acc: 86.88% | Sparsity: 0.59
# Epoch: 150/200 | Train Loss: 0.7140, Train Acc: 90.68% | Val Loss: 0.8639, Val Acc: 84.40% | Sparsity: 0.60
# Epoch: 151/200 | Train Loss: 0.7143, Train Acc: 90.64% | Val Loss: 0.8047, Val Acc: 86.48% | Sparsity: 0.60
# Epoch: 152/200 | Train Loss: 0.7076, Train Acc: 90.96% | Val Loss: 0.8004, Val Acc: 86.80% | Sparsity: 0.60
# Epoch: 153/200 | Train Loss: 0.7056, Train Acc: 91.05% | Val Loss: 0.8207, Val Acc: 86.23% | Sparsity: 0.61
# Epoch: 154/200 | Train Loss: 0.7017, Train Acc: 91.27% | Val Loss: 0.8127, Val Acc: 86.03% | Sparsity: 0.61
# Epoch: 155/200 | Train Loss: 0.6964, Train Acc: 91.44% | Val Loss: 0.7815, Val Acc: 87.77% | Sparsity: 0.62
# Epoch: 156/200 | Train Loss: 0.6919, Train Acc: 91.72% | Val Loss: 0.8550, Val Acc: 84.97% | Sparsity: 0.62
# Epoch: 157/200 | Train Loss: 0.6913, Train Acc: 91.80% | Val Loss: 0.8141, Val Acc: 86.58% | Sparsity: 0.62
# Epoch: 158/200 | Train Loss: 0.6888, Train Acc: 91.81% | Val Loss: 0.8074, Val Acc: 86.50% | Sparsity: 0.63
# Epoch: 159/200 | Train Loss: 0.6814, Train Acc: 92.03% | Val Loss: 0.8159, Val Acc: 86.32% | Sparsity: 0.63
# Epoch: 160/200 | Train Loss: 0.6802, Train Acc: 92.28% | Val Loss: 0.7849, Val Acc: 87.30% | Sparsity: 0.64
# Epoch: 161/200 | Train Loss: 0.6722, Train Acc: 92.51% | Val Loss: 0.7756, Val Acc: 88.25% | Sparsity: 0.64
# Epoch: 162/200 | Train Loss: 0.6687, Train Acc: 92.62% | Val Loss: 0.7819, Val Acc: 87.83% | Sparsity: 0.64
# Epoch: 163/200 | Train Loss: 0.6684, Train Acc: 92.76% | Val Loss: 0.7828, Val Acc: 87.52% | Sparsity: 0.65
# Epoch: 164/200 | Train Loss: 0.6632, Train Acc: 92.95% | Val Loss: 0.7836, Val Acc: 87.67% | Sparsity: 0.65
# Epoch: 165/200 | Train Loss: 0.6548, Train Acc: 93.20% | Val Loss: 0.7775, Val Acc: 87.80% | Sparsity: 0.66
# Epoch: 166/200 | Train Loss: 0.6530, Train Acc: 93.46% | Val Loss: 0.7522, Val Acc: 89.00% | Sparsity: 0.66
# Epoch: 167/200 | Train Loss: 0.6475, Train Acc: 93.58% | Val Loss: 0.7563, Val Acc: 88.85% | Sparsity: 0.66
# Epoch: 168/200 | Train Loss: 0.6467, Train Acc: 93.65% | Val Loss: 0.7529, Val Acc: 89.28% | Sparsity: 0.67
# Epoch: 169/200 | Train Loss: 0.6394, Train Acc: 94.05% | Val Loss: 0.7535, Val Acc: 89.18% | Sparsity: 0.67
# Epoch: 170/200 | Train Loss: 0.6358, Train Acc: 94.21% | Val Loss: 0.7581, Val Acc: 88.75% | Sparsity: 0.68
# Epoch: 171/200 | Train Loss: 0.6293, Train Acc: 94.57% | Val Loss: 0.7571, Val Acc: 89.15% | Sparsity: 0.68
# Epoch: 172/200 | Train Loss: 0.6304, Train Acc: 94.40% | Val Loss: 0.7473, Val Acc: 89.22% | Sparsity: 0.68
# Epoch: 173/200 | Train Loss: 0.6253, Train Acc: 94.61% | Val Loss: 0.7489, Val Acc: 89.80% | Sparsity: 0.69
# Epoch: 174/200 | Train Loss: 0.6207, Train Acc: 94.80% | Val Loss: 0.7401, Val Acc: 89.70% | Sparsity: 0.69
# Epoch: 175/200 | Train Loss: 0.6191, Train Acc: 94.96% | Val Loss: 0.7248, Val Acc: 90.65% | Sparsity: 0.70
# Epoch: 176/200 | Train Loss: 0.6138, Train Acc: 95.14% | Val Loss: 0.7373, Val Acc: 90.12% | Sparsity: 0.70
# Epoch: 177/200 | Train Loss: 0.6121, Train Acc: 95.19% | Val Loss: 0.7303, Val Acc: 90.47% | Sparsity: 0.70
# Epoch: 178/200 | Train Loss: 0.6079, Train Acc: 95.50% | Val Loss: 0.7421, Val Acc: 89.42% | Sparsity: 0.71
# Epoch: 179/200 | Train Loss: 0.6040, Train Acc: 95.70% | Val Loss: 0.7268, Val Acc: 90.30% | Sparsity: 0.71
# Epoch: 180/200 | Train Loss: 0.6003, Train Acc: 95.73% | Val Loss: 0.7217, Val Acc: 90.52% | Sparsity: 0.72
# Epoch: 181/200 | Train Loss: 0.6014, Train Acc: 95.75% | Val Loss: 0.7270, Val Acc: 89.95% | Sparsity: 0.72
# Epoch: 182/200 | Train Loss: 0.5966, Train Acc: 96.02% | Val Loss: 0.7379, Val Acc: 89.80% | Sparsity: 0.72
# Epoch: 183/200 | Train Loss: 0.5916, Train Acc: 96.12% | Val Loss: 0.7224, Val Acc: 90.48% | Sparsity: 0.73
# Epoch: 184/200 | Train Loss: 0.5925, Train Acc: 96.18% | Val Loss: 0.7199, Val Acc: 90.63% | Sparsity: 0.73
# Epoch: 185/200 | Train Loss: 0.5890, Train Acc: 96.32% | Val Loss: 0.7215, Val Acc: 90.90% | Sparsity: 0.74
# Epoch: 186/200 | Train Loss: 0.5880, Train Acc: 96.30% | Val Loss: 0.7183, Val Acc: 90.83% | Sparsity: 0.74
# Epoch: 187/200 | Train Loss: 0.5867, Train Acc: 96.41% | Val Loss: 0.7248, Val Acc: 90.42% | Sparsity: 0.74
# Epoch: 188/200 | Train Loss: 0.5808, Train Acc: 96.70% | Val Loss: 0.7081, Val Acc: 91.45% | Sparsity: 0.75
# Epoch: 189/200 | Train Loss: 0.5823, Train Acc: 96.60% | Val Loss: 0.7122, Val Acc: 91.15% | Sparsity: 0.75
# Epoch: 190/200 | Train Loss: 0.5808, Train Acc: 96.62% | Val Loss: 0.7096, Val Acc: 91.22% | Sparsity: 0.76
# Epoch: 191/200 | Train Loss: 0.5817, Train Acc: 96.63% | Val Loss: 0.7100, Val Acc: 91.20% | Sparsity: 0.76
# Epoch: 192/200 | Train Loss: 0.5784, Train Acc: 96.78% | Val Loss: 0.7098, Val Acc: 91.05% | Sparsity: 0.76
# Epoch: 193/200 | Train Loss: 0.5783, Train Acc: 96.71% | Val Loss: 0.7024, Val Acc: 91.68% | Sparsity: 0.77
# Epoch: 194/200 | Train Loss: 0.5764, Train Acc: 96.85% | Val Loss: 0.7084, Val Acc: 91.17% | Sparsity: 0.77
# Epoch: 195/200 | Train Loss: 0.5762, Train Acc: 96.87% | Val Loss: 0.7157, Val Acc: 91.02% | Sparsity: 0.78
# Epoch: 196/200 | Train Loss: 0.5787, Train Acc: 96.71% | Val Loss: 0.7146, Val Acc: 90.85% | Sparsity: 0.78
# Epoch: 197/200 | Train Loss: 0.5758, Train Acc: 96.94% | Val Loss: 0.7069, Val Acc: 91.10% | Sparsity: 0.78
# Epoch: 198/200 | Train Loss: 0.5760, Train Acc: 96.88% | Val Loss: 0.7118, Val Acc: 91.08% | Sparsity: 0.79
# Epoch: 199/200 | Train Loss: 0.5731, Train Acc: 97.07% | Val Loss: 0.7169, Val Acc: 90.93% | Sparsity: 0.79
# Epoch: 200/200 | Train Loss: 0.5747, Train Acc: 96.84% | Val Loss: 0.7063, Val Acc: 91.25% | Sparsity: 0.80
# Final Results:
# Final Training Loss: 0.5747
# Final Validation Loss: 0.7063
# Final Training Accuracy: 96.84%
# Final Validation Accuracy: 91.25%
# Final Test Loss: 0.7012
# Final Test Accuracy: 91.88%
