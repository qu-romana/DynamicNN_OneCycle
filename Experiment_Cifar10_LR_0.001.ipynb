# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms

# Define the basic block for ResNet
class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_channels, out_channels, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(
            in_channels, out_channels, kernel_size=3, stride=stride, padding=1, bias=False
        )
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.conv2 = nn.Conv2d(
            out_channels, out_channels, kernel_size=3, stride=1, padding=1, bias=False
        )
        self.bn2 = nn.BatchNorm2d(out_channels)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_channels != out_channels:
            self.shortcut = nn.Sequential(
                nn.Conv2d(
                    in_channels, out_channels, kernel_size=1, stride=stride, bias=False
                ),
                nn.BatchNorm2d(out_channels),
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out

# Define ResNet
class DynamicSparseResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):  # For CIFAR-10, num_classes=10
        super(DynamicSparseResNet, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(
            3, 64, kernel_size=3, stride=1, padding=1, bias=False  # CIFAR-10 images have 3 channels
        )
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.linear = nn.Linear(512 * block.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        layers = []
        strides = [stride] + [1] * (num_blocks - 1)
        for s in strides:
            layers.append(block(self.in_planes, planes, s))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))  # Output size: 32x32
        out = self.layer1(out)                 # Output size: 32x32
        out = self.layer2(out)                 # Output size: 16x16
        out = self.layer3(out)                 # Output size: 8x8
        out = self.layer4(out)                 # Output size: 4x4
        out = F.avg_pool2d(out, 4)             # Output size: 1x1
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out

def ResNet18(num_classes=10):
    return DynamicSparseResNet(BasicBlock, [2, 2, 2, 2], num_classes=num_classes)

def initialize_weights(model):
    for m in model.modules():
        if isinstance(m, (nn.Conv2d, nn.Linear)):
            nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
            if m.bias is not None:
                nn.init.zeros_(m.bias)
        elif isinstance(m, nn.BatchNorm2d):
            nn.init.ones_(m.weight)
            nn.init.zeros_(m.bias)

def apply_dynamic_supermask(model, sparsity_rate):
    masks = {}
    for name, param in model.named_parameters():
        if 'weight' in name:
            weight_flat = param.data.abs().flatten()
            k = int(weight_flat.shape[0] * (1 - sparsity_rate))
            if k == 0:
                threshold = torch.max(weight_flat) + 1
            else:
                threshold = torch.topk(weight_flat, k, largest=True, sorted=True)[0][-1]
            mask = (param.data.abs() >= threshold).float()
            masks[name] = mask.view(param.size()).to(param.device)
    return masks

def dynamic_weight_update(model, masks):
    for name, param in model.named_parameters():
        if 'weight' in name and param.grad is not None:
            mask = masks[name]
            param.grad.data.mul_(mask)

def train_with_dynamic_pruning(model, train_loader, val_loader, epochs=200, device='cuda'):
    criterion = nn.CrossEntropyLoss(label_smoothing=0.1)
    optimizer = torch.optim.SGD(
        model.parameters(), lr=0.001, momentum=0.9, weight_decay=5e-4
    )
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=epochs)

    initial_sparsity = 0.0
    final_sparsity = 0.8
    sparsity_increment = (final_sparsity - initial_sparsity) / epochs

    train_losses = []
    val_losses = []
    train_acc = []
    val_acc = []

    initialize_weights(model)

    for epoch in range(epochs):
        model.train()
        running_loss = 0
        correct = 0
        total = 0

        current_sparsity = initial_sparsity + sparsity_increment * epoch
        masks = apply_dynamic_supermask(model, current_sparsity)

        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()

            dynamic_weight_update(model, masks)
            optimizer.step()

            running_loss += loss.item() * images.size(0)
            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()

        train_loss = running_loss / total
        train_accuracy = 100.0 * correct / total

        # Validation
        val_loss, val_accuracy = evaluate(model, val_loader, criterion, device)

        train_losses.append(train_loss)
        val_losses.append(val_loss)
        train_acc.append(train_accuracy)
        val_acc.append(val_accuracy)

        scheduler.step()

        print(
            f"Epoch: {epoch+1}/{epochs}"
            f" | Train Loss: {train_loss:.4f}, Train Acc: {train_accuracy:.2f}%"
            f" | Val Loss: {val_loss:.4f}, Val Acc: {val_accuracy:.2f}%"
            f" | Sparsity: {current_sparsity:.2f}"
        )

    return train_losses, val_losses, train_acc, val_acc

def evaluate(model, data_loader, criterion, device):
    model.eval()
    loss_total = 0
    correct = 0
    total = 0

    with torch.no_grad():
        for images, labels in data_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)

            loss_total += loss.item() * images.size(0)
            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()

    avg_loss = loss_total / total
    accuracy = 100.0 * correct / total
    return avg_loss, accuracy

def main():
    torch.manual_seed(42)

    # Data augmentation for CIFAR-10
    transform = transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(15),
        transforms.ColorJitter(
            brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1
        ),
        transforms.ToTensor(),
        transforms.RandomErasing(),
        transforms.Normalize(
            (0.4914, 0.4822, 0.4465),
            (0.2470, 0.2435, 0.2616)
        ),
    ])

    # Load the full CIFAR-10 dataset (both train and test sets)
    train_dataset = torchvision.datasets.CIFAR10(
        root='./data', train=True, download=True, transform=transform
    )
    test_dataset = torchvision.datasets.CIFAR10(
        root='./data', train=False, download=True, transform=transform
    )

    # Combine train and test datasets
    full_dataset = torch.utils.data.ConcatDataset([train_dataset, test_dataset])

    # Calculate sizes for splits
    total_size = len(full_dataset)
    train_size = int(0.8 * total_size)
    val_size = int(0.1 * total_size)
    test_size = total_size - train_size - val_size

    # Split the dataset
    train_dataset, val_dataset, test_dataset = torch.utils.data.random_split(
        full_dataset, [train_size, val_size, test_size]
    )

    # Set up DataLoader for training, validation, and testing data
    batch_size = 128
    train_loader = torch.utils.data.DataLoader(
        train_dataset,
        batch_size=batch_size,
        shuffle=True,
        num_workers=4,
        pin_memory=True,
    )
    val_loader = torch.utils.data.DataLoader(
        val_dataset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=4,
        pin_memory=True,
    )
    test_loader = torch.utils.data.DataLoader(
        test_dataset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=4,
        pin_memory=True,
    )

    # Set device to GPU if available
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model = ResNet18(num_classes=10).to(device)

    # Train and validate the model with dynamic pruning
    train_losses, val_losses, train_acc, val_acc = train_with_dynamic_pruning(
        model, train_loader, val_loader, epochs=200, device=device
    )

    # Plot training results
    import matplotlib.pyplot as plt
    plt.figure(figsize=(12, 4))

    plt.subplot(1, 2, 1)
    plt.plot(train_losses, label='Train Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.title('CIFAR-10 Training and Validation Loss')

    plt.subplot(1, 2, 2)
    plt.plot(train_acc, label='Train Accuracy')
    plt.plot(val_acc, label='Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy (%)')
    plt.legend()
    plt.title('CIFAR-10 Training and Validation Accuracy')

    plt.tight_layout()
    plt.show()

    # Evaluate on the test set
    criterion = nn.CrossEntropyLoss(label_smoothing=0.1)
    test_loss, test_accuracy = evaluate(model, test_loader, criterion, device)

    # Print final metrics
    print("\nFinal Results:")
    print(f"Final Training Loss: {train_losses[-1]:.4f}")
    print(f"Final Validation Loss: {val_losses[-1]:.4f}")
    print(f"Final Training Accuracy: {train_acc[-1]:.2f}%")
    print(f"Final Validation Accuracy: {val_acc[-1]:.2f}%")
    print(f"Final Test Loss: {test_loss:.4f}")
    print(f"Final Test Accuracy: {test_accuracy:.2f}%")

if __name__ == "__main__":
    main()
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170M/170M [00:13<00:00, 13.0MB/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
# Epoch: 1/200 | Train Loss: 2.5891, Train Acc: 27.10% | Val Loss: 1.9875, Val Acc: 33.38% | Sparsity: 0.00
# Epoch: 2/200 | Train Loss: 1.9098, Train Acc: 36.20% | Val Loss: 1.8791, Val Acc: 38.67% | Sparsity: 0.00
# Epoch: 3/200 | Train Loss: 1.8151, Train Acc: 40.17% | Val Loss: 1.8057, Val Acc: 41.13% | Sparsity: 0.01
# Epoch: 4/200 | Train Loss: 1.7497, Train Acc: 43.12% | Val Loss: 1.7726, Val Acc: 42.47% | Sparsity: 0.01
# Epoch: 5/200 | Train Loss: 1.7075, Train Acc: 45.00% | Val Loss: 1.7438, Val Acc: 45.55% | Sparsity: 0.02
# Epoch: 6/200 | Train Loss: 1.6680, Train Acc: 46.70% | Val Loss: 1.6642, Val Acc: 47.75% | Sparsity: 0.02
# Epoch: 7/200 | Train Loss: 1.6318, Train Acc: 48.98% | Val Loss: 1.6852, Val Acc: 46.70% | Sparsity: 0.02
# Epoch: 8/200 | Train Loss: 1.5995, Train Acc: 50.22% | Val Loss: 1.6295, Val Acc: 49.22% | Sparsity: 0.03
# Epoch: 9/200 | Train Loss: 1.5760, Train Acc: 51.69% | Val Loss: 1.6269, Val Acc: 50.05% | Sparsity: 0.03
# Epoch: 10/200 | Train Loss: 1.5450, Train Acc: 53.01% | Val Loss: 1.5560, Val Acc: 51.33% | Sparsity: 0.04
# Epoch: 11/200 | Train Loss: 1.5219, Train Acc: 54.24% | Val Loss: 1.5719, Val Acc: 52.67% | Sparsity: 0.04
# Epoch: 12/200 | Train Loss: 1.4983, Train Acc: 55.44% | Val Loss: 1.5434, Val Acc: 53.53% | Sparsity: 0.04
# Epoch: 13/200 | Train Loss: 1.4778, Train Acc: 56.51% | Val Loss: 1.4920, Val Acc: 55.35% | Sparsity: 0.05
# Epoch: 14/200 | Train Loss: 1.4564, Train Acc: 57.28% | Val Loss: 1.4938, Val Acc: 55.32% | Sparsity: 0.05
# Epoch: 15/200 | Train Loss: 1.4418, Train Acc: 58.05% | Val Loss: 1.4765, Val Acc: 57.35% | Sparsity: 0.06
# Epoch: 16/200 | Train Loss: 1.4222, Train Acc: 59.19% | Val Loss: 1.4499, Val Acc: 57.68% | Sparsity: 0.06
# Epoch: 17/200 | Train Loss: 1.4076, Train Acc: 59.85% | Val Loss: 1.4469, Val Acc: 58.22% | Sparsity: 0.06
# Epoch: 18/200 | Train Loss: 1.3919, Train Acc: 60.61% | Val Loss: 1.4301, Val Acc: 58.53% | Sparsity: 0.07
# Epoch: 19/200 | Train Loss: 1.3753, Train Acc: 61.27% | Val Loss: 1.4363, Val Acc: 58.22% | Sparsity: 0.07
# Epoch: 20/200 | Train Loss: 1.3654, Train Acc: 61.89% | Val Loss: 1.4501, Val Acc: 58.92% | Sparsity: 0.08
# Epoch: 21/200 | Train Loss: 1.3474, Train Acc: 62.95% | Val Loss: 1.4067, Val Acc: 60.12% | Sparsity: 0.08
# Epoch: 22/200 | Train Loss: 1.3353, Train Acc: 63.41% | Val Loss: 1.3846, Val Acc: 60.78% | Sparsity: 0.08
# Epoch: 23/200 | Train Loss: 1.3253, Train Acc: 63.74% | Val Loss: 1.3734, Val Acc: 61.18% | Sparsity: 0.09
# Epoch: 24/200 | Train Loss: 1.3125, Train Acc: 64.42% | Val Loss: 1.3963, Val Acc: 61.25% | Sparsity: 0.09
# Epoch: 25/200 | Train Loss: 1.3032, Train Acc: 64.87% | Val Loss: 1.3610, Val Acc: 62.68% | Sparsity: 0.10
# Epoch: 26/200 | Train Loss: 1.2921, Train Acc: 65.40% | Val Loss: 1.3295, Val Acc: 63.45% | Sparsity: 0.10
# Epoch: 27/200 | Train Loss: 1.2850, Train Acc: 65.56% | Val Loss: 1.3304, Val Acc: 64.00% | Sparsity: 0.10
# Epoch: 28/200 | Train Loss: 1.2722, Train Acc: 66.22% | Val Loss: 1.3700, Val Acc: 61.35% | Sparsity: 0.11
# Epoch: 29/200 | Train Loss: 1.2636, Train Acc: 66.54% | Val Loss: 1.2875, Val Acc: 65.78% | Sparsity: 0.11
# Epoch: 30/200 | Train Loss: 1.2551, Train Acc: 67.13% | Val Loss: 1.2979, Val Acc: 65.02% | Sparsity: 0.12
# Epoch: 31/200 | Train Loss: 1.2461, Train Acc: 67.44% | Val Loss: 1.2703, Val Acc: 65.82% | Sparsity: 0.12
# Epoch: 32/200 | Train Loss: 1.2377, Train Acc: 67.84% | Val Loss: 1.2899, Val Acc: 65.80% | Sparsity: 0.12
# Epoch: 33/200 | Train Loss: 1.2319, Train Acc: 68.23% | Val Loss: 1.2639, Val Acc: 67.02% | Sparsity: 0.13
# Epoch: 34/200 | Train Loss: 1.2221, Train Acc: 68.61% | Val Loss: 1.2853, Val Acc: 65.68% | Sparsity: 0.13
# Epoch: 35/200 | Train Loss: 1.2068, Train Acc: 69.56% | Val Loss: 1.2436, Val Acc: 67.42% | Sparsity: 0.14
# Epoch: 36/200 | Train Loss: 1.2054, Train Acc: 69.48% | Val Loss: 1.2405, Val Acc: 67.88% | Sparsity: 0.14
# Epoch: 37/200 | Train Loss: 1.1966, Train Acc: 69.80% | Val Loss: 1.2390, Val Acc: 67.42% | Sparsity: 0.14
# Epoch: 38/200 | Train Loss: 1.1896, Train Acc: 70.10% | Val Loss: 1.2398, Val Acc: 68.33% | Sparsity: 0.15
# Epoch: 39/200 | Train Loss: 1.1827, Train Acc: 70.46% | Val Loss: 1.2281, Val Acc: 68.80% | Sparsity: 0.15
# Epoch: 40/200 | Train Loss: 1.1730, Train Acc: 70.99% | Val Loss: 1.2175, Val Acc: 69.00% | Sparsity: 0.16
# Epoch: 41/200 | Train Loss: 1.1640, Train Acc: 71.56% | Val Loss: 1.2493, Val Acc: 67.53% | Sparsity: 0.16
# Epoch: 42/200 | Train Loss: 1.1624, Train Acc: 71.37% | Val Loss: 1.2130, Val Acc: 68.77% | Sparsity: 0.16
# Epoch: 43/200 | Train Loss: 1.1504, Train Acc: 71.80% | Val Loss: 1.2108, Val Acc: 69.88% | Sparsity: 0.17
# Epoch: 44/200 | Train Loss: 1.1453, Train Acc: 72.24% | Val Loss: 1.1951, Val Acc: 70.60% | Sparsity: 0.17
# Epoch: 45/200 | Train Loss: 1.1390, Train Acc: 72.55% | Val Loss: 1.1966, Val Acc: 69.75% | Sparsity: 0.18
# Epoch: 46/200 | Train Loss: 1.1350, Train Acc: 72.70% | Val Loss: 1.1813, Val Acc: 70.15% | Sparsity: 0.18
# Epoch: 47/200 | Train Loss: 1.1285, Train Acc: 73.03% | Val Loss: 1.1940, Val Acc: 70.40% | Sparsity: 0.18
# Epoch: 48/200 | Train Loss: 1.1237, Train Acc: 73.45% | Val Loss: 1.1946, Val Acc: 69.93% | Sparsity: 0.19
# Epoch: 49/200 | Train Loss: 1.1147, Train Acc: 73.68% | Val Loss: 1.1707, Val Acc: 70.57% | Sparsity: 0.19
# Epoch: 50/200 | Train Loss: 1.1097, Train Acc: 73.83% | Val Loss: 1.1548, Val Acc: 71.53% | Sparsity: 0.20
# Epoch: 51/200 | Train Loss: 1.1042, Train Acc: 74.32% | Val Loss: 1.1598, Val Acc: 71.85% | Sparsity: 0.20
# Epoch: 52/200 | Train Loss: 1.0987, Train Acc: 74.43% | Val Loss: 1.1576, Val Acc: 71.75% | Sparsity: 0.20
# Epoch: 53/200 | Train Loss: 1.0936, Train Acc: 74.63% | Val Loss: 1.1769, Val Acc: 70.62% | Sparsity: 0.21
# Epoch: 54/200 | Train Loss: 1.0908, Train Acc: 74.93% | Val Loss: 1.1647, Val Acc: 71.65% | Sparsity: 0.21
# Epoch: 55/200 | Train Loss: 1.0851, Train Acc: 75.16% | Val Loss: 1.1481, Val Acc: 72.90% | Sparsity: 0.22
# Epoch: 56/200 | Train Loss: 1.0818, Train Acc: 75.39% | Val Loss: 1.1576, Val Acc: 71.53% | Sparsity: 0.22
# Epoch: 57/200 | Train Loss: 1.0793, Train Acc: 75.44% | Val Loss: 1.1353, Val Acc: 73.07% | Sparsity: 0.22
# Epoch: 58/200 | Train Loss: 1.0747, Train Acc: 75.58% | Val Loss: 1.1356, Val Acc: 72.67% | Sparsity: 0.23
# Epoch: 59/200 | Train Loss: 1.0689, Train Acc: 76.04% | Val Loss: 1.1359, Val Acc: 72.83% | Sparsity: 0.23
# Epoch: 60/200 | Train Loss: 1.0657, Train Acc: 76.08% | Val Loss: 1.1174, Val Acc: 73.78% | Sparsity: 0.24
# Epoch: 61/200 | Train Loss: 1.0609, Train Acc: 76.12% | Val Loss: 1.1157, Val Acc: 73.42% | Sparsity: 0.24
# Epoch: 62/200 | Train Loss: 1.0554, Train Acc: 76.39% | Val Loss: 1.1211, Val Acc: 73.40% | Sparsity: 0.24
# Epoch: 63/200 | Train Loss: 1.0535, Train Acc: 76.53% | Val Loss: 1.1201, Val Acc: 73.35% | Sparsity: 0.25
# Epoch: 64/200 | Train Loss: 1.0475, Train Acc: 76.91% | Val Loss: 1.1078, Val Acc: 74.43% | Sparsity: 0.25
# Epoch: 65/200 | Train Loss: 1.0481, Train Acc: 76.83% | Val Loss: 1.1104, Val Acc: 73.48% | Sparsity: 0.26
# Epoch: 66/200 | Train Loss: 1.0438, Train Acc: 77.03% | Val Loss: 1.1070, Val Acc: 74.33% | Sparsity: 0.26
# Epoch: 67/200 | Train Loss: 1.0375, Train Acc: 77.40% | Val Loss: 1.1104, Val Acc: 74.62% | Sparsity: 0.26
# Epoch: 68/200 | Train Loss: 1.0325, Train Acc: 77.42% | Val Loss: 1.1046, Val Acc: 74.10% | Sparsity: 0.27
# Epoch: 69/200 | Train Loss: 1.0328, Train Acc: 77.71% | Val Loss: 1.0843, Val Acc: 75.27% | Sparsity: 0.27
# Epoch: 70/200 | Train Loss: 1.0264, Train Acc: 77.91% | Val Loss: 1.0880, Val Acc: 74.97% | Sparsity: 0.28
# Epoch: 71/200 | Train Loss: 1.0231, Train Acc: 77.90% | Val Loss: 1.0825, Val Acc: 75.43% | Sparsity: 0.28
# Epoch: 72/200 | Train Loss: 1.0183, Train Acc: 78.41% | Val Loss: 1.0935, Val Acc: 74.58% | Sparsity: 0.28
# Epoch: 73/200 | Train Loss: 1.0174, Train Acc: 78.37% | Val Loss: 1.0899, Val Acc: 74.37% | Sparsity: 0.29
# Epoch: 74/200 | Train Loss: 1.0129, Train Acc: 78.55% | Val Loss: 1.1359, Val Acc: 73.58% | Sparsity: 0.29
# Epoch: 75/200 | Train Loss: 1.0078, Train Acc: 78.62% | Val Loss: 1.0915, Val Acc: 75.40% | Sparsity: 0.30
# Epoch: 76/200 | Train Loss: 1.0107, Train Acc: 78.71% | Val Loss: 1.0818, Val Acc: 74.68% | Sparsity: 0.30
# Epoch: 77/200 | Train Loss: 1.0040, Train Acc: 78.88% | Val Loss: 1.0754, Val Acc: 75.32% | Sparsity: 0.30
# Epoch: 78/200 | Train Loss: 1.0037, Train Acc: 78.92% | Val Loss: 1.0723, Val Acc: 75.82% | Sparsity: 0.31
# Epoch: 79/200 | Train Loss: 0.9996, Train Acc: 79.11% | Val Loss: 1.0737, Val Acc: 75.68% | Sparsity: 0.31
# Epoch: 80/200 | Train Loss: 0.9994, Train Acc: 78.91% | Val Loss: 1.0647, Val Acc: 75.93% | Sparsity: 0.32
# Epoch: 81/200 | Train Loss: 0.9936, Train Acc: 79.58% | Val Loss: 1.0657, Val Acc: 76.43% | Sparsity: 0.32
# Epoch: 82/200 | Train Loss: 0.9914, Train Acc: 79.56% | Val Loss: 1.0698, Val Acc: 76.05% | Sparsity: 0.32
# Epoch: 83/200 | Train Loss: 0.9888, Train Acc: 79.52% | Val Loss: 1.0624, Val Acc: 76.47% | Sparsity: 0.33
# Epoch: 84/200 | Train Loss: 0.9852, Train Acc: 80.00% | Val Loss: 1.0597, Val Acc: 76.40% | Sparsity: 0.33
# Epoch: 85/200 | Train Loss: 0.9842, Train Acc: 79.86% | Val Loss: 1.0534, Val Acc: 76.72% | Sparsity: 0.34
# Epoch: 86/200 | Train Loss: 0.9856, Train Acc: 79.60% | Val Loss: 1.0506, Val Acc: 77.32% | Sparsity: 0.34
# Epoch: 87/200 | Train Loss: 0.9808, Train Acc: 80.15% | Val Loss: 1.0537, Val Acc: 76.58% | Sparsity: 0.34
# Epoch: 88/200 | Train Loss: 0.9761, Train Acc: 80.31% | Val Loss: 1.0594, Val Acc: 76.15% | Sparsity: 0.35
# Epoch: 89/200 | Train Loss: 0.9720, Train Acc: 80.39% | Val Loss: 1.0495, Val Acc: 77.17% | Sparsity: 0.35
# Epoch: 90/200 | Train Loss: 0.9724, Train Acc: 80.55% | Val Loss: 1.0527, Val Acc: 76.55% | Sparsity: 0.36
# Epoch: 91/200 | Train Loss: 0.9722, Train Acc: 80.33% | Val Loss: 1.0506, Val Acc: 76.47% | Sparsity: 0.36
# Epoch: 92/200 | Train Loss: 0.9696, Train Acc: 80.43% | Val Loss: 1.0534, Val Acc: 76.65% | Sparsity: 0.36
# Epoch: 93/200 | Train Loss: 0.9691, Train Acc: 80.59% | Val Loss: 1.0429, Val Acc: 76.62% | Sparsity: 0.37
# Epoch: 94/200 | Train Loss: 0.9644, Train Acc: 80.92% | Val Loss: 1.0496, Val Acc: 77.07% | Sparsity: 0.37
# Epoch: 95/200 | Train Loss: 0.9633, Train Acc: 81.10% | Val Loss: 1.0491, Val Acc: 76.48% | Sparsity: 0.38
# Epoch: 96/200 | Train Loss: 0.9613, Train Acc: 81.13% | Val Loss: 1.0338, Val Acc: 77.70% | Sparsity: 0.38
# Epoch: 97/200 | Train Loss: 0.9591, Train Acc: 81.02% | Val Loss: 1.0405, Val Acc: 76.57% | Sparsity: 0.38
# Epoch: 98/200 | Train Loss: 0.9584, Train Acc: 81.00% | Val Loss: 1.0339, Val Acc: 77.80% | Sparsity: 0.39
# Epoch: 99/200 | Train Loss: 0.9590, Train Acc: 81.11% | Val Loss: 1.0432, Val Acc: 76.88% | Sparsity: 0.39
# Epoch: 100/200 | Train Loss: 0.9522, Train Acc: 81.51% | Val Loss: 1.0287, Val Acc: 77.78% | Sparsity: 0.40
# Epoch: 101/200 | Train Loss: 0.9512, Train Acc: 81.41% | Val Loss: 1.0208, Val Acc: 77.98% | Sparsity: 0.40
# Epoch: 102/200 | Train Loss: 0.9521, Train Acc: 81.52% | Val Loss: 1.0333, Val Acc: 77.70% | Sparsity: 0.40
# Epoch: 103/200 | Train Loss: 0.9499, Train Acc: 81.56% | Val Loss: 1.0293, Val Acc: 77.78% | Sparsity: 0.41
# Epoch: 104/200 | Train Loss: 0.9444, Train Acc: 81.64% | Val Loss: 1.0156, Val Acc: 78.10% | Sparsity: 0.41
# Epoch: 105/200 | Train Loss: 0.9466, Train Acc: 81.54% | Val Loss: 1.0165, Val Acc: 78.33% | Sparsity: 0.42
# Epoch: 106/200 | Train Loss: 0.9454, Train Acc: 81.59% | Val Loss: 1.0146, Val Acc: 78.60% | Sparsity: 0.42
# Epoch: 107/200 | Train Loss: 0.9400, Train Acc: 81.97% | Val Loss: 1.0205, Val Acc: 78.45% | Sparsity: 0.42
# Epoch: 108/200 | Train Loss: 0.9359, Train Acc: 82.08% | Val Loss: 1.0232, Val Acc: 78.43% | Sparsity: 0.43
# Epoch: 109/200 | Train Loss: 0.9375, Train Acc: 82.06% | Val Loss: 1.0096, Val Acc: 78.63% | Sparsity: 0.43
# Epoch: 110/200 | Train Loss: 0.9394, Train Acc: 82.11% | Val Loss: 1.0192, Val Acc: 78.35% | Sparsity: 0.44
# Epoch: 111/200 | Train Loss: 0.9363, Train Acc: 82.10% | Val Loss: 1.0209, Val Acc: 78.42% | Sparsity: 0.44
# Epoch: 112/200 | Train Loss: 0.9338, Train Acc: 82.31% | Val Loss: 1.0193, Val Acc: 77.93% | Sparsity: 0.44
# Epoch: 113/200 | Train Loss: 0.9370, Train Acc: 82.06% | Val Loss: 1.0175, Val Acc: 78.12% | Sparsity: 0.45
# Epoch: 114/200 | Train Loss: 0.9348, Train Acc: 82.36% | Val Loss: 1.0186, Val Acc: 78.28% | Sparsity: 0.45
# Epoch: 115/200 | Train Loss: 0.9306, Train Acc: 82.57% | Val Loss: 1.0198, Val Acc: 78.00% | Sparsity: 0.46
# Epoch: 116/200 | Train Loss: 0.9286, Train Acc: 82.49% | Val Loss: 1.0197, Val Acc: 78.32% | Sparsity: 0.46
# Epoch: 117/200 | Train Loss: 0.9238, Train Acc: 82.69% | Val Loss: 1.0185, Val Acc: 78.67% | Sparsity: 0.46
# Epoch: 118/200 | Train Loss: 0.9232, Train Acc: 82.84% | Val Loss: 1.0142, Val Acc: 78.03% | Sparsity: 0.47
# Epoch: 119/200 | Train Loss: 0.9256, Train Acc: 82.50% | Val Loss: 1.0168, Val Acc: 78.27% | Sparsity: 0.47
# Epoch: 120/200 | Train Loss: 0.9272, Train Acc: 82.60% | Val Loss: 1.0101, Val Acc: 78.77% | Sparsity: 0.48
# Epoch: 121/200 | Train Loss: 0.9196, Train Acc: 82.92% | Val Loss: 1.0026, Val Acc: 78.98% | Sparsity: 0.48
# Epoch: 122/200 | Train Loss: 0.9244, Train Acc: 82.62% | Val Loss: 1.0053, Val Acc: 78.82% | Sparsity: 0.48
# Epoch: 123/200 | Train Loss: 0.9182, Train Acc: 82.99% | Val Loss: 0.9983, Val Acc: 79.28% | Sparsity: 0.49
# Epoch: 124/200 | Train Loss: 0.9196, Train Acc: 82.67% | Val Loss: 1.0081, Val Acc: 78.63% | Sparsity: 0.49
# Epoch: 125/200 | Train Loss: 0.9186, Train Acc: 82.92% | Val Loss: 1.0059, Val Acc: 78.75% | Sparsity: 0.50
# Epoch: 126/200 | Train Loss: 0.9206, Train Acc: 82.88% | Val Loss: 1.0025, Val Acc: 78.60% | Sparsity: 0.50
# Epoch: 127/200 | Train Loss: 0.9195, Train Acc: 82.82% | Val Loss: 0.9910, Val Acc: 79.07% | Sparsity: 0.50
# Epoch: 128/200 | Train Loss: 0.9134, Train Acc: 83.20% | Val Loss: 0.9997, Val Acc: 79.18% | Sparsity: 0.51
# Epoch: 129/200 | Train Loss: 0.9145, Train Acc: 83.04% | Val Loss: 1.0043, Val Acc: 78.70% | Sparsity: 0.51
# Epoch: 130/200 | Train Loss: 0.9143, Train Acc: 83.05% | Val Loss: 0.9954, Val Acc: 79.52% | Sparsity: 0.52
# Epoch: 131/200 | Train Loss: 0.9126, Train Acc: 83.26% | Val Loss: 1.0031, Val Acc: 79.03% | Sparsity: 0.52
# Epoch: 132/200 | Train Loss: 0.9099, Train Acc: 83.36% | Val Loss: 0.9919, Val Acc: 79.45% | Sparsity: 0.52
# Epoch: 133/200 | Train Loss: 0.9125, Train Acc: 83.13% | Val Loss: 0.9895, Val Acc: 79.55% | Sparsity: 0.53
# Epoch: 134/200 | Train Loss: 0.9088, Train Acc: 83.44% | Val Loss: 1.0047, Val Acc: 78.82% | Sparsity: 0.53
# Epoch: 135/200 | Train Loss: 0.9079, Train Acc: 83.52% | Val Loss: 1.0044, Val Acc: 79.22% | Sparsity: 0.54
# Epoch: 136/200 | Train Loss: 0.9061, Train Acc: 83.46% | Val Loss: 0.9889, Val Acc: 79.85% | Sparsity: 0.54
# Epoch: 137/200 | Train Loss: 0.9111, Train Acc: 83.23% | Val Loss: 0.9965, Val Acc: 78.72% | Sparsity: 0.54
# Epoch: 138/200 | Train Loss: 0.9088, Train Acc: 83.40% | Val Loss: 0.9969, Val Acc: 79.33% | Sparsity: 0.55
# Epoch: 139/200 | Train Loss: 0.9063, Train Acc: 83.64% | Val Loss: 0.9899, Val Acc: 78.93% | Sparsity: 0.55
# Epoch: 140/200 | Train Loss: 0.9060, Train Acc: 83.34% | Val Loss: 1.0000, Val Acc: 79.30% | Sparsity: 0.56
# Epoch: 141/200 | Train Loss: 0.9039, Train Acc: 83.77% | Val Loss: 0.9880, Val Acc: 79.62% | Sparsity: 0.56
# Epoch: 142/200 | Train Loss: 0.9017, Train Acc: 83.62% | Val Loss: 0.9893, Val Acc: 79.40% | Sparsity: 0.56
# Epoch: 143/200 | Train Loss: 0.9063, Train Acc: 83.53% | Val Loss: 0.9932, Val Acc: 79.12% | Sparsity: 0.57
# Epoch: 144/200 | Train Loss: 0.9049, Train Acc: 83.36% | Val Loss: 0.9965, Val Acc: 79.00% | Sparsity: 0.57
# Epoch: 145/200 | Train Loss: 0.9025, Train Acc: 83.87% | Val Loss: 0.9989, Val Acc: 79.27% | Sparsity: 0.58
# Epoch: 146/200 | Train Loss: 0.9036, Train Acc: 83.71% | Val Loss: 1.0036, Val Acc: 79.13% | Sparsity: 0.58
# Epoch: 147/200 | Train Loss: 0.8996, Train Acc: 83.89% | Val Loss: 0.9955, Val Acc: 79.25% | Sparsity: 0.58
# Epoch: 148/200 | Train Loss: 0.8992, Train Acc: 83.92% | Val Loss: 1.0000, Val Acc: 78.87% | Sparsity: 0.59
# Epoch: 149/200 | Train Loss: 0.9027, Train Acc: 83.80% | Val Loss: 0.9933, Val Acc: 78.85% | Sparsity: 0.59
# Epoch: 150/200 | Train Loss: 0.9005, Train Acc: 83.67% | Val Loss: 0.9898, Val Acc: 79.55% | Sparsity: 0.60
# Epoch: 151/200 | Train Loss: 0.9007, Train Acc: 83.72% | Val Loss: 0.9890, Val Acc: 79.43% | Sparsity: 0.60
# Epoch: 152/200 | Train Loss: 0.8995, Train Acc: 83.98% | Val Loss: 0.9919, Val Acc: 79.02% | Sparsity: 0.60
# Epoch: 153/200 | Train Loss: 0.9002, Train Acc: 83.83% | Val Loss: 0.9823, Val Acc: 79.78% | Sparsity: 0.61
# Epoch: 154/200 | Train Loss: 0.8994, Train Acc: 83.94% | Val Loss: 0.9827, Val Acc: 80.35% | Sparsity: 0.61
# Epoch: 155/200 | Train Loss: 0.8955, Train Acc: 83.99% | Val Loss: 0.9766, Val Acc: 80.67% | Sparsity: 0.62
# Epoch: 156/200 | Train Loss: 0.8976, Train Acc: 84.05% | Val Loss: 0.9797, Val Acc: 79.80% | Sparsity: 0.62
# Epoch: 157/200 | Train Loss: 0.8939, Train Acc: 84.21% | Val Loss: 0.9881, Val Acc: 79.48% | Sparsity: 0.62
# Epoch: 158/200 | Train Loss: 0.8967, Train Acc: 83.94% | Val Loss: 0.9802, Val Acc: 79.53% | Sparsity: 0.63
# Epoch: 159/200 | Train Loss: 0.8947, Train Acc: 84.10% | Val Loss: 0.9842, Val Acc: 79.95% | Sparsity: 0.63
# Epoch: 160/200 | Train Loss: 0.8957, Train Acc: 83.99% | Val Loss: 0.9870, Val Acc: 79.70% | Sparsity: 0.64
# Epoch: 161/200 | Train Loss: 0.8954, Train Acc: 83.96% | Val Loss: 0.9973, Val Acc: 78.83% | Sparsity: 0.64
# Epoch: 162/200 | Train Loss: 0.8955, Train Acc: 83.99% | Val Loss: 0.9863, Val Acc: 79.27% | Sparsity: 0.64
# Epoch: 163/200 | Train Loss: 0.8974, Train Acc: 83.90% | Val Loss: 0.9851, Val Acc: 79.35% | Sparsity: 0.65
# Epoch: 164/200 | Train Loss: 0.8948, Train Acc: 84.09% | Val Loss: 0.9945, Val Acc: 78.95% | Sparsity: 0.65
# Epoch: 165/200 | Train Loss: 0.8955, Train Acc: 84.07% | Val Loss: 0.9879, Val Acc: 79.57% | Sparsity: 0.66
# Epoch: 166/200 | Train Loss: 0.8939, Train Acc: 83.97% | Val Loss: 0.9883, Val Acc: 79.72% | Sparsity: 0.66
# Epoch: 167/200 | Train Loss: 0.8923, Train Acc: 84.24% | Val Loss: 0.9786, Val Acc: 79.55% | Sparsity: 0.66
# Epoch: 168/200 | Train Loss: 0.8958, Train Acc: 83.94% | Val Loss: 0.9762, Val Acc: 80.35% | Sparsity: 0.67
# Epoch: 169/200 | Train Loss: 0.8926, Train Acc: 84.05% | Val Loss: 0.9857, Val Acc: 79.85% | Sparsity: 0.67
# Epoch: 170/200 | Train Loss: 0.8940, Train Acc: 84.07% | Val Loss: 0.9901, Val Acc: 79.85% | Sparsity: 0.68
# Epoch: 171/200 | Train Loss: 0.8918, Train Acc: 84.23% | Val Loss: 0.9821, Val Acc: 79.65% | Sparsity: 0.68
# Epoch: 172/200 | Train Loss: 0.8914, Train Acc: 84.22% | Val Loss: 0.9843, Val Acc: 79.90% | Sparsity: 0.68
# Epoch: 173/200 | Train Loss: 0.8928, Train Acc: 84.24% | Val Loss: 0.9853, Val Acc: 79.53% | Sparsity: 0.69
# Epoch: 174/200 | Train Loss: 0.8937, Train Acc: 84.11% | Val Loss: 0.9735, Val Acc: 80.43% | Sparsity: 0.69
# Epoch: 175/200 | Train Loss: 0.8897, Train Acc: 84.35% | Val Loss: 0.9828, Val Acc: 79.97% | Sparsity: 0.70
# Epoch: 176/200 | Train Loss: 0.8934, Train Acc: 84.09% | Val Loss: 0.9867, Val Acc: 79.33% | Sparsity: 0.70
# Epoch: 177/200 | Train Loss: 0.8906, Train Acc: 84.33% | Val Loss: 0.9842, Val Acc: 80.12% | Sparsity: 0.70
# Epoch: 178/200 | Train Loss: 0.8928, Train Acc: 84.06% | Val Loss: 0.9827, Val Acc: 79.85% | Sparsity: 0.71
# Epoch: 179/200 | Train Loss: 0.8903, Train Acc: 84.19% | Val Loss: 0.9782, Val Acc: 80.38% | Sparsity: 0.71
# Epoch: 180/200 | Train Loss: 0.8915, Train Acc: 84.41% | Val Loss: 0.9843, Val Acc: 80.32% | Sparsity: 0.72
# Epoch: 181/200 | Train Loss: 0.8928, Train Acc: 84.20% | Val Loss: 0.9798, Val Acc: 79.67% | Sparsity: 0.72
# Epoch: 182/200 | Train Loss: 0.8933, Train Acc: 84.05% | Val Loss: 0.9811, Val Acc: 79.67% | Sparsity: 0.72
# Epoch: 183/200 | Train Loss: 0.8901, Train Acc: 84.11% | Val Loss: 0.9844, Val Acc: 79.55% | Sparsity: 0.73
# Epoch: 184/200 | Train Loss: 0.8915, Train Acc: 84.25% | Val Loss: 0.9785, Val Acc: 79.93% | Sparsity: 0.73
# Epoch: 185/200 | Train Loss: 0.8900, Train Acc: 84.42% | Val Loss: 0.9832, Val Acc: 79.83% | Sparsity: 0.74
# Epoch: 186/200 | Train Loss: 0.8915, Train Acc: 84.14% | Val Loss: 0.9816, Val Acc: 79.90% | Sparsity: 0.74
# Epoch: 187/200 | Train Loss: 0.8886, Train Acc: 84.41% | Val Loss: 0.9838, Val Acc: 79.62% | Sparsity: 0.74
# Epoch: 188/200 | Train Loss: 0.8906, Train Acc: 84.19% | Val Loss: 0.9787, Val Acc: 80.02% | Sparsity: 0.75
# Epoch: 189/200 | Train Loss: 0.8912, Train Acc: 84.25% | Val Loss: 0.9917, Val Acc: 79.62% | Sparsity: 0.75
# Epoch: 190/200 | Train Loss: 0.8902, Train Acc: 84.18% | Val Loss: 0.9786, Val Acc: 80.15% | Sparsity: 0.76
# Epoch: 191/200 | Train Loss: 0.8912, Train Acc: 84.31% | Val Loss: 0.9812, Val Acc: 80.00% | Sparsity: 0.76
# Epoch: 192/200 | Train Loss: 0.8925, Train Acc: 84.10% | Val Loss: 0.9857, Val Acc: 79.33% | Sparsity: 0.76
# Epoch: 193/200 | Train Loss: 0.8930, Train Acc: 84.15% | Val Loss: 0.9792, Val Acc: 80.03% | Sparsity: 0.77
# Epoch: 194/200 | Train Loss: 0.8917, Train Acc: 84.33% | Val Loss: 0.9906, Val Acc: 79.50% | Sparsity: 0.77
# Epoch: 195/200 | Train Loss: 0.8920, Train Acc: 84.23% | Val Loss: 0.9843, Val Acc: 79.88% | Sparsity: 0.78
# Epoch: 196/200 | Train Loss: 0.8903, Train Acc: 84.28% | Val Loss: 0.9850, Val Acc: 79.23% | Sparsity: 0.78
# Epoch: 197/200 | Train Loss: 0.8945, Train Acc: 84.10% | Val Loss: 0.9819, Val Acc: 79.95% | Sparsity: 0.78
# Epoch: 198/200 | Train Loss: 0.8892, Train Acc: 84.20% | Val Loss: 0.9844, Val Acc: 79.73% | Sparsity: 0.79
# Epoch: 199/200 | Train Loss: 0.8889, Train Acc: 84.40% | Val Loss: 0.9806, Val Acc: 79.72% | Sparsity: 0.79
# Epoch: 200/200 | Train Loss: 0.8880, Train Acc: 84.42% | Val Loss: 0.9876, Val Acc: 79.70% | Sparsity: 0.80
# Final Results:
# Final Training Loss: 0.8880
# Final Validation Loss: 0.9876
# Final Training Accuracy: 84.42%
# Final Validation Accuracy: 79.70%
# Final Test Loss: 0.9712
# Final Test Accuracy: 79.63%
