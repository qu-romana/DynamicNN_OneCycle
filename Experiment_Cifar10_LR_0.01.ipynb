# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms

# Define the basic block for ResNet
class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_channels, out_channels, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(
            in_channels, out_channels, kernel_size=3, stride=stride, padding=1, bias=False
        )
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.conv2 = nn.Conv2d(
            out_channels, out_channels, kernel_size=3, stride=1, padding=1, bias=False
        )
        self.bn2 = nn.BatchNorm2d(out_channels)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_channels != out_channels:
            self.shortcut = nn.Sequential(
                nn.Conv2d(
                    in_channels, out_channels, kernel_size=1, stride=stride, bias=False
                ),
                nn.BatchNorm2d(out_channels),
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out

# Define ResNet
class DynamicSparseResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):  # For CIFAR-10, num_classes=10
        super(DynamicSparseResNet, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(
            3, 64, kernel_size=3, stride=1, padding=1, bias=False  # CIFAR-10 images have 3 channels
        )
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.linear = nn.Linear(512 * block.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        layers = []
        strides = [stride] + [1] * (num_blocks - 1)
        for s in strides:
            layers.append(block(self.in_planes, planes, s))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))  # Output size: 32x32
        out = self.layer1(out)                 # Output size: 32x32
        out = self.layer2(out)                 # Output size: 16x16
        out = self.layer3(out)                 # Output size: 8x8
        out = self.layer4(out)                 # Output size: 4x4
        out = F.avg_pool2d(out, 4)             # Output size: 1x1
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out

def ResNet18(num_classes=10):
    return DynamicSparseResNet(BasicBlock, [2, 2, 2, 2], num_classes=num_classes)

def initialize_weights(model):
    for m in model.modules():
        if isinstance(m, (nn.Conv2d, nn.Linear)):
            nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
            if m.bias is not None:
                nn.init.zeros_(m.bias)
        elif isinstance(m, nn.BatchNorm2d):
            nn.init.ones_(m.weight)
            nn.init.zeros_(m.bias)

def apply_dynamic_supermask(model, sparsity_rate):
    masks = {}
    for name, param in model.named_parameters():
        if 'weight' in name:
            weight_flat = param.data.abs().flatten()
            k = int(weight_flat.shape[0] * (1 - sparsity_rate))
            if k == 0:
                threshold = torch.max(weight_flat) + 1
            else:
                threshold = torch.topk(weight_flat, k, largest=True, sorted=True)[0][-1]
            mask = (param.data.abs() >= threshold).float()
            masks[name] = mask.view(param.size()).to(param.device)
    return masks

def dynamic_weight_update(model, masks):
    for name, param in model.named_parameters():
        if 'weight' in name and param.grad is not None:
            mask = masks[name]
            param.grad.data.mul_(mask)

def train_with_dynamic_pruning(model, train_loader, val_loader, epochs=200, device='cuda'):
    criterion = nn.CrossEntropyLoss(label_smoothing=0.1)
    optimizer = torch.optim.SGD(
        model.parameters(), lr=0.01, momentum=0.9, weight_decay=5e-4
    )
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=epochs)

    initial_sparsity = 0.0
    final_sparsity = 0.8
    sparsity_increment = (final_sparsity - initial_sparsity) / epochs

    train_losses = []
    val_losses = []
    train_acc = []
    val_acc = []

    initialize_weights(model)

    for epoch in range(epochs):
        model.train()
        running_loss = 0
        correct = 0
        total = 0

        current_sparsity = initial_sparsity + sparsity_increment * epoch
        masks = apply_dynamic_supermask(model, current_sparsity)

        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()

            dynamic_weight_update(model, masks)
            optimizer.step()

            running_loss += loss.item() * images.size(0)
            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()

        train_loss = running_loss / total
        train_accuracy = 100.0 * correct / total

        # Validation
        val_loss, val_accuracy = evaluate(model, val_loader, criterion, device)

        train_losses.append(train_loss)
        val_losses.append(val_loss)
        train_acc.append(train_accuracy)
        val_acc.append(val_accuracy)

        scheduler.step()

        print(
            f"Epoch: {epoch+1}/{epochs}"
            f" | Train Loss: {train_loss:.4f}, Train Acc: {train_accuracy:.2f}%"
            f" | Val Loss: {val_loss:.4f}, Val Acc: {val_accuracy:.2f}%"
            f" | Sparsity: {current_sparsity:.2f}"
        )

    return train_losses, val_losses, train_acc, val_acc

def evaluate(model, data_loader, criterion, device):
    model.eval()
    loss_total = 0
    correct = 0
    total = 0

    with torch.no_grad():
        for images, labels in data_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)

            loss_total += loss.item() * images.size(0)
            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()

    avg_loss = loss_total / total
    accuracy = 100.0 * correct / total
    return avg_loss, accuracy

def main():
    torch.manual_seed(42)

    # Data augmentation for CIFAR-10
    transform = transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(15),
        transforms.ColorJitter(
            brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1
        ),
        transforms.ToTensor(),
        transforms.RandomErasing(),
        transforms.Normalize(
            (0.4914, 0.4822, 0.4465),
            (0.2470, 0.2435, 0.2616)
        ),
    ])

    # Load the full CIFAR-10 dataset (both train and test sets)
    train_dataset = torchvision.datasets.CIFAR10(
        root='./data', train=True, download=True, transform=transform
    )
    test_dataset = torchvision.datasets.CIFAR10(
        root='./data', train=False, download=True, transform=transform
    )

    # Combine train and test datasets
    full_dataset = torch.utils.data.ConcatDataset([train_dataset, test_dataset])

    # Calculate sizes for splits
    total_size = len(full_dataset)
    train_size = int(0.8 * total_size)
    val_size = int(0.1 * total_size)
    test_size = total_size - train_size - val_size

    # Split the dataset
    train_dataset, val_dataset, test_dataset = torch.utils.data.random_split(
        full_dataset, [train_size, val_size, test_size]
    )

    # Set up DataLoader for training, validation, and testing data
    batch_size = 32
    train_loader = torch.utils.data.DataLoader(
        train_dataset,
        batch_size=batch_size,
        shuffle=True,
        num_workers=4,
        pin_memory=True,
    )
    val_loader = torch.utils.data.DataLoader(
        val_dataset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=4,
        pin_memory=True,
    )
    test_loader = torch.utils.data.DataLoader(
        test_dataset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=4,
        pin_memory=True,
    )

    # Set device to GPU if available
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model = ResNet18(num_classes=10).to(device)

    # Train and validate the model with dynamic pruning
    train_losses, val_losses, train_acc, val_acc = train_with_dynamic_pruning(
        model, train_loader, val_loader, epochs=200, device=device
    )

    # Plot training results
    import matplotlib.pyplot as plt
    plt.figure(figsize=(12, 4))

    plt.subplot(1, 2, 1)
    plt.plot(train_losses, label='Train Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.title('CIFAR-10 Training and Validation Loss')

    plt.subplot(1, 2, 2)
    plt.plot(train_acc, label='Train Accuracy')
    plt.plot(val_acc, label='Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy (%)')
    plt.legend()
    plt.title('CIFAR-10 Training and Validation Accuracy')

    plt.tight_layout()
    plt.show()

    # Evaluate on the test set
    criterion = nn.CrossEntropyLoss(label_smoothing=0.1)
    test_loss, test_accuracy = evaluate(model, test_loader, criterion, device)

    # Print final metrics
    print("\nFinal Results:")
    print(f"Final Training Loss: {train_losses[-1]:.4f}")
    print(f"Final Validation Loss: {val_losses[-1]:.4f}")
    print(f"Final Training Accuracy: {train_acc[-1]:.2f}%")
    print(f"Final Validation Accuracy: {val_acc[-1]:.2f}%")
    print(f"Final Test Loss: {test_loss:.4f}")
    print(f"Final Test Accuracy: {test_accuracy:.2f}%")

if __name__ == "__main__":
    main()
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170M/170M [00:12<00:00, 13.2MB/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
# Epoch: 1/200 | Train Loss: 2.3670, Train Acc: 28.62% | Val Loss: 1.8934, Val Acc: 38.70% | Sparsity: 0.00
# Epoch: 2/200 | Train Loss: 1.8200, Train Acc: 40.76% | Val Loss: 1.6800, Val Acc: 47.80% | Sparsity: 0.00
# Epoch: 3/200 | Train Loss: 1.6193, Train Acc: 49.36% | Val Loss: 1.6727, Val Acc: 47.62% | Sparsity: 0.01
# Epoch: 4/200 | Train Loss: 1.4639, Train Acc: 56.91% | Val Loss: 1.4872, Val Acc: 56.48% | Sparsity: 0.01
# Epoch: 5/200 | Train Loss: 1.3498, Train Acc: 62.66% | Val Loss: 1.3515, Val Acc: 63.17% | Sparsity: 0.02
# Epoch: 6/200 | Train Loss: 1.2685, Train Acc: 66.42% | Val Loss: 1.3580, Val Acc: 63.40% | Sparsity: 0.02
# Epoch: 7/200 | Train Loss: 1.2075, Train Acc: 69.33% | Val Loss: 1.2095, Val Acc: 69.82% | Sparsity: 0.02
# Epoch: 8/200 | Train Loss: 1.1483, Train Acc: 72.04% | Val Loss: 1.1898, Val Acc: 70.73% | Sparsity: 0.03
# Epoch: 9/200 | Train Loss: 1.1142, Train Acc: 73.56% | Val Loss: 1.1276, Val Acc: 73.30% | Sparsity: 0.03
# Epoch: 10/200 | Train Loss: 1.0767, Train Acc: 75.21% | Val Loss: 1.0935, Val Acc: 74.68% | Sparsity: 0.04
# Epoch: 11/200 | Train Loss: 1.0482, Train Acc: 76.42% | Val Loss: 1.1506, Val Acc: 71.58% | Sparsity: 0.04
# Epoch: 12/200 | Train Loss: 1.0212, Train Acc: 77.59% | Val Loss: 1.0394, Val Acc: 76.12% | Sparsity: 0.04
# Epoch: 13/200 | Train Loss: 1.0034, Train Acc: 78.30% | Val Loss: 1.0493, Val Acc: 75.33% | Sparsity: 0.05
# Epoch: 14/200 | Train Loss: 0.9900, Train Acc: 78.58% | Val Loss: 1.0098, Val Acc: 77.62% | Sparsity: 0.05
# Epoch: 15/200 | Train Loss: 0.9732, Train Acc: 79.53% | Val Loss: 0.9963, Val Acc: 78.15% | Sparsity: 0.06
# Epoch: 16/200 | Train Loss: 0.9590, Train Acc: 79.85% | Val Loss: 1.0078, Val Acc: 78.17% | Sparsity: 0.06
# Epoch: 17/200 | Train Loss: 0.9502, Train Acc: 80.37% | Val Loss: 0.9715, Val Acc: 79.57% | Sparsity: 0.06
# Epoch: 18/200 | Train Loss: 0.9395, Train Acc: 80.71% | Val Loss: 0.9465, Val Acc: 80.80% | Sparsity: 0.07
# Epoch: 19/200 | Train Loss: 0.9323, Train Acc: 81.24% | Val Loss: 1.0040, Val Acc: 78.18% | Sparsity: 0.07
# Epoch: 20/200 | Train Loss: 0.9225, Train Acc: 81.65% | Val Loss: 0.9629, Val Acc: 79.65% | Sparsity: 0.08
# Epoch: 21/200 | Train Loss: 0.9209, Train Acc: 81.79% | Val Loss: 0.9866, Val Acc: 78.30% | Sparsity: 0.08
# Epoch: 22/200 | Train Loss: 0.9102, Train Acc: 82.20% | Val Loss: 0.9408, Val Acc: 80.47% | Sparsity: 0.08
# Epoch: 23/200 | Train Loss: 0.9085, Train Acc: 82.34% | Val Loss: 0.9545, Val Acc: 80.08% | Sparsity: 0.09
# Epoch: 24/200 | Train Loss: 0.9017, Train Acc: 82.46% | Val Loss: 0.9382, Val Acc: 80.48% | Sparsity: 0.09
# Epoch: 25/200 | Train Loss: 0.8983, Train Acc: 82.58% | Val Loss: 0.9788, Val Acc: 78.88% | Sparsity: 0.10
# Epoch: 26/200 | Train Loss: 0.8905, Train Acc: 82.96% | Val Loss: 0.9302, Val Acc: 80.92% | Sparsity: 0.10
# Epoch: 27/200 | Train Loss: 0.8924, Train Acc: 82.83% | Val Loss: 0.9485, Val Acc: 80.77% | Sparsity: 0.10
# Epoch: 28/200 | Train Loss: 0.8805, Train Acc: 83.42% | Val Loss: 0.9245, Val Acc: 81.00% | Sparsity: 0.11
# Epoch: 29/200 | Train Loss: 0.8819, Train Acc: 83.28% | Val Loss: 0.9228, Val Acc: 81.35% | Sparsity: 0.11
# Epoch: 30/200 | Train Loss: 0.8767, Train Acc: 83.56% | Val Loss: 0.9367, Val Acc: 81.05% | Sparsity: 0.12
# Epoch: 31/200 | Train Loss: 0.8748, Train Acc: 83.73% | Val Loss: 0.9323, Val Acc: 80.98% | Sparsity: 0.12
# Epoch: 32/200 | Train Loss: 0.8689, Train Acc: 83.79% | Val Loss: 0.9304, Val Acc: 81.43% | Sparsity: 0.12
# Epoch: 33/200 | Train Loss: 0.8683, Train Acc: 83.99% | Val Loss: 0.9308, Val Acc: 80.98% | Sparsity: 0.13
# Epoch: 34/200 | Train Loss: 0.8661, Train Acc: 84.04% | Val Loss: 0.9145, Val Acc: 82.28% | Sparsity: 0.13
# Epoch: 35/200 | Train Loss: 0.8601, Train Acc: 84.25% | Val Loss: 0.9187, Val Acc: 81.58% | Sparsity: 0.14
# Epoch: 36/200 | Train Loss: 0.8578, Train Acc: 84.31% | Val Loss: 0.9269, Val Acc: 81.28% | Sparsity: 0.14
# Epoch: 37/200 | Train Loss: 0.8564, Train Acc: 84.59% | Val Loss: 0.9136, Val Acc: 82.22% | Sparsity: 0.14
# Epoch: 38/200 | Train Loss: 0.8564, Train Acc: 84.42% | Val Loss: 0.9024, Val Acc: 82.33% | Sparsity: 0.15
# Epoch: 39/200 | Train Loss: 0.8486, Train Acc: 84.80% | Val Loss: 0.9025, Val Acc: 82.25% | Sparsity: 0.15
# Epoch: 40/200 | Train Loss: 0.8504, Train Acc: 84.85% | Val Loss: 0.9090, Val Acc: 81.37% | Sparsity: 0.16
# Epoch: 41/200 | Train Loss: 0.8458, Train Acc: 84.98% | Val Loss: 0.9087, Val Acc: 82.25% | Sparsity: 0.16
# Epoch: 42/200 | Train Loss: 0.8409, Train Acc: 85.12% | Val Loss: 0.9359, Val Acc: 81.15% | Sparsity: 0.16
# Epoch: 43/200 | Train Loss: 0.8401, Train Acc: 85.22% | Val Loss: 0.9333, Val Acc: 81.15% | Sparsity: 0.17
# Epoch: 44/200 | Train Loss: 0.8397, Train Acc: 85.41% | Val Loss: 0.9017, Val Acc: 82.62% | Sparsity: 0.17
# Epoch: 45/200 | Train Loss: 0.8379, Train Acc: 85.34% | Val Loss: 0.9389, Val Acc: 81.27% | Sparsity: 0.18
# Epoch: 46/200 | Train Loss: 0.8368, Train Acc: 85.39% | Val Loss: 0.9020, Val Acc: 82.40% | Sparsity: 0.18
# Epoch: 47/200 | Train Loss: 0.8323, Train Acc: 85.59% | Val Loss: 0.9009, Val Acc: 82.45% | Sparsity: 0.18
# Epoch: 48/200 | Train Loss: 0.8292, Train Acc: 85.68% | Val Loss: 0.8641, Val Acc: 83.60% | Sparsity: 0.19
# Epoch: 49/200 | Train Loss: 0.8272, Train Acc: 85.74% | Val Loss: 0.8776, Val Acc: 83.73% | Sparsity: 0.19
# Epoch: 50/200 | Train Loss: 0.8273, Train Acc: 85.82% | Val Loss: 0.9013, Val Acc: 82.43% | Sparsity: 0.20
# Epoch: 51/200 | Train Loss: 0.8261, Train Acc: 85.84% | Val Loss: 0.8644, Val Acc: 84.12% | Sparsity: 0.20
# Epoch: 52/200 | Train Loss: 0.8223, Train Acc: 85.97% | Val Loss: 0.8836, Val Acc: 83.05% | Sparsity: 0.20
# Epoch: 53/200 | Train Loss: 0.8193, Train Acc: 86.16% | Val Loss: 0.8788, Val Acc: 83.32% | Sparsity: 0.21
# Epoch: 54/200 | Train Loss: 0.8194, Train Acc: 86.09% | Val Loss: 0.8911, Val Acc: 82.82% | Sparsity: 0.21
# Epoch: 55/200 | Train Loss: 0.8175, Train Acc: 86.29% | Val Loss: 0.8657, Val Acc: 83.97% | Sparsity: 0.22
# Epoch: 56/200 | Train Loss: 0.8179, Train Acc: 86.26% | Val Loss: 0.9096, Val Acc: 81.93% | Sparsity: 0.22
# Epoch: 57/200 | Train Loss: 0.8175, Train Acc: 86.07% | Val Loss: 0.8793, Val Acc: 83.52% | Sparsity: 0.22
# Epoch: 58/200 | Train Loss: 0.8112, Train Acc: 86.41% | Val Loss: 0.8897, Val Acc: 82.93% | Sparsity: 0.23
# Epoch: 59/200 | Train Loss: 0.8100, Train Acc: 86.61% | Val Loss: 0.8798, Val Acc: 83.47% | Sparsity: 0.23
# Epoch: 60/200 | Train Loss: 0.8092, Train Acc: 86.59% | Val Loss: 0.8579, Val Acc: 84.57% | Sparsity: 0.24
# Epoch: 61/200 | Train Loss: 0.8126, Train Acc: 86.42% | Val Loss: 0.9102, Val Acc: 82.07% | Sparsity: 0.24
# Epoch: 62/200 | Train Loss: 0.8063, Train Acc: 86.87% | Val Loss: 0.8914, Val Acc: 82.90% | Sparsity: 0.24
# Epoch: 63/200 | Train Loss: 0.8022, Train Acc: 86.94% | Val Loss: 0.8666, Val Acc: 83.95% | Sparsity: 0.25
# Epoch: 64/200 | Train Loss: 0.7999, Train Acc: 87.15% | Val Loss: 0.8412, Val Acc: 85.08% | Sparsity: 0.25
# Epoch: 65/200 | Train Loss: 0.7984, Train Acc: 87.03% | Val Loss: 0.8763, Val Acc: 83.60% | Sparsity: 0.26
# Epoch: 66/200 | Train Loss: 0.8001, Train Acc: 87.06% | Val Loss: 0.8695, Val Acc: 83.55% | Sparsity: 0.26
# Epoch: 67/200 | Train Loss: 0.7961, Train Acc: 87.07% | Val Loss: 0.8583, Val Acc: 84.35% | Sparsity: 0.26
# Epoch: 68/200 | Train Loss: 0.7987, Train Acc: 87.13% | Val Loss: 0.8841, Val Acc: 83.07% | Sparsity: 0.27
# Epoch: 69/200 | Train Loss: 0.7930, Train Acc: 87.41% | Val Loss: 0.8533, Val Acc: 84.73% | Sparsity: 0.27
# Epoch: 70/200 | Train Loss: 0.7969, Train Acc: 87.11% | Val Loss: 0.8598, Val Acc: 84.45% | Sparsity: 0.28
# Epoch: 71/200 | Train Loss: 0.7890, Train Acc: 87.41% | Val Loss: 0.8801, Val Acc: 84.12% | Sparsity: 0.28
# Epoch: 72/200 | Train Loss: 0.7877, Train Acc: 87.56% | Val Loss: 0.8914, Val Acc: 83.15% | Sparsity: 0.28
# Epoch: 73/200 | Train Loss: 0.7880, Train Acc: 87.50% | Val Loss: 0.8578, Val Acc: 84.53% | Sparsity: 0.29
# Epoch: 74/200 | Train Loss: 0.7883, Train Acc: 87.51% | Val Loss: 0.8590, Val Acc: 84.37% | Sparsity: 0.29
# Epoch: 75/200 | Train Loss: 0.7833, Train Acc: 87.65% | Val Loss: 0.8415, Val Acc: 85.12% | Sparsity: 0.30
# Epoch: 76/200 | Train Loss: 0.7861, Train Acc: 87.67% | Val Loss: 0.8665, Val Acc: 84.50% | Sparsity: 0.30
# Epoch: 77/200 | Train Loss: 0.7810, Train Acc: 87.83% | Val Loss: 0.8431, Val Acc: 85.45% | Sparsity: 0.30
# Epoch: 78/200 | Train Loss: 0.7786, Train Acc: 88.04% | Val Loss: 0.8591, Val Acc: 84.53% | Sparsity: 0.31
# Epoch: 79/200 | Train Loss: 0.7751, Train Acc: 88.15% | Val Loss: 0.8372, Val Acc: 85.37% | Sparsity: 0.31
# Epoch: 80/200 | Train Loss: 0.7772, Train Acc: 88.05% | Val Loss: 0.8449, Val Acc: 84.80% | Sparsity: 0.32
# Epoch: 81/200 | Train Loss: 0.7780, Train Acc: 88.00% | Val Loss: 0.8559, Val Acc: 84.47% | Sparsity: 0.32
# Epoch: 82/200 | Train Loss: 0.7740, Train Acc: 88.19% | Val Loss: 0.8541, Val Acc: 84.53% | Sparsity: 0.32
# Epoch: 83/200 | Train Loss: 0.7737, Train Acc: 88.15% | Val Loss: 0.8498, Val Acc: 84.90% | Sparsity: 0.33
# Epoch: 84/200 | Train Loss: 0.7715, Train Acc: 88.21% | Val Loss: 0.8370, Val Acc: 85.80% | Sparsity: 0.33
# Epoch: 85/200 | Train Loss: 0.7686, Train Acc: 88.39% | Val Loss: 0.8485, Val Acc: 85.15% | Sparsity: 0.34
# Epoch: 86/200 | Train Loss: 0.7708, Train Acc: 88.30% | Val Loss: 0.8365, Val Acc: 84.77% | Sparsity: 0.34
# Epoch: 87/200 | Train Loss: 0.7675, Train Acc: 88.51% | Val Loss: 0.8390, Val Acc: 84.97% | Sparsity: 0.34
# Epoch: 88/200 | Train Loss: 0.7622, Train Acc: 88.61% | Val Loss: 0.8258, Val Acc: 86.07% | Sparsity: 0.35
# Epoch: 89/200 | Train Loss: 0.7647, Train Acc: 88.66% | Val Loss: 0.8625, Val Acc: 84.17% | Sparsity: 0.35
# Epoch: 90/200 | Train Loss: 0.7607, Train Acc: 88.65% | Val Loss: 0.8283, Val Acc: 85.48% | Sparsity: 0.36
# Epoch: 91/200 | Train Loss: 0.7596, Train Acc: 88.86% | Val Loss: 0.8268, Val Acc: 85.70% | Sparsity: 0.36
# Epoch: 92/200 | Train Loss: 0.7629, Train Acc: 88.60% | Val Loss: 0.8528, Val Acc: 84.60% | Sparsity: 0.36
# Epoch: 93/200 | Train Loss: 0.7588, Train Acc: 88.87% | Val Loss: 0.8289, Val Acc: 85.82% | Sparsity: 0.37
# Epoch: 94/200 | Train Loss: 0.7568, Train Acc: 88.85% | Val Loss: 0.8049, Val Acc: 86.45% | Sparsity: 0.37
# Epoch: 95/200 | Train Loss: 0.7529, Train Acc: 89.25% | Val Loss: 0.8384, Val Acc: 85.40% | Sparsity: 0.38
# Epoch: 96/200 | Train Loss: 0.7533, Train Acc: 89.05% | Val Loss: 0.8386, Val Acc: 85.12% | Sparsity: 0.38
# Epoch: 97/200 | Train Loss: 0.7494, Train Acc: 89.08% | Val Loss: 0.8109, Val Acc: 86.65% | Sparsity: 0.38
# Epoch: 98/200 | Train Loss: 0.7496, Train Acc: 89.21% | Val Loss: 0.8259, Val Acc: 85.83% | Sparsity: 0.39
# Epoch: 99/200 | Train Loss: 0.7494, Train Acc: 89.22% | Val Loss: 0.8481, Val Acc: 84.82% | Sparsity: 0.39
# Epoch: 100/200 | Train Loss: 0.7454, Train Acc: 89.31% | Val Loss: 0.8133, Val Acc: 86.78% | Sparsity: 0.40
# Epoch: 101/200 | Train Loss: 0.7450, Train Acc: 89.42% | Val Loss: 0.8092, Val Acc: 86.70% | Sparsity: 0.40
# Epoch: 102/200 | Train Loss: 0.7423, Train Acc: 89.60% | Val Loss: 0.7975, Val Acc: 86.85% | Sparsity: 0.40
# Epoch: 103/200 | Train Loss: 0.7392, Train Acc: 89.86% | Val Loss: 0.8289, Val Acc: 85.77% | Sparsity: 0.41
# Epoch: 104/200 | Train Loss: 0.7370, Train Acc: 89.70% | Val Loss: 0.8229, Val Acc: 85.92% | Sparsity: 0.41
# Epoch: 105/200 | Train Loss: 0.7341, Train Acc: 89.89% | Val Loss: 0.8456, Val Acc: 85.28% | Sparsity: 0.42
# Epoch: 106/200 | Train Loss: 0.7348, Train Acc: 90.02% | Val Loss: 0.8070, Val Acc: 86.58% | Sparsity: 0.42
# Epoch: 107/200 | Train Loss: 0.7324, Train Acc: 89.98% | Val Loss: 0.8188, Val Acc: 86.67% | Sparsity: 0.42
# Epoch: 108/200 | Train Loss: 0.7300, Train Acc: 90.10% | Val Loss: 0.8319, Val Acc: 85.33% | Sparsity: 0.43
# Epoch: 109/200 | Train Loss: 0.7265, Train Acc: 90.11% | Val Loss: 0.8181, Val Acc: 86.48% | Sparsity: 0.43
# Epoch: 110/200 | Train Loss: 0.7297, Train Acc: 90.15% | Val Loss: 0.8271, Val Acc: 85.78% | Sparsity: 0.44
# Epoch: 111/200 | Train Loss: 0.7196, Train Acc: 90.61% | Val Loss: 0.8145, Val Acc: 86.78% | Sparsity: 0.44
# Epoch: 112/200 | Train Loss: 0.7239, Train Acc: 90.41% | Val Loss: 0.8085, Val Acc: 86.80% | Sparsity: 0.44
# Epoch: 113/200 | Train Loss: 0.7246, Train Acc: 90.42% | Val Loss: 0.8174, Val Acc: 86.40% | Sparsity: 0.45
# Epoch: 114/200 | Train Loss: 0.7211, Train Acc: 90.55% | Val Loss: 0.8180, Val Acc: 86.57% | Sparsity: 0.45
# Epoch: 115/200 | Train Loss: 0.7205, Train Acc: 90.44% | Val Loss: 0.7899, Val Acc: 87.40% | Sparsity: 0.46
# Epoch: 116/200 | Train Loss: 0.7182, Train Acc: 90.62% | Val Loss: 0.8110, Val Acc: 86.35% | Sparsity: 0.46
# Epoch: 117/200 | Train Loss: 0.7134, Train Acc: 90.76% | Val Loss: 0.7997, Val Acc: 86.83% | Sparsity: 0.46
# Epoch: 118/200 | Train Loss: 0.7130, Train Acc: 90.85% | Val Loss: 0.7976, Val Acc: 87.25% | Sparsity: 0.47
# Epoch: 119/200 | Train Loss: 0.7083, Train Acc: 91.10% | Val Loss: 0.8039, Val Acc: 86.97% | Sparsity: 0.47
# Epoch: 120/200 | Train Loss: 0.7064, Train Acc: 91.14% | Val Loss: 0.8003, Val Acc: 86.90% | Sparsity: 0.48
# Epoch: 121/200 | Train Loss: 0.7060, Train Acc: 91.28% | Val Loss: 0.8135, Val Acc: 86.32% | Sparsity: 0.48
# Epoch: 122/200 | Train Loss: 0.7065, Train Acc: 91.11% | Val Loss: 0.7978, Val Acc: 87.52% | Sparsity: 0.48
# Epoch: 123/200 | Train Loss: 0.7018, Train Acc: 91.40% | Val Loss: 0.7849, Val Acc: 87.83% | Sparsity: 0.49
# Epoch: 124/200 | Train Loss: 0.7009, Train Acc: 91.32% | Val Loss: 0.7995, Val Acc: 87.03% | Sparsity: 0.49
# Epoch: 125/200 | Train Loss: 0.6964, Train Acc: 91.62% | Val Loss: 0.7894, Val Acc: 87.63% | Sparsity: 0.50
# Epoch: 126/200 | Train Loss: 0.7013, Train Acc: 91.19% | Val Loss: 0.7860, Val Acc: 87.52% | Sparsity: 0.50
# Epoch: 127/200 | Train Loss: 0.6942, Train Acc: 91.61% | Val Loss: 0.7758, Val Acc: 87.80% | Sparsity: 0.50
# Epoch: 128/200 | Train Loss: 0.6930, Train Acc: 91.72% | Val Loss: 0.7978, Val Acc: 86.90% | Sparsity: 0.51
# Epoch: 129/200 | Train Loss: 0.6920, Train Acc: 91.88% | Val Loss: 0.8011, Val Acc: 87.18% | Sparsity: 0.51
# Epoch: 130/200 | Train Loss: 0.6872, Train Acc: 91.93% | Val Loss: 0.7960, Val Acc: 87.13% | Sparsity: 0.52
# Epoch: 131/200 | Train Loss: 0.6882, Train Acc: 91.84% | Val Loss: 0.7806, Val Acc: 88.05% | Sparsity: 0.52
# Epoch: 132/200 | Train Loss: 0.6803, Train Acc: 92.35% | Val Loss: 0.7732, Val Acc: 88.10% | Sparsity: 0.52
# Epoch: 133/200 | Train Loss: 0.6787, Train Acc: 92.34% | Val Loss: 0.7805, Val Acc: 87.95% | Sparsity: 0.53
# Epoch: 134/200 | Train Loss: 0.6745, Train Acc: 92.60% | Val Loss: 0.7767, Val Acc: 87.95% | Sparsity: 0.53
# Epoch: 135/200 | Train Loss: 0.6768, Train Acc: 92.41% | Val Loss: 0.7774, Val Acc: 87.98% | Sparsity: 0.54
# Epoch: 136/200 | Train Loss: 0.6716, Train Acc: 92.77% | Val Loss: 0.7938, Val Acc: 87.48% | Sparsity: 0.54
# Epoch: 137/200 | Train Loss: 0.6691, Train Acc: 92.76% | Val Loss: 0.7899, Val Acc: 87.37% | Sparsity: 0.54
# Epoch: 138/200 | Train Loss: 0.6671, Train Acc: 92.93% | Val Loss: 0.7612, Val Acc: 88.85% | Sparsity: 0.55
# Epoch: 139/200 | Train Loss: 0.6646, Train Acc: 93.03% | Val Loss: 0.7760, Val Acc: 88.30% | Sparsity: 0.55
# Epoch: 140/200 | Train Loss: 0.6611, Train Acc: 93.09% | Val Loss: 0.7594, Val Acc: 88.68% | Sparsity: 0.56
# Epoch: 141/200 | Train Loss: 0.6596, Train Acc: 93.19% | Val Loss: 0.7671, Val Acc: 88.55% | Sparsity: 0.56
# Epoch: 142/200 | Train Loss: 0.6543, Train Acc: 93.39% | Val Loss: 0.7566, Val Acc: 89.12% | Sparsity: 0.56
# Epoch: 143/200 | Train Loss: 0.6559, Train Acc: 93.36% | Val Loss: 0.7683, Val Acc: 88.45% | Sparsity: 0.57
# Epoch: 144/200 | Train Loss: 0.6549, Train Acc: 93.39% | Val Loss: 0.7726, Val Acc: 88.37% | Sparsity: 0.57
# Epoch: 145/200 | Train Loss: 0.6500, Train Acc: 93.70% | Val Loss: 0.7580, Val Acc: 88.88% | Sparsity: 0.58
# Epoch: 146/200 | Train Loss: 0.6513, Train Acc: 93.64% | Val Loss: 0.7497, Val Acc: 89.27% | Sparsity: 0.58
# Epoch: 147/200 | Train Loss: 0.6413, Train Acc: 94.10% | Val Loss: 0.7585, Val Acc: 88.87% | Sparsity: 0.58
# Epoch: 148/200 | Train Loss: 0.6442, Train Acc: 93.99% | Val Loss: 0.7561, Val Acc: 88.90% | Sparsity: 0.59
# Epoch: 149/200 | Train Loss: 0.6413, Train Acc: 94.09% | Val Loss: 0.7594, Val Acc: 89.20% | Sparsity: 0.59
# Epoch: 150/200 | Train Loss: 0.6386, Train Acc: 94.25% | Val Loss: 0.7610, Val Acc: 88.63% | Sparsity: 0.60
# Epoch: 151/200 | Train Loss: 0.6353, Train Acc: 94.36% | Val Loss: 0.7622, Val Acc: 88.72% | Sparsity: 0.60
# Epoch: 152/200 | Train Loss: 0.6352, Train Acc: 94.24% | Val Loss: 0.7373, Val Acc: 89.97% | Sparsity: 0.60
# Epoch: 153/200 | Train Loss: 0.6309, Train Acc: 94.57% | Val Loss: 0.7591, Val Acc: 89.18% | Sparsity: 0.61
# Epoch: 154/200 | Train Loss: 0.6282, Train Acc: 94.70% | Val Loss: 0.7418, Val Acc: 89.75% | Sparsity: 0.61
# Epoch: 155/200 | Train Loss: 0.6258, Train Acc: 94.61% | Val Loss: 0.7379, Val Acc: 89.43% | Sparsity: 0.62
# Epoch: 156/200 | Train Loss: 0.6201, Train Acc: 94.96% | Val Loss: 0.7499, Val Acc: 89.27% | Sparsity: 0.62
# Epoch: 157/200 | Train Loss: 0.6196, Train Acc: 94.97% | Val Loss: 0.7309, Val Acc: 89.92% | Sparsity: 0.62
# Epoch: 158/200 | Train Loss: 0.6196, Train Acc: 94.96% | Val Loss: 0.7444, Val Acc: 90.20% | Sparsity: 0.63
# Epoch: 159/200 | Train Loss: 0.6159, Train Acc: 95.09% | Val Loss: 0.7374, Val Acc: 89.98% | Sparsity: 0.63
# Epoch: 160/200 | Train Loss: 0.6108, Train Acc: 95.31% | Val Loss: 0.7388, Val Acc: 89.72% | Sparsity: 0.64
# Epoch: 161/200 | Train Loss: 0.6105, Train Acc: 95.47% | Val Loss: 0.7369, Val Acc: 90.13% | Sparsity: 0.64
# Epoch: 162/200 | Train Loss: 0.6097, Train Acc: 95.36% | Val Loss: 0.7284, Val Acc: 90.25% | Sparsity: 0.64
# Epoch: 163/200 | Train Loss: 0.6079, Train Acc: 95.53% | Val Loss: 0.7250, Val Acc: 90.48% | Sparsity: 0.65
# Epoch: 164/200 | Train Loss: 0.6059, Train Acc: 95.60% | Val Loss: 0.7260, Val Acc: 90.67% | Sparsity: 0.65
# Epoch: 165/200 | Train Loss: 0.6002, Train Acc: 95.86% | Val Loss: 0.7317, Val Acc: 90.47% | Sparsity: 0.66
# Epoch: 166/200 | Train Loss: 0.5972, Train Acc: 95.98% | Val Loss: 0.7307, Val Acc: 90.00% | Sparsity: 0.66
# Epoch: 167/200 | Train Loss: 0.5971, Train Acc: 96.03% | Val Loss: 0.7140, Val Acc: 90.72% | Sparsity: 0.66
# Epoch: 168/200 | Train Loss: 0.5967, Train Acc: 96.01% | Val Loss: 0.7237, Val Acc: 90.75% | Sparsity: 0.67
# Epoch: 169/200 | Train Loss: 0.5907, Train Acc: 96.36% | Val Loss: 0.7089, Val Acc: 91.27% | Sparsity: 0.67
# Epoch: 170/200 | Train Loss: 0.5906, Train Acc: 96.23% | Val Loss: 0.7151, Val Acc: 91.03% | Sparsity: 0.68
# Epoch: 171/200 | Train Loss: 0.5889, Train Acc: 96.41% | Val Loss: 0.7251, Val Acc: 90.55% | Sparsity: 0.68
# Epoch: 172/200 | Train Loss: 0.5862, Train Acc: 96.44% | Val Loss: 0.7142, Val Acc: 91.02% | Sparsity: 0.68
# Epoch: 173/200 | Train Loss: 0.5871, Train Acc: 96.42% | Val Loss: 0.7113, Val Acc: 91.03% | Sparsity: 0.69
# Epoch: 174/200 | Train Loss: 0.5810, Train Acc: 96.77% | Val Loss: 0.7080, Val Acc: 91.20% | Sparsity: 0.69
# Epoch: 175/200 | Train Loss: 0.5841, Train Acc: 96.52% | Val Loss: 0.7012, Val Acc: 91.40% | Sparsity: 0.70
# Epoch: 176/200 | Train Loss: 0.5791, Train Acc: 96.78% | Val Loss: 0.7136, Val Acc: 90.83% | Sparsity: 0.70
# Epoch: 177/200 | Train Loss: 0.5796, Train Acc: 96.71% | Val Loss: 0.7091, Val Acc: 91.22% | Sparsity: 0.70
# Epoch: 178/200 | Train Loss: 0.5768, Train Acc: 97.00% | Val Loss: 0.7071, Val Acc: 91.43% | Sparsity: 0.71
# Epoch: 179/200 | Train Loss: 0.5778, Train Acc: 96.86% | Val Loss: 0.7078, Val Acc: 91.23% | Sparsity: 0.71
# Epoch: 180/200 | Train Loss: 0.5768, Train Acc: 96.96% | Val Loss: 0.7075, Val Acc: 91.53% | Sparsity: 0.72
# Epoch: 181/200 | Train Loss: 0.5759, Train Acc: 96.99% | Val Loss: 0.7086, Val Acc: 91.23% | Sparsity: 0.72
# Epoch: 182/200 | Train Loss: 0.5705, Train Acc: 97.25% | Val Loss: 0.7164, Val Acc: 90.77% | Sparsity: 0.72
# Epoch: 183/200 | Train Loss: 0.5721, Train Acc: 97.07% | Val Loss: 0.7069, Val Acc: 91.23% | Sparsity: 0.73
# Epoch: 184/200 | Train Loss: 0.5717, Train Acc: 97.14% | Val Loss: 0.7108, Val Acc: 91.45% | Sparsity: 0.73
# Epoch: 185/200 | Train Loss: 0.5720, Train Acc: 97.08% | Val Loss: 0.7059, Val Acc: 91.18% | Sparsity: 0.74
# Epoch: 186/200 | Train Loss: 0.5683, Train Acc: 97.22% | Val Loss: 0.7013, Val Acc: 91.55% | Sparsity: 0.74
# Epoch: 187/200 | Train Loss: 0.5695, Train Acc: 97.23% | Val Loss: 0.7075, Val Acc: 91.13% | Sparsity: 0.74
# Epoch: 188/200 | Train Loss: 0.5679, Train Acc: 97.23% | Val Loss: 0.6940, Val Acc: 91.75% | Sparsity: 0.75
# Epoch: 189/200 | Train Loss: 0.5663, Train Acc: 97.31% | Val Loss: 0.6976, Val Acc: 91.48% | Sparsity: 0.75
# Epoch: 190/200 | Train Loss: 0.5664, Train Acc: 97.37% | Val Loss: 0.6988, Val Acc: 91.87% | Sparsity: 0.76
# Epoch: 191/200 | Train Loss: 0.5668, Train Acc: 97.32% | Val Loss: 0.6955, Val Acc: 91.78% | Sparsity: 0.76
# Epoch: 192/200 | Train Loss: 0.5646, Train Acc: 97.42% | Val Loss: 0.7012, Val Acc: 91.57% | Sparsity: 0.76
# Epoch: 193/200 | Train Loss: 0.5663, Train Acc: 97.44% | Val Loss: 0.6948, Val Acc: 91.98% | Sparsity: 0.77
# Epoch: 194/200 | Train Loss: 0.5657, Train Acc: 97.39% | Val Loss: 0.6978, Val Acc: 91.88% | Sparsity: 0.77
# Epoch: 195/200 | Train Loss: 0.5642, Train Acc: 97.40% | Val Loss: 0.6960, Val Acc: 91.67% | Sparsity: 0.78
# Epoch: 196/200 | Train Loss: 0.5665, Train Acc: 97.36% | Val Loss: 0.7062, Val Acc: 91.37% | Sparsity: 0.78
# Epoch: 197/200 | Train Loss: 0.5644, Train Acc: 97.46% | Val Loss: 0.7027, Val Acc: 91.53% | Sparsity: 0.78
# Epoch: 198/200 | Train Loss: 0.5662, Train Acc: 97.38% | Val Loss: 0.6931, Val Acc: 91.92% | Sparsity: 0.79
# Epoch: 199/200 | Train Loss: 0.5648, Train Acc: 97.44% | Val Loss: 0.6905, Val Acc: 92.03% | Sparsity: 0.79
# Epoch: 200/200 | Train Loss: 0.5630, Train Acc: 97.52% | Val Loss: 0.6988, Val Acc: 91.65% | Sparsity: 0.80
# Final Results:
# Final Training Loss: 0.5630
# Final Validation Loss: 0.6988
# Final Training Accuracy: 97.52%
# Final Validation Accuracy: 91.65%
# Final Test Loss: 0.6919
# Final Test Accuracy: 91.98%
