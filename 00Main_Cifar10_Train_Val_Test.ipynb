# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms

# Define the basic block for ResNet
class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_channels, out_channels, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(
            in_channels, out_channels, kernel_size=3, stride=stride, padding=1, bias=False
        )
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.conv2 = nn.Conv2d(
            out_channels, out_channels, kernel_size=3, stride=1, padding=1, bias=False
        )
        self.bn2 = nn.BatchNorm2d(out_channels)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_channels != out_channels:
            self.shortcut = nn.Sequential(
                nn.Conv2d(
                    in_channels, out_channels, kernel_size=1, stride=stride, bias=False
                ),
                nn.BatchNorm2d(out_channels),
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out

# Define ResNet
class DynamicSparseResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):  # For CIFAR-10, num_classes=10
        super(DynamicSparseResNet, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(
            3, 64, kernel_size=3, stride=1, padding=1, bias=False  # CIFAR-10 images have 3 channels
        )
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.linear = nn.Linear(512 * block.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        layers = []
        strides = [stride] + [1] * (num_blocks - 1)
        for s in strides:
            layers.append(block(self.in_planes, planes, s))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))  # Output size: 32x32
        out = self.layer1(out)                 # Output size: 32x32
        out = self.layer2(out)                 # Output size: 16x16
        out = self.layer3(out)                 # Output size: 8x8
        out = self.layer4(out)                 # Output size: 4x4
        out = F.avg_pool2d(out, 4)             # Output size: 1x1
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out

def ResNet18(num_classes=10):
    return DynamicSparseResNet(BasicBlock, [2, 2, 2, 2], num_classes=num_classes)

def initialize_weights(model):
    for m in model.modules():
        if isinstance(m, (nn.Conv2d, nn.Linear)):
            nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
            if m.bias is not None:
                nn.init.zeros_(m.bias)
        elif isinstance(m, nn.BatchNorm2d):
            nn.init.ones_(m.weight)
            nn.init.zeros_(m.bias)

def apply_dynamic_supermask(model, sparsity_rate):
    masks = {}
    for name, param in model.named_parameters():
        if 'weight' in name:
            weight_flat = param.data.abs().flatten()
            k = int(weight_flat.shape[0] * (1 - sparsity_rate))
            if k == 0:
                threshold = torch.max(weight_flat) + 1
            else:
                threshold = torch.topk(weight_flat, k, largest=True, sorted=True)[0][-1]
            mask = (param.data.abs() >= threshold).float()
            masks[name] = mask.view(param.size()).to(param.device)
    return masks

def dynamic_weight_update(model, masks):
    for name, param in model.named_parameters():
        if 'weight' in name and param.grad is not None:
            mask = masks[name]
            param.grad.data.mul_(mask)

def train_with_dynamic_pruning(model, train_loader, val_loader, test_loader, epochs=200, device='cuda'):
    criterion = nn.CrossEntropyLoss(label_smoothing=0.1)
    optimizer = torch.optim.SGD(
        model.parameters(), lr=0.1, momentum=0.9, weight_decay=5e-4
    )
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=epochs)

    initial_sparsity = 0.0
    final_sparsity = 0.8
    sparsity_increment = (final_sparsity - initial_sparsity) / epochs

    train_losses = []
    val_losses = []
    train_acc = []
    val_acc = []

    initialize_weights(model)

    for epoch in range(epochs):
        model.train()
        running_loss = 0
        correct = 0
        total = 0

        current_sparsity = initial_sparsity + sparsity_increment * epoch
        masks = apply_dynamic_supermask(model, current_sparsity)

        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()

            dynamic_weight_update(model, masks)
            optimizer.step()

            running_loss += loss.item() * images.size(0)
            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()

        train_loss = running_loss / total
        train_accuracy = 100.0 * correct / total

        # Validation
        val_loss, val_accuracy = evaluate(model, val_loader, criterion, device)

        train_losses.append(train_loss)
        val_losses.append(val_loss)
        train_acc.append(train_accuracy)
        val_acc.append(val_accuracy)

        scheduler.step()

        print(
            f"Epoch: {epoch+1}/{epochs}"
            f" | Train Loss: {train_loss:.4f}, Train Acc: {train_accuracy:.2f}%"
            f" | Val Loss: {val_loss:.4f}, Val Acc: {val_accuracy:.2f}%"
            f" | Sparsity: {current_sparsity:.2f}"
        )

    # Final evaluation on the test set
    test_loss, test_accuracy = evaluate(model, test_loader, criterion, device)
    print(f"\nTest Set Evaluation: Loss: {test_loss:.4f}, Accuracy: {test_accuracy:.2f}%")

    return train_losses, val_losses, train_acc, val_acc, test_loss, test_accuracy

def evaluate(model, data_loader, criterion, device):
    model.eval()
    loss_total = 0
    correct = 0
    total = 0

    with torch.no_grad():
        for images, labels in data_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)

            loss_total += loss.item() * images.size(0)
            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()

    avg_loss = loss_total / total
    accuracy = 100.0 * correct / total
    return avg_loss, accuracy

def main():
    torch.manual_seed(42)

    # Data augmentation for CIFAR-10
    transform_train = transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(15),
        transforms.ColorJitter(
            brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1
        ),
        transforms.ToTensor(),
        transforms.RandomErasing(),
        transforms.Normalize(
            (0.4914, 0.4822, 0.4465),
            (0.2470, 0.2435, 0.2616)
        ),
    ])

    # Test transformation - no augmentation
    transform_test = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize(
            (0.4914, 0.4822, 0.4465),
            (0.2470, 0.2435, 0.2616)
        ),
    ])

    # Load CIFAR-10 dataset
    train_dataset = torchvision.datasets.CIFAR10(
        root='./data', train=True, download=True, transform=transform_train
    )

    test_dataset = torchvision.datasets.CIFAR10(
        root='./data', train=False, download=True, transform=transform_test
    )

    # For a proper 80/10/10 split:
    # With 50,000 training samples and 10,000 test samples,
    # 80% would be 48,000, 10% would be 6,000 samples each
    # Since we want to keep the test set as-is,
    # we need to use 48,000/50,000 = 96% of the training set for training
    # and 6,000/50,000 = 12% of the training set for validation
    # But since 96% + 12% > 100%, we adjust to use 88% for training and 12% for validation

    # Calculate split sizes
    train_size = int(0.89 * len(train_dataset))  # ~44,500 samples (89% of training)
    val_size = len(train_dataset) - train_size   # ~5,500 samples (11% of training)

    # Split the training dataset into train and validation sets
    train_subset, val_subset = torch.utils.data.random_split(
        train_dataset, [train_size, val_size]
    )

    # Display dataset sizes
    total_samples = len(train_subset) + len(val_subset) + len(test_dataset)
    print(f"Dataset sizes - Train: {len(train_subset)} ({len(train_subset)/total_samples*100:.1f}%), "
          f"Validation: {len(val_subset)} ({len(val_subset)/total_samples*100:.1f}%), "
          f"Test: {len(test_dataset)} ({len(test_dataset)/total_samples*100:.1f}%)")
    print(f"Total samples: {total_samples}")

    # Set up DataLoader for training, validation, and testing data
    batch_size = 128
    train_loader = torch.utils.data.DataLoader(
        train_subset,
        batch_size=batch_size,
        shuffle=True,
        num_workers=4,
        pin_memory=True,
    )

    val_loader = torch.utils.data.DataLoader(
        val_subset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=4,
        pin_memory=True,
    )

    test_loader = torch.utils.data.DataLoader(
        test_dataset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=4,
        pin_memory=True,
    )

    # Set device to GPU if available
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model = ResNet18(num_classes=10).to(device)

    # Train and validate the model with dynamic pruning
    train_losses, val_losses, train_acc, val_acc, test_loss, test_accuracy = train_with_dynamic_pruning(
        model, train_loader, val_loader, test_loader, epochs=200, device=device
    )

    # Plot training results
    import matplotlib.pyplot as plt
    plt.figure(figsize=(12, 4))

    plt.subplot(1, 2, 1)
    plt.plot(train_losses, label='Train Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.title('CIFAR-10 Training and Validation Loss')

    plt.subplot(1, 2, 2)
    plt.plot(train_acc, label='Train Accuracy')
    plt.plot(val_acc, label='Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy (%)')
    plt.legend()
    plt.title('CIFAR-10 Training and Validation Accuracy')

    plt.tight_layout()
    plt.show()

    # Print final metrics
    print("\nFinal Results:")
    print(f"Final Training Loss: {train_losses[-1]:.4f}")
    print(f"Final Validation Loss: {val_losses[-1]:.4f}")
    print(f"Final Training Accuracy: {train_acc[-1]:.2f}%")
    print(f"Final Validation Accuracy: {val_acc[-1]:.2f}%")
    print(f"Final Test Loss: {test_loss:.4f}")
    print(f"Final Test Accuracy: {test_accuracy:.2f}%")

if __name__ == "__main__":
    main()
# Out:
# Dataset sizes - Train: 44500 (74.2%), Validation: 5500 (9.2%), Test: 10000 (16.7%)
# Total samples: 60000
# Epoch: 1/200 | Train Loss: 3.1972, Train Acc: 13.48% | Val Loss: 2.1425, Val Acc: 21.95% | Sparsity: 0.00
# Epoch: 2/200 | Train Loss: 2.0802, Train Acc: 23.82% | Val Loss: 2.0334, Val Acc: 28.27% | Sparsity: 0.00
# Epoch: 3/200 | Train Loss: 1.9366, Train Acc: 30.94% | Val Loss: 1.8984, Val Acc: 34.02% | Sparsity: 0.01
# Epoch: 4/200 | Train Loss: 1.8291, Train Acc: 36.83% | Val Loss: 1.7928, Val Acc: 39.20% | Sparsity: 0.01
# Epoch: 5/200 | Train Loss: 1.7310, Train Acc: 41.94% | Val Loss: 1.6707, Val Acc: 46.31% | Sparsity: 0.02
# Epoch: 6/200 | Train Loss: 1.6231, Train Acc: 47.38% | Val Loss: 1.5526, Val Acc: 51.00% | Sparsity: 0.02
# Epoch: 7/200 | Train Loss: 1.5247, Train Acc: 52.46% | Val Loss: 1.5224, Val Acc: 52.87% | Sparsity: 0.02
# Epoch: 8/200 | Train Loss: 1.4385, Train Acc: 57.35% | Val Loss: 1.4696, Val Acc: 55.95% | Sparsity: 0.03
# Epoch: 9/200 | Train Loss: 1.3761, Train Acc: 60.13% | Val Loss: 1.5265, Val Acc: 52.51% | Sparsity: 0.03
# Epoch: 10/200 | Train Loss: 1.3274, Train Acc: 62.89% | Val Loss: 1.3500, Val Acc: 61.80% | Sparsity: 0.04
# Epoch: 11/200 | Train Loss: 1.2618, Train Acc: 65.74% | Val Loss: 1.3412, Val Acc: 61.91% | Sparsity: 0.04
# Epoch: 12/200 | Train Loss: 1.2153, Train Acc: 67.89% | Val Loss: 1.4017, Val Acc: 59.93% | Sparsity: 0.04
# Epoch: 13/200 | Train Loss: 1.1776, Train Acc: 69.78% | Val Loss: 1.2402, Val Acc: 67.16% | Sparsity: 0.05
# Epoch: 14/200 | Train Loss: 1.1501, Train Acc: 70.93% | Val Loss: 1.2582, Val Acc: 65.60% | Sparsity: 0.05
# Epoch: 15/200 | Train Loss: 1.1306, Train Acc: 72.24% | Val Loss: 1.3395, Val Acc: 63.27% | Sparsity: 0.06
# Epoch: 16/200 | Train Loss: 1.1164, Train Acc: 72.76% | Val Loss: 1.1808, Val Acc: 70.05% | Sparsity: 0.06
# Epoch: 17/200 | Train Loss: 1.0988, Train Acc: 73.46% | Val Loss: 1.1611, Val Acc: 70.38% | Sparsity: 0.06
# Epoch: 18/200 | Train Loss: 1.0824, Train Acc: 74.28% | Val Loss: 1.3060, Val Acc: 65.62% | Sparsity: 0.07
# Epoch: 19/200 | Train Loss: 1.0672, Train Acc: 74.85% | Val Loss: 1.2363, Val Acc: 67.60% | Sparsity: 0.07
# Epoch: 20/200 | Train Loss: 1.0593, Train Acc: 75.20% | Val Loss: 1.3268, Val Acc: 64.55% | Sparsity: 0.08
# Epoch: 21/200 | Train Loss: 1.0506, Train Acc: 75.69% | Val Loss: 1.1264, Val Acc: 71.49% | Sparsity: 0.08
# Epoch: 22/200 | Train Loss: 1.0472, Train Acc: 75.97% | Val Loss: 1.1269, Val Acc: 72.22% | Sparsity: 0.08
# Epoch: 23/200 | Train Loss: 1.0341, Train Acc: 76.47% | Val Loss: 1.1822, Val Acc: 69.82% | Sparsity: 0.09
# Epoch: 24/200 | Train Loss: 1.0231, Train Acc: 77.07% | Val Loss: 1.4154, Val Acc: 60.93% | Sparsity: 0.09
# Epoch: 25/200 | Train Loss: 1.0192, Train Acc: 77.38% | Val Loss: 1.1643, Val Acc: 70.45% | Sparsity: 0.10
# Epoch: 26/200 | Train Loss: 1.0169, Train Acc: 77.12% | Val Loss: 1.1045, Val Acc: 73.25% | Sparsity: 0.10
# Epoch: 27/200 | Train Loss: 1.0168, Train Acc: 77.27% | Val Loss: 1.1274, Val Acc: 72.65% | Sparsity: 0.10
# Epoch: 28/200 | Train Loss: 1.0040, Train Acc: 77.68% | Val Loss: 1.0740, Val Acc: 74.11% | Sparsity: 0.11
# Epoch: 29/200 | Train Loss: 0.9984, Train Acc: 78.11% | Val Loss: 1.1689, Val Acc: 70.20% | Sparsity: 0.11
# Epoch: 30/200 | Train Loss: 0.9985, Train Acc: 78.08% | Val Loss: 1.1162, Val Acc: 73.16% | Sparsity: 0.12
# Epoch: 31/200 | Train Loss: 0.9873, Train Acc: 78.53% | Val Loss: 1.0963, Val Acc: 74.04% | Sparsity: 0.12
# Epoch: 32/200 | Train Loss: 0.9887, Train Acc: 78.54% | Val Loss: 1.0605, Val Acc: 74.93% | Sparsity: 0.12
# Epoch: 33/200 | Train Loss: 0.9822, Train Acc: 79.05% | Val Loss: 1.0900, Val Acc: 73.49% | Sparsity: 0.13
# Epoch: 34/200 | Train Loss: 0.9800, Train Acc: 79.10% | Val Loss: 1.0796, Val Acc: 74.80% | Sparsity: 0.13
# Epoch: 35/200 | Train Loss: 0.9814, Train Acc: 78.79% | Val Loss: 1.1286, Val Acc: 71.71% | Sparsity: 0.14
# Epoch: 36/200 | Train Loss: 0.9789, Train Acc: 78.88% | Val Loss: 1.0502, Val Acc: 76.16% | Sparsity: 0.14
# Epoch: 37/200 | Train Loss: 0.9721, Train Acc: 79.07% | Val Loss: 1.0809, Val Acc: 74.00% | Sparsity: 0.14
# Epoch: 38/200 | Train Loss: 0.9665, Train Acc: 79.47% | Val Loss: 1.2506, Val Acc: 68.22% | Sparsity: 0.15
# Epoch: 39/200 | Train Loss: 0.9677, Train Acc: 79.51% | Val Loss: 1.2214, Val Acc: 70.20% | Sparsity: 0.15
# Epoch: 40/200 | Train Loss: 0.9631, Train Acc: 79.75% | Val Loss: 1.1331, Val Acc: 73.07% | Sparsity: 0.16
# Epoch: 41/200 | Train Loss: 0.9667, Train Acc: 79.54% | Val Loss: 1.1516, Val Acc: 72.33% | Sparsity: 0.16
# Epoch: 42/200 | Train Loss: 0.9574, Train Acc: 80.02% | Val Loss: 1.1449, Val Acc: 72.05% | Sparsity: 0.16
# Epoch: 43/200 | Train Loss: 0.9471, Train Acc: 80.47% | Val Loss: 1.0428, Val Acc: 76.35% | Sparsity: 0.17
# Epoch: 44/200 | Train Loss: 0.9530, Train Acc: 80.00% | Val Loss: 1.0552, Val Acc: 75.60% | Sparsity: 0.17
# Epoch: 45/200 | Train Loss: 0.9530, Train Acc: 80.01% | Val Loss: 1.1967, Val Acc: 69.53% | Sparsity: 0.18
# Epoch: 46/200 | Train Loss: 0.9477, Train Acc: 80.35% | Val Loss: 1.1154, Val Acc: 73.13% | Sparsity: 0.18
# Epoch: 47/200 | Train Loss: 0.9474, Train Acc: 80.33% | Val Loss: 1.2042, Val Acc: 69.47% | Sparsity: 0.18
# Epoch: 48/200 | Train Loss: 0.9452, Train Acc: 80.49% | Val Loss: 1.0435, Val Acc: 76.04% | Sparsity: 0.19
# Epoch: 49/200 | Train Loss: 0.9452, Train Acc: 80.41% | Val Loss: 1.1186, Val Acc: 72.89% | Sparsity: 0.19
# Epoch: 50/200 | Train Loss: 0.9397, Train Acc: 80.72% | Val Loss: 1.1439, Val Acc: 71.38% | Sparsity: 0.20
# Epoch: 51/200 | Train Loss: 0.9510, Train Acc: 80.48% | Val Loss: 1.0433, Val Acc: 76.20% | Sparsity: 0.20
# Epoch: 52/200 | Train Loss: 0.9359, Train Acc: 80.85% | Val Loss: 1.0049, Val Acc: 77.78% | Sparsity: 0.20
# Epoch: 53/200 | Train Loss: 0.9368, Train Acc: 80.75% | Val Loss: 1.2794, Val Acc: 66.13% | Sparsity: 0.21
# Epoch: 54/200 | Train Loss: 0.9304, Train Acc: 81.19% | Val Loss: 1.0169, Val Acc: 77.35% | Sparsity: 0.21
# Epoch: 55/200 | Train Loss: 0.9304, Train Acc: 81.30% | Val Loss: 1.1446, Val Acc: 72.95% | Sparsity: 0.22
# Epoch: 56/200 | Train Loss: 0.9324, Train Acc: 81.08% | Val Loss: 0.9987, Val Acc: 78.56% | Sparsity: 0.22
# Epoch: 57/200 | Train Loss: 0.9312, Train Acc: 80.92% | Val Loss: 0.9799, Val Acc: 78.73% | Sparsity: 0.22
# Epoch: 58/200 | Train Loss: 0.9221, Train Acc: 81.52% | Val Loss: 1.0739, Val Acc: 74.51% | Sparsity: 0.23
# Epoch: 59/200 | Train Loss: 0.9202, Train Acc: 81.74% | Val Loss: 1.0306, Val Acc: 76.75% | Sparsity: 0.23
# Epoch: 60/200 | Train Loss: 0.9244, Train Acc: 81.48% | Val Loss: 1.1235, Val Acc: 72.38% | Sparsity: 0.24
# Epoch: 61/200 | Train Loss: 0.9222, Train Acc: 81.64% | Val Loss: 1.0809, Val Acc: 75.45% | Sparsity: 0.24
# Epoch: 62/200 | Train Loss: 0.9212, Train Acc: 81.60% | Val Loss: 0.9822, Val Acc: 78.49% | Sparsity: 0.24
# Epoch: 63/200 | Train Loss: 0.9149, Train Acc: 81.76% | Val Loss: 1.0901, Val Acc: 74.31% | Sparsity: 0.25
# Epoch: 64/200 | Train Loss: 0.9151, Train Acc: 81.71% | Val Loss: 0.9794, Val Acc: 78.80% | Sparsity: 0.25
# Epoch: 65/200 | Train Loss: 0.9170, Train Acc: 81.62% | Val Loss: 1.0905, Val Acc: 73.75% | Sparsity: 0.26
# Epoch: 66/200 | Train Loss: 0.9124, Train Acc: 81.97% | Val Loss: 1.0314, Val Acc: 76.64% | Sparsity: 0.26
# Epoch: 67/200 | Train Loss: 0.9073, Train Acc: 82.07% | Val Loss: 1.0182, Val Acc: 77.56% | Sparsity: 0.26
# Epoch: 68/200 | Train Loss: 0.9103, Train Acc: 82.20% | Val Loss: 1.0528, Val Acc: 75.47% | Sparsity: 0.27
# Epoch: 69/200 | Train Loss: 0.9061, Train Acc: 82.23% | Val Loss: 1.0832, Val Acc: 74.60% | Sparsity: 0.27
# Epoch: 70/200 | Train Loss: 0.9113, Train Acc: 82.01% | Val Loss: 1.0350, Val Acc: 76.58% | Sparsity: 0.28
# Epoch: 71/200 | Train Loss: 0.9003, Train Acc: 82.55% | Val Loss: 1.1032, Val Acc: 73.18% | Sparsity: 0.28
# Epoch: 72/200 | Train Loss: 0.9033, Train Acc: 82.47% | Val Loss: 0.9957, Val Acc: 78.09% | Sparsity: 0.28
# Epoch: 73/200 | Train Loss: 0.9003, Train Acc: 82.51% | Val Loss: 1.1178, Val Acc: 72.98% | Sparsity: 0.29
# Epoch: 74/200 | Train Loss: 0.8977, Train Acc: 82.61% | Val Loss: 0.9729, Val Acc: 78.95% | Sparsity: 0.29
# Epoch: 75/200 | Train Loss: 0.8993, Train Acc: 82.33% | Val Loss: 1.0884, Val Acc: 74.71% | Sparsity: 0.30
# Epoch: 76/200 | Train Loss: 0.8888, Train Acc: 82.97% | Val Loss: 1.0092, Val Acc: 77.58% | Sparsity: 0.30
# Epoch: 77/200 | Train Loss: 0.8892, Train Acc: 82.93% | Val Loss: 0.9424, Val Acc: 80.71% | Sparsity: 0.30
# Epoch: 78/200 | Train Loss: 0.8912, Train Acc: 82.96% | Val Loss: 1.0779, Val Acc: 74.91% | Sparsity: 0.31
# Epoch: 79/200 | Train Loss: 0.8899, Train Acc: 82.92% | Val Loss: 1.0448, Val Acc: 75.91% | Sparsity: 0.31
# Epoch: 80/200 | Train Loss: 0.8869, Train Acc: 82.96% | Val Loss: 1.0344, Val Acc: 76.89% | Sparsity: 0.32
# Epoch: 81/200 | Train Loss: 0.8829, Train Acc: 83.34% | Val Loss: 0.9950, Val Acc: 78.27% | Sparsity: 0.32
# Epoch: 82/200 | Train Loss: 0.8834, Train Acc: 83.06% | Val Loss: 0.9623, Val Acc: 79.31% | Sparsity: 0.32
# Epoch: 83/200 | Train Loss: 0.8811, Train Acc: 83.24% | Val Loss: 0.9490, Val Acc: 80.40% | Sparsity: 0.33
# Epoch: 84/200 | Train Loss: 0.8846, Train Acc: 83.22% | Val Loss: 1.0277, Val Acc: 76.65% | Sparsity: 0.33
# Epoch: 85/200 | Train Loss: 0.8795, Train Acc: 83.27% | Val Loss: 1.0570, Val Acc: 75.60% | Sparsity: 0.34
# Epoch: 86/200 | Train Loss: 0.8755, Train Acc: 83.64% | Val Loss: 0.9507, Val Acc: 79.31% | Sparsity: 0.34
# Epoch: 87/200 | Train Loss: 0.8725, Train Acc: 83.72% | Val Loss: 0.9718, Val Acc: 79.49% | Sparsity: 0.34
# Epoch: 88/200 | Train Loss: 0.8711, Train Acc: 83.72% | Val Loss: 0.9582, Val Acc: 80.05% | Sparsity: 0.35
# Epoch: 89/200 | Train Loss: 0.8685, Train Acc: 83.71% | Val Loss: 0.9822, Val Acc: 78.85% | Sparsity: 0.35
# Epoch: 90/200 | Train Loss: 0.8667, Train Acc: 84.08% | Val Loss: 0.9828, Val Acc: 78.82% | Sparsity: 0.36
# Epoch: 91/200 | Train Loss: 0.8661, Train Acc: 83.91% | Val Loss: 1.1097, Val Acc: 73.85% | Sparsity: 0.36
# Epoch: 92/200 | Train Loss: 0.8601, Train Acc: 84.15% | Val Loss: 0.9831, Val Acc: 78.36% | Sparsity: 0.36
# Epoch: 93/200 | Train Loss: 0.8624, Train Acc: 84.08% | Val Loss: 1.0716, Val Acc: 75.07% | Sparsity: 0.37
# Epoch: 94/200 | Train Loss: 0.8625, Train Acc: 84.26% | Val Loss: 0.9561, Val Acc: 79.80% | Sparsity: 0.37
# Epoch: 95/200 | Train Loss: 0.8552, Train Acc: 84.51% | Val Loss: 1.0288, Val Acc: 76.91% | Sparsity: 0.38
# Epoch: 96/200 | Train Loss: 0.8604, Train Acc: 84.10% | Val Loss: 1.0290, Val Acc: 76.69% | Sparsity: 0.38
# Epoch: 97/200 | Train Loss: 0.8550, Train Acc: 84.51% | Val Loss: 0.9500, Val Acc: 80.55% | Sparsity: 0.38
# Epoch: 98/200 | Train Loss: 0.8543, Train Acc: 84.49% | Val Loss: 0.9284, Val Acc: 80.91% | Sparsity: 0.39
# Epoch: 99/200 | Train Loss: 0.8497, Train Acc: 84.65% | Val Loss: 0.8909, Val Acc: 83.27% | Sparsity: 0.39
# Epoch: 100/200 | Train Loss: 0.8473, Train Acc: 84.89% | Val Loss: 0.9385, Val Acc: 80.31% | Sparsity: 0.40
# Epoch: 101/200 | Train Loss: 0.8484, Train Acc: 84.73% | Val Loss: 1.1359, Val Acc: 71.87% | Sparsity: 0.40
# Epoch: 102/200 | Train Loss: 0.8481, Train Acc: 84.62% | Val Loss: 0.9630, Val Acc: 79.76% | Sparsity: 0.40
# Epoch: 103/200 | Train Loss: 0.8368, Train Acc: 85.34% | Val Loss: 0.9427, Val Acc: 80.51% | Sparsity: 0.41
# Epoch: 104/200 | Train Loss: 0.8433, Train Acc: 85.02% | Val Loss: 1.0232, Val Acc: 77.04% | Sparsity: 0.41
# Epoch: 105/200 | Train Loss: 0.8341, Train Acc: 85.31% | Val Loss: 0.9484, Val Acc: 80.35% | Sparsity: 0.42
# Epoch: 106/200 | Train Loss: 0.8358, Train Acc: 85.33% | Val Loss: 0.9622, Val Acc: 79.67% | Sparsity: 0.42
# Epoch: 107/200 | Train Loss: 0.8300, Train Acc: 85.55% | Val Loss: 0.9435, Val Acc: 80.71% | Sparsity: 0.42
# Epoch: 108/200 | Train Loss: 0.8312, Train Acc: 85.53% | Val Loss: 0.9515, Val Acc: 79.73% | Sparsity: 0.43
# Epoch: 109/200 | Train Loss: 0.8310, Train Acc: 85.29% | Val Loss: 0.9658, Val Acc: 79.47% | Sparsity: 0.43
# Epoch: 110/200 | Train Loss: 0.8230, Train Acc: 85.78% | Val Loss: 0.9735, Val Acc: 79.42% | Sparsity: 0.44
# Epoch: 111/200 | Train Loss: 0.8255, Train Acc: 85.72% | Val Loss: 0.9783, Val Acc: 79.05% | Sparsity: 0.44
# Epoch: 112/200 | Train Loss: 0.8207, Train Acc: 85.92% | Val Loss: 0.9030, Val Acc: 82.16% | Sparsity: 0.44
# Epoch: 113/200 | Train Loss: 0.8205, Train Acc: 86.00% | Val Loss: 0.9417, Val Acc: 80.93% | Sparsity: 0.45
# Epoch: 114/200 | Train Loss: 0.8129, Train Acc: 86.21% | Val Loss: 0.9059, Val Acc: 82.15% | Sparsity: 0.45
# Epoch: 115/200 | Train Loss: 0.8129, Train Acc: 86.28% | Val Loss: 0.9289, Val Acc: 80.89% | Sparsity: 0.46
# Epoch: 116/200 | Train Loss: 0.8140, Train Acc: 86.28% | Val Loss: 0.8877, Val Acc: 82.71% | Sparsity: 0.46
# Epoch: 117/200 | Train Loss: 0.8088, Train Acc: 86.42% | Val Loss: 0.8957, Val Acc: 82.98% | Sparsity: 0.46
# Epoch: 118/200 | Train Loss: 0.8011, Train Acc: 86.93% | Val Loss: 0.9068, Val Acc: 82.00% | Sparsity: 0.47
# Epoch: 119/200 | Train Loss: 0.8087, Train Acc: 86.43% | Val Loss: 0.8918, Val Acc: 82.96% | Sparsity: 0.47
# Epoch: 120/200 | Train Loss: 0.8016, Train Acc: 86.84% | Val Loss: 0.9585, Val Acc: 79.38% | Sparsity: 0.48
# Epoch: 121/200 | Train Loss: 0.8002, Train Acc: 86.74% | Val Loss: 0.8784, Val Acc: 83.78% | Sparsity: 0.48
# Epoch: 122/200 | Train Loss: 0.7962, Train Acc: 87.00% | Val Loss: 0.9076, Val Acc: 81.89% | Sparsity: 0.48
# Epoch: 123/200 | Train Loss: 0.7945, Train Acc: 87.18% | Val Loss: 1.0070, Val Acc: 78.07% | Sparsity: 0.49
# Epoch: 124/200 | Train Loss: 0.7938, Train Acc: 87.11% | Val Loss: 0.8462, Val Acc: 85.09% | Sparsity: 0.49
# Epoch: 125/200 | Train Loss: 0.7916, Train Acc: 87.17% | Val Loss: 0.8874, Val Acc: 83.00% | Sparsity: 0.50
# Epoch: 126/200 | Train Loss: 0.7870, Train Acc: 87.42% | Val Loss: 0.8931, Val Acc: 82.85% | Sparsity: 0.50
# Epoch: 127/200 | Train Loss: 0.7846, Train Acc: 87.58% | Val Loss: 0.8700, Val Acc: 83.24% | Sparsity: 0.50
# Epoch: 128/200 | Train Loss: 0.7832, Train Acc: 87.62% | Val Loss: 1.0104, Val Acc: 77.87% | Sparsity: 0.51
# Epoch: 129/200 | Train Loss: 0.7780, Train Acc: 87.87% | Val Loss: 0.8747, Val Acc: 83.93% | Sparsity: 0.51
# Epoch: 130/200 | Train Loss: 0.7767, Train Acc: 87.93% | Val Loss: 0.8776, Val Acc: 83.35% | Sparsity: 0.52
# Epoch: 131/200 | Train Loss: 0.7709, Train Acc: 88.05% | Val Loss: 0.8771, Val Acc: 82.84% | Sparsity: 0.52
# Epoch: 132/200 | Train Loss: 0.7704, Train Acc: 88.16% | Val Loss: 0.8781, Val Acc: 83.49% | Sparsity: 0.52
# Epoch: 133/200 | Train Loss: 0.7688, Train Acc: 88.26% | Val Loss: 0.8655, Val Acc: 83.95% | Sparsity: 0.53
# Epoch: 134/200 | Train Loss: 0.7668, Train Acc: 88.55% | Val Loss: 0.8489, Val Acc: 84.53% | Sparsity: 0.53
# Epoch: 135/200 | Train Loss: 0.7602, Train Acc: 88.70% | Val Loss: 0.8881, Val Acc: 82.65% | Sparsity: 0.54
# Epoch: 136/200 | Train Loss: 0.7579, Train Acc: 88.63% | Val Loss: 0.8879, Val Acc: 83.40% | Sparsity: 0.54
# Epoch: 137/200 | Train Loss: 0.7597, Train Acc: 88.55% | Val Loss: 0.8388, Val Acc: 85.02% | Sparsity: 0.54
# Epoch: 138/200 | Train Loss: 0.7531, Train Acc: 89.00% | Val Loss: 0.8721, Val Acc: 83.62% | Sparsity: 0.55
# Epoch: 139/200 | Train Loss: 0.7505, Train Acc: 88.98% | Val Loss: 0.8203, Val Acc: 85.71% | Sparsity: 0.55
# Epoch: 140/200 | Train Loss: 0.7467, Train Acc: 89.12% | Val Loss: 0.8511, Val Acc: 84.58% | Sparsity: 0.56
# Epoch: 141/200 | Train Loss: 0.7427, Train Acc: 89.37% | Val Loss: 0.8366, Val Acc: 85.24% | Sparsity: 0.56
# Epoch: 142/200 | Train Loss: 0.7371, Train Acc: 89.61% | Val Loss: 0.8360, Val Acc: 85.09% | Sparsity: 0.56
# Epoch: 143/200 | Train Loss: 0.7405, Train Acc: 89.49% | Val Loss: 0.8506, Val Acc: 84.24% | Sparsity: 0.57
# Epoch: 144/200 | Train Loss: 0.7340, Train Acc: 89.76% | Val Loss: 0.8160, Val Acc: 86.16% | Sparsity: 0.57
# Epoch: 145/200 | Train Loss: 0.7310, Train Acc: 89.82% | Val Loss: 0.8453, Val Acc: 84.51% | Sparsity: 0.58
# Epoch: 146/200 | Train Loss: 0.7292, Train Acc: 90.00% | Val Loss: 0.8192, Val Acc: 86.05% | Sparsity: 0.58
# Epoch: 147/200 | Train Loss: 0.7203, Train Acc: 90.27% | Val Loss: 0.8502, Val Acc: 85.02% | Sparsity: 0.58
# Epoch: 148/200 | Train Loss: 0.7207, Train Acc: 90.44% | Val Loss: 0.8206, Val Acc: 86.24% | Sparsity: 0.59
# Epoch: 149/200 | Train Loss: 0.7147, Train Acc: 90.66% | Val Loss: 0.8542, Val Acc: 84.69% | Sparsity: 0.59
# Epoch: 150/200 | Train Loss: 0.7120, Train Acc: 90.74% | Val Loss: 0.8375, Val Acc: 85.29% | Sparsity: 0.60
# Epoch: 151/200 | Train Loss: 0.7097, Train Acc: 90.85% | Val Loss: 0.7927, Val Acc: 87.09% | Sparsity: 0.60
# Epoch: 152/200 | Train Loss: 0.7080, Train Acc: 90.95% | Val Loss: 0.8228, Val Acc: 86.05% | Sparsity: 0.60
# Epoch: 153/200 | Train Loss: 0.7040, Train Acc: 91.00% | Val Loss: 0.7945, Val Acc: 87.16% | Sparsity: 0.61
# Epoch: 154/200 | Train Loss: 0.6993, Train Acc: 91.44% | Val Loss: 0.7908, Val Acc: 87.27% | Sparsity: 0.61
# Epoch: 155/200 | Train Loss: 0.6935, Train Acc: 91.57% | Val Loss: 0.8401, Val Acc: 85.20% | Sparsity: 0.62
# Epoch: 156/200 | Train Loss: 0.6911, Train Acc: 91.65% | Val Loss: 0.7940, Val Acc: 87.16% | Sparsity: 0.62
# Epoch: 157/200 | Train Loss: 0.6880, Train Acc: 91.72% | Val Loss: 0.8080, Val Acc: 86.58% | Sparsity: 0.62
# Epoch: 158/200 | Train Loss: 0.6843, Train Acc: 92.02% | Val Loss: 0.7758, Val Acc: 87.80% | Sparsity: 0.63
# Epoch: 159/200 | Train Loss: 0.6837, Train Acc: 91.84% | Val Loss: 0.8102, Val Acc: 86.53% | Sparsity: 0.63
# Epoch: 160/200 | Train Loss: 0.6809, Train Acc: 92.04% | Val Loss: 0.7900, Val Acc: 86.75% | Sparsity: 0.64
# Epoch: 161/200 | Train Loss: 0.6745, Train Acc: 92.50% | Val Loss: 0.7741, Val Acc: 87.65% | Sparsity: 0.64
# Epoch: 162/200 | Train Loss: 0.6695, Train Acc: 92.68% | Val Loss: 0.7815, Val Acc: 87.80% | Sparsity: 0.64
# Epoch: 163/200 | Train Loss: 0.6607, Train Acc: 93.01% | Val Loss: 0.7677, Val Acc: 88.07% | Sparsity: 0.65
# Epoch: 164/200 | Train Loss: 0.6585, Train Acc: 93.17% | Val Loss: 0.7812, Val Acc: 87.36% | Sparsity: 0.65
# Epoch: 165/200 | Train Loss: 0.6541, Train Acc: 93.29% | Val Loss: 0.7554, Val Acc: 88.64% | Sparsity: 0.66
# Epoch: 166/200 | Train Loss: 0.6522, Train Acc: 93.40% | Val Loss: 0.7686, Val Acc: 88.62% | Sparsity: 0.66
# Epoch: 167/200 | Train Loss: 0.6439, Train Acc: 93.69% | Val Loss: 0.7541, Val Acc: 88.87% | Sparsity: 0.66
# Epoch: 168/200 | Train Loss: 0.6430, Train Acc: 93.75% | Val Loss: 0.7566, Val Acc: 88.95% | Sparsity: 0.67
# Epoch: 169/200 | Train Loss: 0.6408, Train Acc: 93.90% | Val Loss: 0.7493, Val Acc: 89.27% | Sparsity: 0.67
# Epoch: 170/200 | Train Loss: 0.6381, Train Acc: 94.09% | Val Loss: 0.7361, Val Acc: 89.89% | Sparsity: 0.68
# Epoch: 171/200 | Train Loss: 0.6287, Train Acc: 94.44% | Val Loss: 0.7477, Val Acc: 89.11% | Sparsity: 0.68
# Epoch: 172/200 | Train Loss: 0.6304, Train Acc: 94.38% | Val Loss: 0.7503, Val Acc: 88.96% | Sparsity: 0.68
# Epoch: 173/200 | Train Loss: 0.6231, Train Acc: 94.69% | Val Loss: 0.7558, Val Acc: 88.96% | Sparsity: 0.69
# Epoch: 174/200 | Train Loss: 0.6201, Train Acc: 94.86% | Val Loss: 0.7385, Val Acc: 89.91% | Sparsity: 0.69
# Epoch: 175/200 | Train Loss: 0.6199, Train Acc: 94.78% | Val Loss: 0.7350, Val Acc: 90.02% | Sparsity: 0.70
# Epoch: 176/200 | Train Loss: 0.6128, Train Acc: 95.12% | Val Loss: 0.7342, Val Acc: 89.82% | Sparsity: 0.70
# Epoch: 177/200 | Train Loss: 0.6122, Train Acc: 95.30% | Val Loss: 0.7309, Val Acc: 90.35% | Sparsity: 0.70
# Epoch: 178/200 | Train Loss: 0.6091, Train Acc: 95.30% | Val Loss: 0.7263, Val Acc: 90.24% | Sparsity: 0.71
# Epoch: 179/200 | Train Loss: 0.6028, Train Acc: 95.59% | Val Loss: 0.7238, Val Acc: 90.51% | Sparsity: 0.71
# Epoch: 180/200 | Train Loss: 0.6010, Train Acc: 95.66% | Val Loss: 0.7241, Val Acc: 90.36% | Sparsity: 0.72
# Epoch: 181/200 | Train Loss: 0.5971, Train Acc: 95.93% | Val Loss: 0.7254, Val Acc: 90.55% | Sparsity: 0.72
# Epoch: 182/200 | Train Loss: 0.5951, Train Acc: 96.02% | Val Loss: 0.7235, Val Acc: 90.22% | Sparsity: 0.72
# Epoch: 183/200 | Train Loss: 0.5924, Train Acc: 96.11% | Val Loss: 0.7173, Val Acc: 90.65% | Sparsity: 0.73
# Epoch: 184/200 | Train Loss: 0.5899, Train Acc: 96.23% | Val Loss: 0.7163, Val Acc: 90.85% | Sparsity: 0.73
# Epoch: 185/200 | Train Loss: 0.5924, Train Acc: 96.05% | Val Loss: 0.7193, Val Acc: 90.75% | Sparsity: 0.74
# Epoch: 186/200 | Train Loss: 0.5915, Train Acc: 96.16% | Val Loss: 0.7114, Val Acc: 90.84% | Sparsity: 0.74
# Epoch: 187/200 | Train Loss: 0.5854, Train Acc: 96.41% | Val Loss: 0.7183, Val Acc: 90.78% | Sparsity: 0.74
# Epoch: 188/200 | Train Loss: 0.5822, Train Acc: 96.54% | Val Loss: 0.7131, Val Acc: 90.62% | Sparsity: 0.75
# Epoch: 189/200 | Train Loss: 0.5801, Train Acc: 96.69% | Val Loss: 0.7114, Val Acc: 90.73% | Sparsity: 0.75
# Epoch: 190/200 | Train Loss: 0.5805, Train Acc: 96.62% | Val Loss: 0.7038, Val Acc: 91.35% | Sparsity: 0.76
# Epoch: 191/200 | Train Loss: 0.5784, Train Acc: 96.76% | Val Loss: 0.7041, Val Acc: 91.15% | Sparsity: 0.76
# Epoch: 192/200 | Train Loss: 0.5792, Train Acc: 96.68% | Val Loss: 0.7106, Val Acc: 90.80% | Sparsity: 0.76
# Epoch: 193/200 | Train Loss: 0.5788, Train Acc: 96.68% | Val Loss: 0.6990, Val Acc: 91.45% | Sparsity: 0.77
# Epoch: 194/200 | Train Loss: 0.5747, Train Acc: 96.90% | Val Loss: 0.7168, Val Acc: 90.71% | Sparsity: 0.77
# Epoch: 195/200 | Train Loss: 0.5759, Train Acc: 96.86% | Val Loss: 0.7092, Val Acc: 90.96% | Sparsity: 0.78
# Epoch: 196/200 | Train Loss: 0.5749, Train Acc: 96.96% | Val Loss: 0.7044, Val Acc: 91.02% | Sparsity: 0.78
# Epoch: 197/200 | Train Loss: 0.5748, Train Acc: 96.88% | Val Loss: 0.7001, Val Acc: 91.44% | Sparsity: 0.78
# Epoch: 198/200 | Train Loss: 0.5735, Train Acc: 97.00% | Val Loss: 0.7000, Val Acc: 91.44% | Sparsity: 0.79
# Epoch: 199/200 | Train Loss: 0.5729, Train Acc: 96.96% | Val Loss: 0.7001, Val Acc: 91.44% | Sparsity: 0.79
# Epoch: 200/200 | Train Loss: 0.5736, Train Acc: 96.89% | Val Loss: 0.7051, Val Acc: 91.07% | Sparsity: 0.80
#
# Test Set Evaluation: Loss: 0.6286, Accuracy: 94.89%
# Final Results:
# Final Training Loss: 0.5736
# Final Validation Loss: 0.7051
# Final Training Accuracy: 96.89%
# Final Validation Accuracy: 91.07%
# Final Test Loss: 0.6286
# Final Test Accuracy: 94.89%
