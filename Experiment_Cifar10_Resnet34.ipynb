# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms

# Define the basic block for ResNet
class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_channels, out_channels, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(
            in_channels, out_channels, kernel_size=3, stride=stride, padding=1, bias=False
        )
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.conv2 = nn.Conv2d(
            out_channels, out_channels, kernel_size=3, stride=1, padding=1, bias=False
        )
        self.bn2 = nn.BatchNorm2d(out_channels)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_channels != out_channels:
            self.shortcut = nn.Sequential(
                nn.Conv2d(
                    in_channels, out_channels, kernel_size=1, stride=stride, bias=False
                ),
                nn.BatchNorm2d(out_channels),
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out

# Define ResNet
class DynamicSparseResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):  # For CIFAR-10, num_classes=10
        super(DynamicSparseResNet, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(
            3, 64, kernel_size=3, stride=1, padding=1, bias=False  # CIFAR-10 images have 3 channels
        )
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.linear = nn.Linear(512 * block.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        layers = []
        strides = [stride] + [1] * (num_blocks - 1)
        for s in strides:
            layers.append(block(self.in_planes, planes, s))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))  # Output size: 32x32
        out = self.layer1(out)                 # Output size: 32x32
        out = self.layer2(out)                 # Output size: 16x16
        out = self.layer3(out)                 # Output size: 8x8
        out = self.layer4(out)                 # Output size: 4x4
        out = F.avg_pool2d(out, 4)             # Output size: 1x1
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out

def ResNet34(num_classes=10):
    return DynamicSparseResNet(BasicBlock, [3, 4, 6, 3], num_classes=num_classes)

def initialize_weights(model):
    for m in model.modules():
        if isinstance(m, (nn.Conv2d, nn.Linear)):
            nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
            if m.bias is not None:
                nn.init.zeros_(m.bias)
        elif isinstance(m, nn.BatchNorm2d):
            nn.init.ones_(m.weight)
            nn.init.zeros_(m.bias)

def apply_dynamic_supermask(model, sparsity_rate):
    masks = {}
    for name, param in model.named_parameters():
        if 'weight' in name:
            weight_flat = param.data.abs().flatten()
            k = int(weight_flat.shape[0] * (1 - sparsity_rate))
            if k == 0:
                threshold = torch.max(weight_flat) + 1
            else:
                threshold = torch.topk(weight_flat, k, largest=True, sorted=True)[0][-1]
            mask = (param.data.abs() >= threshold).float()
            masks[name] = mask.view(param.size()).to(param.device)
    return masks

def dynamic_weight_update(model, masks):
    for name, param in model.named_parameters():
        if 'weight' in name and param.grad is not None:
            mask = masks[name]
            param.grad.data.mul_(mask)

def train_with_dynamic_pruning(model, train_loader, val_loader, epochs=200, device='cuda'):
    train_criterion = nn.CrossEntropyLoss(label_smoothing=0.1)
    eval_criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.SGD(
        model.parameters(), lr=0.1, momentum=0.9, weight_decay=5e-4
    )
    scheduler = torch.optim.lr_scheduler.OneCycleLR(
        optimizer, max_lr=0.1, steps_per_epoch=len(train_loader), epochs=epochs
    )

    initial_sparsity = 0.0
    final_sparsity = 0.5  # Reduced final sparsity to 50%
    pruning_start_epoch = 20  # Delay pruning until epoch 20
    sparsity_increment = (final_sparsity - initial_sparsity) / (epochs - pruning_start_epoch)

    train_losses = []
    val_losses = []
    train_acc = []
    val_acc = []

    initialize_weights(model)

    for epoch in range(epochs):
        model.train()
        running_loss = 0
        correct = 0
        total = 0

        if epoch >= pruning_start_epoch:
            current_sparsity = initial_sparsity + sparsity_increment * (epoch - pruning_start_epoch)
            masks = apply_dynamic_supermask(model, current_sparsity)
        else:
            masks = None  # No pruning applied

        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(images)
            loss = train_criterion(outputs, labels)
            loss.backward()

            if masks is not None:
                dynamic_weight_update(model, masks)
            optimizer.step()

            running_loss += loss.item() * images.size(0)
            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()

        train_loss = running_loss / total
        train_accuracy = 100.0 * correct / total

        # Validation
        val_loss, val_accuracy = evaluate(model, val_loader, eval_criterion, device)

        train_losses.append(train_loss)
        val_losses.append(val_loss)
        train_acc.append(train_accuracy)
        val_acc.append(val_accuracy)

        scheduler.step()

        print(
            f"Epoch: {epoch+1}/{epochs}"
            f" | Train Loss: {train_loss:.4f}, Train Acc: {train_accuracy:.2f}%"
            f" | Val Loss: {val_loss:.4f}, Val Acc: {val_accuracy:.2f}%"
            f" | Sparsity: {current_sparsity if epoch >= pruning_start_epoch else 0.0:.2f}"
        )

    return train_losses, val_losses, train_acc, val_acc

def evaluate(model, data_loader, criterion, device):
    model.eval()
    loss_total = 0
    correct = 0
    total = 0

    with torch.no_grad():
        for images, labels in data_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)

            loss_total += loss.item() * images.size(0)
            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()

    avg_loss = loss_total / total
    accuracy = 100.0 * correct / total
    return avg_loss, accuracy

def main():
    torch.manual_seed(42)

    # Training data transformations (with augmentation)
    train_transform = transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(15),
        transforms.ColorJitter(
            brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1
        ),
        transforms.ToTensor(),
        transforms.Normalize(
            (0.4914, 0.4822, 0.4465),
            (0.2470, 0.2435, 0.2616)
        ),
        transforms.RandomErasing(),
    ])

    # Validation and test data transformations (without augmentation)
    test_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize(
            (0.4914, 0.4822, 0.4465),
            (0.2470, 0.2435, 0.2616)
        ),
    ])

    # Load the CIFAR-10 training and test sets separately
    train_dataset_full = torchvision.datasets.CIFAR10(
        root='./data', train=True, download=True, transform=train_transform
    )
    test_dataset = torchvision.datasets.CIFAR10(
        root='./data', train=False, download=True, transform=test_transform
    )

    # Split the training set into training and validation sets
    train_size = int(0.9 * len(train_dataset_full))
    val_size = len(train_dataset_full) - train_size
    train_dataset, val_dataset = torch.utils.data.random_split(
        train_dataset_full, [train_size, val_size]
    )

    # Set up DataLoader for training, validation, and testing data
    batch_size = 128
    train_loader = torch.utils.data.DataLoader(
        train_dataset,
        batch_size=batch_size,
        shuffle=True,
        num_workers=4,
        pin_memory=True,
    )
    val_loader = torch.utils.data.DataLoader(
        val_dataset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=4,
        pin_memory=True,
    )
    test_loader = torch.utils.data.DataLoader(
        test_dataset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=4,
        pin_memory=True,
    )

    # Set device to GPU if available
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model = ResNet34(num_classes=10).to(device)

    # Train and validate the model with dynamic pruning
    train_losses, val_losses, train_acc, val_acc = train_with_dynamic_pruning(
        model, train_loader, val_loader, epochs=200, device=device
    )

    # Plot training results
    import matplotlib.pyplot as plt
    plt.figure(figsize=(12, 4))

    plt.subplot(1, 2, 1)
    plt.plot(train_losses, label='Train Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.title('CIFAR-10 Training and Validation Loss')

    plt.subplot(1, 2, 2)
    plt.plot(train_acc, label='Train Accuracy')
    plt.plot(val_acc, label='Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy (%)')
    plt.legend()
    plt.title('CIFAR-10 Training and Validation Accuracy')

    plt.tight_layout()
    plt.show()

    # Evaluate on the test set
    eval_criterion = nn.CrossEntropyLoss()
    test_loss, test_accuracy = evaluate(model, test_loader, eval_criterion, device)

    # Print final metrics
    print("\nFinal Results:")
    print(f"Final Training Loss: {train_losses[-1]:.4f}")
    print(f"Final Validation Loss: {val_losses[-1]:.4f}")
    print(f"Final Training Accuracy: {train_acc[-1]:.2f}%")
    print(f"Final Validation Accuracy: {val_acc[-1]:.2f}%")
    print(f"Final Test Loss: {test_loss:.4f}")
    print(f"Final Test Accuracy: {test_accuracy:.2f}%")

if __name__ == "__main__":
    main()
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170M/170M [00:13<00:00, 13.0MB/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
# Epoch: 1/200 | Train Loss: 2.7327, Train Acc: 26.36% | Val Loss: 2.4021, Val Acc: 33.86% | Sparsity: 0.00
# Epoch: 2/200 | Train Loss: 2.1353, Train Acc: 35.83% | Val Loss: 2.0983, Val Acc: 38.14% | Sparsity: 0.00
# Epoch: 3/200 | Train Loss: 1.9481, Train Acc: 40.86% | Val Loss: 2.7437, Val Acc: 43.02% | Sparsity: 0.00
# Epoch: 4/200 | Train Loss: 1.8101, Train Acc: 45.51% | Val Loss: 2.1805, Val Acc: 45.36% | Sparsity: 0.00
# Epoch: 5/200 | Train Loss: 1.7137, Train Acc: 49.45% | Val Loss: 1.4528, Val Acc: 49.70% | Sparsity: 0.00
# Epoch: 6/200 | Train Loss: 1.6567, Train Acc: 51.92% | Val Loss: 1.4264, Val Acc: 53.00% | Sparsity: 0.00
# Epoch: 7/200 | Train Loss: 1.6289, Train Acc: 53.20% | Val Loss: 1.4313, Val Acc: 55.78% | Sparsity: 0.00
# Epoch: 8/200 | Train Loss: 1.5554, Train Acc: 56.00% | Val Loss: 1.2459, Val Acc: 55.78% | Sparsity: 0.00
# Epoch: 9/200 | Train Loss: 1.4896, Train Acc: 57.77% | Val Loss: 1.4148, Val Acc: 59.20% | Sparsity: 0.00
# Epoch: 10/200 | Train Loss: 1.4399, Train Acc: 60.40% | Val Loss: 2.5907, Val Acc: 48.24% | Sparsity: 0.00
# Epoch: 11/200 | Train Loss: 1.4668, Train Acc: 59.25% | Val Loss: 1.3794, Val Acc: 59.54% | Sparsity: 0.00
# Epoch: 12/200 | Train Loss: 1.4371, Train Acc: 60.90% | Val Loss: 1.2624, Val Acc: 61.38% | Sparsity: 0.00
# Epoch: 13/200 | Train Loss: 1.3425, Train Acc: 64.08% | Val Loss: 1.1125, Val Acc: 63.74% | Sparsity: 0.00
# Epoch: 14/200 | Train Loss: 1.2801, Train Acc: 66.70% | Val Loss: 1.0105, Val Acc: 66.42% | Sparsity: 0.00
# Epoch: 15/200 | Train Loss: 1.2356, Train Acc: 68.42% | Val Loss: 1.2163, Val Acc: 68.64% | Sparsity: 0.00
# Epoch: 16/200 | Train Loss: 1.2490, Train Acc: 68.99% | Val Loss: 1.4023, Val Acc: 67.94% | Sparsity: 0.00
# Epoch: 17/200 | Train Loss: 1.1788, Train Acc: 71.00% | Val Loss: 0.9317, Val Acc: 69.72% | Sparsity: 0.00
# Epoch: 18/200 | Train Loss: 1.1533, Train Acc: 71.88% | Val Loss: 1.0584, Val Acc: 70.28% | Sparsity: 0.00
# Epoch: 19/200 | Train Loss: 1.1221, Train Acc: 73.30% | Val Loss: 0.8985, Val Acc: 71.76% | Sparsity: 0.00
# Epoch: 20/200 | Train Loss: 1.0935, Train Acc: 74.20% | Val Loss: 0.9029, Val Acc: 71.08% | Sparsity: 0.00
# Epoch: 21/200 | Train Loss: 1.0747, Train Acc: 75.05% | Val Loss: 0.8360, Val Acc: 73.04% | Sparsity: 0.00
# Epoch: 22/200 | Train Loss: 1.0617, Train Acc: 75.82% | Val Loss: 0.8669, Val Acc: 73.80% | Sparsity: 0.00
# Epoch: 23/200 | Train Loss: 1.0316, Train Acc: 76.99% | Val Loss: 0.9616, Val Acc: 71.28% | Sparsity: 0.01
# Epoch: 24/200 | Train Loss: 1.0316, Train Acc: 77.08% | Val Loss: 0.9017, Val Acc: 75.18% | Sparsity: 0.01
# Epoch: 25/200 | Train Loss: 1.0080, Train Acc: 78.07% | Val Loss: 0.7791, Val Acc: 75.66% | Sparsity: 0.01
# Epoch: 26/200 | Train Loss: 0.9961, Train Acc: 78.55% | Val Loss: 0.7520, Val Acc: 77.00% | Sparsity: 0.01
# Epoch: 27/200 | Train Loss: 0.9781, Train Acc: 79.00% | Val Loss: 0.7563, Val Acc: 76.90% | Sparsity: 0.02
# Epoch: 28/200 | Train Loss: 0.9653, Train Acc: 79.72% | Val Loss: 1.0758, Val Acc: 72.46% | Sparsity: 0.02
# Epoch: 29/200 | Train Loss: 0.9510, Train Acc: 80.32% | Val Loss: 0.6837, Val Acc: 78.18% | Sparsity: 0.02
# Epoch: 30/200 | Train Loss: 0.9359, Train Acc: 81.02% | Val Loss: 0.7193, Val Acc: 76.40% | Sparsity: 0.03
# Epoch: 31/200 | Train Loss: 0.9334, Train Acc: 81.31% | Val Loss: 0.7223, Val Acc: 76.34% | Sparsity: 0.03
# Epoch: 32/200 | Train Loss: 0.9208, Train Acc: 81.71% | Val Loss: 0.6966, Val Acc: 78.04% | Sparsity: 0.03
# Epoch: 33/200 | Train Loss: 0.9126, Train Acc: 82.17% | Val Loss: 0.6466, Val Acc: 79.66% | Sparsity: 0.03
# Epoch: 34/200 | Train Loss: 0.9021, Train Acc: 82.64% | Val Loss: 0.7201, Val Acc: 77.62% | Sparsity: 0.04
# Epoch: 35/200 | Train Loss: 0.8991, Train Acc: 82.52% | Val Loss: 0.6853, Val Acc: 78.06% | Sparsity: 0.04
# Epoch: 36/200 | Train Loss: 0.8870, Train Acc: 83.19% | Val Loss: 0.7198, Val Acc: 78.22% | Sparsity: 0.04
# Epoch: 37/200 | Train Loss: 0.8806, Train Acc: 83.53% | Val Loss: 0.6571, Val Acc: 80.02% | Sparsity: 0.04
# Epoch: 38/200 | Train Loss: 0.8722, Train Acc: 83.68% | Val Loss: 0.6416, Val Acc: 80.22% | Sparsity: 0.05
# Epoch: 39/200 | Train Loss: 0.8590, Train Acc: 84.27% | Val Loss: 0.6051, Val Acc: 81.18% | Sparsity: 0.05
# Epoch: 40/200 | Train Loss: 0.8521, Train Acc: 84.71% | Val Loss: 0.6621, Val Acc: 79.00% | Sparsity: 0.05
# Epoch: 41/200 | Train Loss: 0.8476, Train Acc: 84.75% | Val Loss: 0.6014, Val Acc: 81.22% | Sparsity: 0.06
# Epoch: 42/200 | Train Loss: 0.8450, Train Acc: 84.93% | Val Loss: 0.5650, Val Acc: 82.02% | Sparsity: 0.06
# Epoch: 43/200 | Train Loss: 0.8346, Train Acc: 85.30% | Val Loss: 0.6078, Val Acc: 81.04% | Sparsity: 0.06
# Epoch: 44/200 | Train Loss: 0.8290, Train Acc: 85.54% | Val Loss: 0.6325, Val Acc: 80.32% | Sparsity: 0.06
# Epoch: 45/200 | Train Loss: 0.8235, Train Acc: 85.81% | Val Loss: 0.5922, Val Acc: 81.70% | Sparsity: 0.07
# Epoch: 46/200 | Train Loss: 0.8202, Train Acc: 85.94% | Val Loss: 0.5848, Val Acc: 82.06% | Sparsity: 0.07
# Epoch: 47/200 | Train Loss: 0.8172, Train Acc: 86.22% | Val Loss: 0.5950, Val Acc: 82.08% | Sparsity: 0.07
# Epoch: 48/200 | Train Loss: 0.8056, Train Acc: 86.52% | Val Loss: 0.5964, Val Acc: 81.54% | Sparsity: 0.07
# Epoch: 49/200 | Train Loss: 0.8010, Train Acc: 86.92% | Val Loss: 0.5936, Val Acc: 81.52% | Sparsity: 0.08
# Epoch: 50/200 | Train Loss: 0.7996, Train Acc: 86.92% | Val Loss: 0.5615, Val Acc: 82.74% | Sparsity: 0.08
# Epoch: 51/200 | Train Loss: 0.7946, Train Acc: 87.24% | Val Loss: 0.5562, Val Acc: 83.10% | Sparsity: 0.08
# Epoch: 52/200 | Train Loss: 0.7899, Train Acc: 87.23% | Val Loss: 0.5515, Val Acc: 82.76% | Sparsity: 0.09
# Epoch: 53/200 | Train Loss: 0.7832, Train Acc: 87.70% | Val Loss: 0.5433, Val Acc: 83.30% | Sparsity: 0.09
# Epoch: 54/200 | Train Loss: 0.7788, Train Acc: 87.93% | Val Loss: 0.5582, Val Acc: 83.02% | Sparsity: 0.09
# Epoch: 55/200 | Train Loss: 0.7757, Train Acc: 88.02% | Val Loss: 0.5737, Val Acc: 82.40% | Sparsity: 0.09
# Epoch: 56/200 | Train Loss: 0.7695, Train Acc: 88.13% | Val Loss: 0.5530, Val Acc: 83.58% | Sparsity: 0.10
# Epoch: 57/200 | Train Loss: 0.7688, Train Acc: 88.06% | Val Loss: 0.5869, Val Acc: 81.46% | Sparsity: 0.10
# Epoch: 58/200 | Train Loss: 0.7637, Train Acc: 88.54% | Val Loss: 0.5466, Val Acc: 82.90% | Sparsity: 0.10
# Epoch: 59/200 | Train Loss: 0.7575, Train Acc: 88.66% | Val Loss: 0.5187, Val Acc: 84.26% | Sparsity: 0.11
# Epoch: 60/200 | Train Loss: 0.7573, Train Acc: 88.66% | Val Loss: 0.5378, Val Acc: 83.48% | Sparsity: 0.11
# Epoch: 61/200 | Train Loss: 0.7532, Train Acc: 88.89% | Val Loss: 0.5513, Val Acc: 83.34% | Sparsity: 0.11
# Epoch: 62/200 | Train Loss: 0.7546, Train Acc: 88.88% | Val Loss: 0.5618, Val Acc: 82.50% | Sparsity: 0.11
# Epoch: 63/200 | Train Loss: 0.7465, Train Acc: 89.19% | Val Loss: 0.5623, Val Acc: 83.22% | Sparsity: 0.12
# Epoch: 64/200 | Train Loss: 0.7413, Train Acc: 89.53% | Val Loss: 0.5387, Val Acc: 83.40% | Sparsity: 0.12
# Epoch: 65/200 | Train Loss: 0.7390, Train Acc: 89.56% | Val Loss: 0.5176, Val Acc: 84.06% | Sparsity: 0.12
# Epoch: 66/200 | Train Loss: 0.7362, Train Acc: 89.52% | Val Loss: 0.5245, Val Acc: 84.06% | Sparsity: 0.12
# Epoch: 67/200 | Train Loss: 0.7323, Train Acc: 89.90% | Val Loss: 0.5104, Val Acc: 84.52% | Sparsity: 0.13
# Epoch: 68/200 | Train Loss: 0.7326, Train Acc: 89.75% | Val Loss: 0.5031, Val Acc: 85.06% | Sparsity: 0.13
# Epoch: 69/200 | Train Loss: 0.7293, Train Acc: 89.89% | Val Loss: 0.4836, Val Acc: 85.04% | Sparsity: 0.13
# Epoch: 70/200 | Train Loss: 0.7223, Train Acc: 90.05% | Val Loss: 0.4929, Val Acc: 85.26% | Sparsity: 0.14
# Epoch: 71/200 | Train Loss: 0.7229, Train Acc: 90.14% | Val Loss: 0.4839, Val Acc: 85.40% | Sparsity: 0.14
# Epoch: 72/200 | Train Loss: 0.7138, Train Acc: 90.68% | Val Loss: 0.4934, Val Acc: 85.26% | Sparsity: 0.14
# Epoch: 73/200 | Train Loss: 0.7163, Train Acc: 90.44% | Val Loss: 0.5262, Val Acc: 83.88% | Sparsity: 0.14
# Epoch: 74/200 | Train Loss: 0.7156, Train Acc: 90.56% | Val Loss: 0.5275, Val Acc: 84.00% | Sparsity: 0.15
# Epoch: 75/200 | Train Loss: 0.7088, Train Acc: 90.79% | Val Loss: 0.5101, Val Acc: 85.16% | Sparsity: 0.15
# Epoch: 76/200 | Train Loss: 0.7096, Train Acc: 90.66% | Val Loss: 0.5174, Val Acc: 84.40% | Sparsity: 0.15
# Epoch: 77/200 | Train Loss: 0.7073, Train Acc: 90.87% | Val Loss: 0.4812, Val Acc: 85.86% | Sparsity: 0.16
# Epoch: 78/200 | Train Loss: 0.7047, Train Acc: 91.00% | Val Loss: 0.4935, Val Acc: 85.20% | Sparsity: 0.16
# Epoch: 79/200 | Train Loss: 0.7049, Train Acc: 90.96% | Val Loss: 0.4940, Val Acc: 85.20% | Sparsity: 0.16
# Epoch: 80/200 | Train Loss: 0.7008, Train Acc: 91.20% | Val Loss: 0.5307, Val Acc: 83.98% | Sparsity: 0.16
# Epoch: 81/200 | Train Loss: 0.6974, Train Acc: 91.40% | Val Loss: 0.5102, Val Acc: 84.42% | Sparsity: 0.17
# Epoch: 82/200 | Train Loss: 0.6968, Train Acc: 91.23% | Val Loss: 0.4746, Val Acc: 85.98% | Sparsity: 0.17
# Epoch: 83/200 | Train Loss: 0.6927, Train Acc: 91.46% | Val Loss: 0.4720, Val Acc: 86.00% | Sparsity: 0.17
# Epoch: 84/200 | Train Loss: 0.6949, Train Acc: 91.46% | Val Loss: 0.4966, Val Acc: 84.82% | Sparsity: 0.18
# Epoch: 85/200 | Train Loss: 0.6932, Train Acc: 91.42% | Val Loss: 0.4849, Val Acc: 85.08% | Sparsity: 0.18
# Epoch: 86/200 | Train Loss: 0.6876, Train Acc: 91.90% | Val Loss: 0.4485, Val Acc: 87.22% | Sparsity: 0.18
# Epoch: 87/200 | Train Loss: 0.6898, Train Acc: 91.63% | Val Loss: 0.4634, Val Acc: 86.66% | Sparsity: 0.18
# Epoch: 88/200 | Train Loss: 0.6872, Train Acc: 91.65% | Val Loss: 0.4647, Val Acc: 86.42% | Sparsity: 0.19
# Epoch: 89/200 | Train Loss: 0.6864, Train Acc: 91.86% | Val Loss: 0.4834, Val Acc: 85.44% | Sparsity: 0.19
# Epoch: 90/200 | Train Loss: 0.6854, Train Acc: 91.79% | Val Loss: 0.4715, Val Acc: 86.04% | Sparsity: 0.19
# Epoch: 91/200 | Train Loss: 0.6805, Train Acc: 92.11% | Val Loss: 0.4910, Val Acc: 85.60% | Sparsity: 0.19
# Epoch: 92/200 | Train Loss: 0.6865, Train Acc: 91.81% | Val Loss: 0.4738, Val Acc: 86.58% | Sparsity: 0.20
# Epoch: 93/200 | Train Loss: 0.6817, Train Acc: 92.06% | Val Loss: 0.4529, Val Acc: 86.60% | Sparsity: 0.20
# Epoch: 94/200 | Train Loss: 0.6764, Train Acc: 92.27% | Val Loss: 0.4631, Val Acc: 85.94% | Sparsity: 0.20
# Epoch: 95/200 | Train Loss: 0.6785, Train Acc: 92.02% | Val Loss: 0.4874, Val Acc: 85.96% | Sparsity: 0.21
# Epoch: 96/200 | Train Loss: 0.6757, Train Acc: 92.24% | Val Loss: 0.4742, Val Acc: 85.52% | Sparsity: 0.21
# Epoch: 97/200 | Train Loss: 0.6747, Train Acc: 92.28% | Val Loss: 0.4744, Val Acc: 86.40% | Sparsity: 0.21
# Epoch: 98/200 | Train Loss: 0.6732, Train Acc: 92.31% | Val Loss: 0.4811, Val Acc: 85.88% | Sparsity: 0.21
# Epoch: 99/200 | Train Loss: 0.6740, Train Acc: 92.27% | Val Loss: 0.4769, Val Acc: 85.90% | Sparsity: 0.22
# Epoch: 100/200 | Train Loss: 0.6706, Train Acc: 92.50% | Val Loss: 0.4601, Val Acc: 86.72% | Sparsity: 0.22
# Epoch: 101/200 | Train Loss: 0.6704, Train Acc: 92.44% | Val Loss: 0.4580, Val Acc: 86.68% | Sparsity: 0.22
# Epoch: 102/200 | Train Loss: 0.6671, Train Acc: 92.75% | Val Loss: 0.4538, Val Acc: 86.82% | Sparsity: 0.23
# Epoch: 103/200 | Train Loss: 0.6637, Train Acc: 92.76% | Val Loss: 0.4637, Val Acc: 86.56% | Sparsity: 0.23
# Epoch: 104/200 | Train Loss: 0.6664, Train Acc: 92.64% | Val Loss: 0.4566, Val Acc: 86.74% | Sparsity: 0.23
# Epoch: 105/200 | Train Loss: 0.6664, Train Acc: 92.66% | Val Loss: 0.4766, Val Acc: 85.80% | Sparsity: 0.23
# Epoch: 106/200 | Train Loss: 0.6646, Train Acc: 92.68% | Val Loss: 0.4889, Val Acc: 86.12% | Sparsity: 0.24
# Epoch: 107/200 | Train Loss: 0.6635, Train Acc: 92.80% | Val Loss: 0.4488, Val Acc: 87.00% | Sparsity: 0.24
# Epoch: 108/200 | Train Loss: 0.6651, Train Acc: 92.64% | Val Loss: 0.4924, Val Acc: 85.38% | Sparsity: 0.24
# Epoch: 109/200 | Train Loss: 0.6621, Train Acc: 92.85% | Val Loss: 0.4854, Val Acc: 86.06% | Sparsity: 0.24
# Epoch: 110/200 | Train Loss: 0.6606, Train Acc: 92.90% | Val Loss: 0.4853, Val Acc: 85.82% | Sparsity: 0.25
# Epoch: 111/200 | Train Loss: 0.6559, Train Acc: 93.00% | Val Loss: 0.4676, Val Acc: 85.92% | Sparsity: 0.25
# Epoch: 112/200 | Train Loss: 0.6593, Train Acc: 92.97% | Val Loss: 0.4546, Val Acc: 87.02% | Sparsity: 0.25
# Epoch: 113/200 | Train Loss: 0.6568, Train Acc: 93.07% | Val Loss: 0.4536, Val Acc: 86.68% | Sparsity: 0.26
# Epoch: 114/200 | Train Loss: 0.6596, Train Acc: 93.11% | Val Loss: 0.4705, Val Acc: 86.34% | Sparsity: 0.26
# Epoch: 115/200 | Train Loss: 0.6575, Train Acc: 93.07% | Val Loss: 0.4738, Val Acc: 86.28% | Sparsity: 0.26
# Epoch: 116/200 | Train Loss: 0.6515, Train Acc: 93.43% | Val Loss: 0.4716, Val Acc: 86.52% | Sparsity: 0.26
# Epoch: 117/200 | Train Loss: 0.6585, Train Acc: 92.98% | Val Loss: 0.4800, Val Acc: 86.06% | Sparsity: 0.27
# Epoch: 118/200 | Train Loss: 0.6564, Train Acc: 93.19% | Val Loss: 0.4498, Val Acc: 86.96% | Sparsity: 0.27
# Epoch: 119/200 | Train Loss: 0.6542, Train Acc: 93.22% | Val Loss: 0.5087, Val Acc: 85.48% | Sparsity: 0.27
# Epoch: 120/200 | Train Loss: 0.6524, Train Acc: 93.29% | Val Loss: 0.4609, Val Acc: 86.54% | Sparsity: 0.28
# Epoch: 121/200 | Train Loss: 0.6503, Train Acc: 93.42% | Val Loss: 0.4610, Val Acc: 86.84% | Sparsity: 0.28
# Epoch: 122/200 | Train Loss: 0.6517, Train Acc: 93.24% | Val Loss: 0.4953, Val Acc: 85.32% | Sparsity: 0.28
# Epoch: 123/200 | Train Loss: 0.6518, Train Acc: 93.31% | Val Loss: 0.5088, Val Acc: 85.74% | Sparsity: 0.28
# Epoch: 124/200 | Train Loss: 0.6510, Train Acc: 93.38% | Val Loss: 0.4711, Val Acc: 86.30% | Sparsity: 0.29
# Epoch: 125/200 | Train Loss: 0.6504, Train Acc: 93.49% | Val Loss: 0.4628, Val Acc: 86.80% | Sparsity: 0.29
# Epoch: 126/200 | Train Loss: 0.6494, Train Acc: 93.35% | Val Loss: 0.4677, Val Acc: 86.72% | Sparsity: 0.29
# Epoch: 127/200 | Train Loss: 0.6533, Train Acc: 93.36% | Val Loss: 0.4726, Val Acc: 86.48% | Sparsity: 0.29
# Epoch: 128/200 | Train Loss: 0.6489, Train Acc: 93.42% | Val Loss: 0.4804, Val Acc: 86.56% | Sparsity: 0.30
# Epoch: 129/200 | Train Loss: 0.6480, Train Acc: 93.52% | Val Loss: 0.4272, Val Acc: 87.60% | Sparsity: 0.30
# Epoch: 130/200 | Train Loss: 0.6472, Train Acc: 93.58% | Val Loss: 0.4727, Val Acc: 86.76% | Sparsity: 0.30
# Epoch: 131/200 | Train Loss: 0.6478, Train Acc: 93.54% | Val Loss: 0.4471, Val Acc: 87.34% | Sparsity: 0.31
# Epoch: 132/200 | Train Loss: 0.6490, Train Acc: 93.39% | Val Loss: 0.4406, Val Acc: 87.02% | Sparsity: 0.31
# Epoch: 133/200 | Train Loss: 0.6405, Train Acc: 93.76% | Val Loss: 0.4541, Val Acc: 87.32% | Sparsity: 0.31
# Epoch: 134/200 | Train Loss: 0.6512, Train Acc: 93.30% | Val Loss: 0.4395, Val Acc: 87.56% | Sparsity: 0.31
# Epoch: 135/200 | Train Loss: 0.6469, Train Acc: 93.53% | Val Loss: 0.4863, Val Acc: 86.16% | Sparsity: 0.32
# Epoch: 136/200 | Train Loss: 0.6436, Train Acc: 93.57% | Val Loss: 0.4758, Val Acc: 86.46% | Sparsity: 0.32
# Epoch: 137/200 | Train Loss: 0.6423, Train Acc: 93.73% | Val Loss: 0.4687, Val Acc: 86.90% | Sparsity: 0.32
# Epoch: 138/200 | Train Loss: 0.6395, Train Acc: 93.84% | Val Loss: 0.4912, Val Acc: 85.94% | Sparsity: 0.33
# Epoch: 139/200 | Train Loss: 0.6446, Train Acc: 93.63% | Val Loss: 0.4678, Val Acc: 86.22% | Sparsity: 0.33
# Epoch: 140/200 | Train Loss: 0.6444, Train Acc: 93.54% | Val Loss: 0.4351, Val Acc: 87.74% | Sparsity: 0.33
# Epoch: 141/200 | Train Loss: 0.6434, Train Acc: 93.74% | Val Loss: 0.4867, Val Acc: 85.78% | Sparsity: 0.33
# Epoch: 142/200 | Train Loss: 0.6438, Train Acc: 93.68% | Val Loss: 0.4358, Val Acc: 87.74% | Sparsity: 0.34
# Epoch: 143/200 | Train Loss: 0.6415, Train Acc: 93.74% | Val Loss: 0.4586, Val Acc: 87.04% | Sparsity: 0.34
# Epoch: 144/200 | Train Loss: 0.6423, Train Acc: 93.76% | Val Loss: 0.4252, Val Acc: 88.10% | Sparsity: 0.34
# Epoch: 145/200 | Train Loss: 0.6410, Train Acc: 93.90% | Val Loss: 0.4506, Val Acc: 86.92% | Sparsity: 0.34
# Epoch: 146/200 | Train Loss: 0.6452, Train Acc: 93.41% | Val Loss: 0.4469, Val Acc: 87.56% | Sparsity: 0.35
# Epoch: 147/200 | Train Loss: 0.6422, Train Acc: 93.80% | Val Loss: 0.4409, Val Acc: 87.62% | Sparsity: 0.35
# Epoch: 148/200 | Train Loss: 0.6356, Train Acc: 93.94% | Val Loss: 0.4650, Val Acc: 86.36% | Sparsity: 0.35
# Epoch: 149/200 | Train Loss: 0.6429, Train Acc: 93.63% | Val Loss: 0.4470, Val Acc: 87.52% | Sparsity: 0.36
# Epoch: 150/200 | Train Loss: 0.6387, Train Acc: 93.92% | Val Loss: 0.4532, Val Acc: 87.08% | Sparsity: 0.36
# Epoch: 151/200 | Train Loss: 0.6381, Train Acc: 93.99% | Val Loss: 0.4517, Val Acc: 87.18% | Sparsity: 0.36
# Epoch: 152/200 | Train Loss: 0.6398, Train Acc: 93.86% | Val Loss: 0.4704, Val Acc: 86.80% | Sparsity: 0.36
# Epoch: 153/200 | Train Loss: 0.6413, Train Acc: 93.75% | Val Loss: 0.4407, Val Acc: 87.24% | Sparsity: 0.37
# Epoch: 154/200 | Train Loss: 0.6376, Train Acc: 94.05% | Val Loss: 0.4534, Val Acc: 87.18% | Sparsity: 0.37
# Epoch: 155/200 | Train Loss: 0.6391, Train Acc: 93.91% | Val Loss: 0.4588, Val Acc: 86.88% | Sparsity: 0.37
# Epoch: 156/200 | Train Loss: 0.6413, Train Acc: 93.74% | Val Loss: 0.4662, Val Acc: 86.90% | Sparsity: 0.38
# Epoch: 157/200 | Train Loss: 0.6385, Train Acc: 93.91% | Val Loss: 0.4597, Val Acc: 86.70% | Sparsity: 0.38
# Epoch: 158/200 | Train Loss: 0.6385, Train Acc: 93.97% | Val Loss: 0.4372, Val Acc: 87.74% | Sparsity: 0.38
# Epoch: 159/200 | Train Loss: 0.6380, Train Acc: 93.88% | Val Loss: 0.4354, Val Acc: 87.96% | Sparsity: 0.38
# Epoch: 160/200 | Train Loss: 0.6337, Train Acc: 94.17% | Val Loss: 0.4658, Val Acc: 86.64% | Sparsity: 0.39
# Epoch: 161/200 | Train Loss: 0.6383, Train Acc: 93.97% | Val Loss: 0.4633, Val Acc: 86.96% | Sparsity: 0.39
# Epoch: 162/200 | Train Loss: 0.6354, Train Acc: 94.13% | Val Loss: 0.4572, Val Acc: 87.18% | Sparsity: 0.39
# Epoch: 163/200 | Train Loss: 0.6357, Train Acc: 93.99% | Val Loss: 0.4593, Val Acc: 86.58% | Sparsity: 0.39
# Epoch: 164/200 | Train Loss: 0.6368, Train Acc: 94.03% | Val Loss: 0.4460, Val Acc: 87.38% | Sparsity: 0.40
# Epoch: 165/200 | Train Loss: 0.6336, Train Acc: 94.10% | Val Loss: 0.4394, Val Acc: 87.92% | Sparsity: 0.40
# Epoch: 166/200 | Train Loss: 0.6341, Train Acc: 94.17% | Val Loss: 0.4421, Val Acc: 87.34% | Sparsity: 0.40
# Epoch: 167/200 | Train Loss: 0.6338, Train Acc: 94.10% | Val Loss: 0.4661, Val Acc: 86.78% | Sparsity: 0.41
# Epoch: 168/200 | Train Loss: 0.6357, Train Acc: 94.02% | Val Loss: 0.4367, Val Acc: 87.66% | Sparsity: 0.41
# Epoch: 169/200 | Train Loss: 0.6392, Train Acc: 93.89% | Val Loss: 0.4576, Val Acc: 87.20% | Sparsity: 0.41
# Epoch: 170/200 | Train Loss: 0.6348, Train Acc: 94.08% | Val Loss: 0.4604, Val Acc: 87.40% | Sparsity: 0.41
# Epoch: 171/200 | Train Loss: 0.6340, Train Acc: 94.21% | Val Loss: 0.4625, Val Acc: 87.38% | Sparsity: 0.42
# Epoch: 172/200 | Train Loss: 0.6371, Train Acc: 93.99% | Val Loss: 0.4409, Val Acc: 87.70% | Sparsity: 0.42
# Epoch: 173/200 | Train Loss: 0.6326, Train Acc: 94.26% | Val Loss: 0.4656, Val Acc: 87.00% | Sparsity: 0.42
# Epoch: 174/200 | Train Loss: 0.6333, Train Acc: 94.17% | Val Loss: 0.4762, Val Acc: 86.48% | Sparsity: 0.42
# Epoch: 175/200 | Train Loss: 0.6368, Train Acc: 94.04% | Val Loss: 0.4420, Val Acc: 87.70% | Sparsity: 0.43
# Epoch: 176/200 | Train Loss: 0.6354, Train Acc: 94.09% | Val Loss: 0.4392, Val Acc: 87.18% | Sparsity: 0.43
# Epoch: 177/200 | Train Loss: 0.6345, Train Acc: 94.05% | Val Loss: 0.4479, Val Acc: 87.68% | Sparsity: 0.43
# Epoch: 178/200 | Train Loss: 0.6355, Train Acc: 93.98% | Val Loss: 0.4336, Val Acc: 87.86% | Sparsity: 0.44
# Epoch: 179/200 | Train Loss: 0.6366, Train Acc: 93.94% | Val Loss: 0.4426, Val Acc: 86.94% | Sparsity: 0.44
# Epoch: 180/200 | Train Loss: 0.6357, Train Acc: 93.98% | Val Loss: 0.4488, Val Acc: 87.36% | Sparsity: 0.44
# Epoch: 181/200 | Train Loss: 0.6382, Train Acc: 94.00% | Val Loss: 0.4365, Val Acc: 87.98% | Sparsity: 0.44
# Epoch: 182/200 | Train Loss: 0.6347, Train Acc: 94.08% | Val Loss: 0.5021, Val Acc: 85.60% | Sparsity: 0.45
# Epoch: 183/200 | Train Loss: 0.6324, Train Acc: 94.21% | Val Loss: 0.4611, Val Acc: 86.72% | Sparsity: 0.45
# Epoch: 184/200 | Train Loss: 0.6339, Train Acc: 94.12% | Val Loss: 0.4549, Val Acc: 87.10% | Sparsity: 0.45
# Epoch: 185/200 | Train Loss: 0.6363, Train Acc: 94.03% | Val Loss: 0.5014, Val Acc: 85.56% | Sparsity: 0.46
# Epoch: 186/200 | Train Loss: 0.6336, Train Acc: 94.17% | Val Loss: 0.4461, Val Acc: 87.24% | Sparsity: 0.46
# Epoch: 187/200 | Train Loss: 0.6363, Train Acc: 93.95% | Val Loss: 0.4837, Val Acc: 86.68% | Sparsity: 0.46
# Epoch: 188/200 | Train Loss: 0.6364, Train Acc: 93.97% | Val Loss: 0.4619, Val Acc: 86.40% | Sparsity: 0.46
# Epoch: 189/200 | Train Loss: 0.6346, Train Acc: 94.07% | Val Loss: 0.4469, Val Acc: 87.78% | Sparsity: 0.47
# Epoch: 190/200 | Train Loss: 0.6366, Train Acc: 94.01% | Val Loss: 0.4461, Val Acc: 87.32% | Sparsity: 0.47
# Epoch: 191/200 | Train Loss: 0.6370, Train Acc: 94.00% | Val Loss: 0.4649, Val Acc: 86.32% | Sparsity: 0.47
# Epoch: 192/200 | Train Loss: 0.6318, Train Acc: 94.23% | Val Loss: 0.4956, Val Acc: 86.38% | Sparsity: 0.48
# Epoch: 193/200 | Train Loss: 0.6331, Train Acc: 94.25% | Val Loss: 0.4548, Val Acc: 87.00% | Sparsity: 0.48
# Epoch: 194/200 | Train Loss: 0.6381, Train Acc: 93.92% | Val Loss: 0.4636, Val Acc: 86.64% | Sparsity: 0.48
# Epoch: 195/200 | Train Loss: 0.6336, Train Acc: 94.10% | Val Loss: 0.4722, Val Acc: 86.84% | Sparsity: 0.48
# Epoch: 196/200 | Train Loss: 0.6365, Train Acc: 93.84% | Val Loss: 0.4576, Val Acc: 86.90% | Sparsity: 0.49
# Epoch: 197/200 | Train Loss: 0.6364, Train Acc: 94.04% | Val Loss: 0.4719, Val Acc: 87.10% | Sparsity: 0.49
# Epoch: 198/200 | Train Loss: 0.6369, Train Acc: 93.94% | Val Loss: 0.4897, Val Acc: 86.26% | Sparsity: 0.49
# Epoch: 199/200 | Train Loss: 0.6374, Train Acc: 93.95% | Val Loss: 0.4304, Val Acc: 87.70% | Sparsity: 0.49
# Epoch: 200/200 | Train Loss: 0.6409, Train Acc: 93.79% | Val Loss: 0.4689, Val Acc: 86.32% | Sparsity: 0.50
# Final Results:
# Final Training Loss: 0.6409
# Final Validation Loss: 0.4689
# Final Training Accuracy: 93.79%
# Final Validation Accuracy: 86.32%
# Final Test Loss: 0.3348
# Final Test Accuracy: 91.75%
