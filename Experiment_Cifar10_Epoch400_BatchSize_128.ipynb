# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms

# Define the basic block for ResNet
class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_channels, out_channels, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(
            in_channels, out_channels, kernel_size=3, stride=stride, padding=1, bias=False
        )
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.conv2 = nn.Conv2d(
            out_channels, out_channels, kernel_size=3, stride=1, padding=1, bias=False
        )
        self.bn2 = nn.BatchNorm2d(out_channels)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_channels != out_channels:
            self.shortcut = nn.Sequential(
                nn.Conv2d(
                    in_channels, out_channels, kernel_size=1, stride=stride, bias=False
                ),
                nn.BatchNorm2d(out_channels),
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out

# Define ResNet
class DynamicSparseResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):  # For CIFAR-10, num_classes=10
        super(DynamicSparseResNet, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(
            3, 64, kernel_size=3, stride=1, padding=1, bias=False  # CIFAR-10 images have 3 channels
        )
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.linear = nn.Linear(512 * block.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        layers = []
        strides = [stride] + [1] * (num_blocks - 1)
        for s in strides:
            layers.append(block(self.in_planes, planes, s))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))  # Output size: 32x32
        out = self.layer1(out)                 # Output size: 32x32
        out = self.layer2(out)                 # Output size: 16x16
        out = self.layer3(out)                 # Output size: 8x8
        out = self.layer4(out)                 # Output size: 4x4
        out = F.avg_pool2d(out, 4)             # Output size: 1x1
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out

def ResNet18(num_classes=10):
    return DynamicSparseResNet(BasicBlock, [2, 2, 2, 2], num_classes=num_classes)

def initialize_weights(model):
    for m in model.modules():
        if isinstance(m, (nn.Conv2d, nn.Linear)):
            nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
            if m.bias is not None:
                nn.init.zeros_(m.bias)
        elif isinstance(m, nn.BatchNorm2d):
            nn.init.ones_(m.weight)
            nn.init.zeros_(m.bias)

def apply_dynamic_supermask(model, sparsity_rate):
    masks = {}
    for name, param in model.named_parameters():
        if 'weight' in name:
            weight_flat = param.data.abs().flatten()
            k = int(weight_flat.shape[0] * (1 - sparsity_rate))
            if k == 0:
                threshold = torch.max(weight_flat) + 1
            else:
                threshold = torch.topk(weight_flat, k, largest=True, sorted=True)[0][-1]
            mask = (param.data.abs() >= threshold).float()
            masks[name] = mask.view(param.size()).to(param.device)
    return masks

def dynamic_weight_update(model, masks):
    for name, param in model.named_parameters():
        if 'weight' in name and param.grad is not None:
            mask = masks[name]
            param.grad.data.mul_(mask)

def train_with_dynamic_pruning(model, train_loader, val_loader, epochs=400, device='cuda'):
    criterion = nn.CrossEntropyLoss(label_smoothing=0.1)
    optimizer = torch.optim.SGD(
        model.parameters(), lr=0.1, momentum=0.9, weight_decay=5e-4
    )
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=epochs)

    initial_sparsity = 0.0
    final_sparsity = 0.8
    sparsity_increment = (final_sparsity - initial_sparsity) / epochs

    train_losses = []
    val_losses = []
    train_acc = []
    val_acc = []

    initialize_weights(model)

    for epoch in range(epochs):
        model.train()
        running_loss = 0
        correct = 0
        total = 0

        current_sparsity = initial_sparsity + sparsity_increment * epoch
        masks = apply_dynamic_supermask(model, current_sparsity)

        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()

            dynamic_weight_update(model, masks)
            optimizer.step()

            running_loss += loss.item() * images.size(0)
            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()

        train_loss = running_loss / total
        train_accuracy = 100.0 * correct / total

        # Validation
        val_loss, val_accuracy = evaluate(model, val_loader, criterion, device)

        train_losses.append(train_loss)
        val_losses.append(val_loss)
        train_acc.append(train_accuracy)
        val_acc.append(val_accuracy)

        scheduler.step()

        print(
            f"Epoch: {epoch+1}/{epochs}"
            f" | Train Loss: {train_loss:.4f}, Train Acc: {train_accuracy:.2f}%"
            f" | Val Loss: {val_loss:.4f}, Val Acc: {val_accuracy:.2f}%"
            f" | Sparsity: {current_sparsity:.2f}"
        )

    return train_losses, val_losses, train_acc, val_acc

def evaluate(model, data_loader, criterion, device):
    model.eval()
    loss_total = 0
    correct = 0
    total = 0

    with torch.no_grad():
        for images, labels in data_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)

            loss_total += loss.item() * images.size(0)
            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()

    avg_loss = loss_total / total
    accuracy = 100.0 * correct / total
    return avg_loss, accuracy

def main():
    torch.manual_seed(42)

    # Data augmentation for CIFAR-10
    transform = transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(15),
        transforms.ColorJitter(
            brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1
        ),
        transforms.ToTensor(),
        transforms.RandomErasing(),
        transforms.Normalize(
            (0.4914, 0.4822, 0.4465),
            (0.2470, 0.2435, 0.2616)
        ),
    ])

    # Load the full CIFAR-10 dataset (both train and test sets)
    train_dataset = torchvision.datasets.CIFAR10(
        root='./data', train=True, download=True, transform=transform
    )
    test_dataset = torchvision.datasets.CIFAR10(
        root='./data', train=False, download=True, transform=transform
    )

    # Combine train and test datasets
    full_dataset = torch.utils.data.ConcatDataset([train_dataset, test_dataset])

    # Calculate sizes for splits
    total_size = len(full_dataset)
    train_size = int(0.8 * total_size)
    val_size = int(0.1 * total_size)
    test_size = total_size - train_size - val_size

    # Split the dataset
    train_dataset, val_dataset, test_dataset = torch.utils.data.random_split(
        full_dataset, [train_size, val_size, test_size]
    )

    # Set up DataLoader for training, validation, and testing data
    batch_size = 128
    train_loader = torch.utils.data.DataLoader(
        train_dataset,
        batch_size=batch_size,
        shuffle=True,
        num_workers=4,
        pin_memory=True,
    )
    val_loader = torch.utils.data.DataLoader(
        val_dataset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=4,
        pin_memory=True,
    )
    test_loader = torch.utils.data.DataLoader(
        test_dataset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=4,
        pin_memory=True,
    )

    # Set device to GPU if available
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model = ResNet18(num_classes=10).to(device)

    # Train and validate the model with dynamic pruning
    train_losses, val_losses, train_acc, val_acc = train_with_dynamic_pruning(
        model, train_loader, val_loader, epochs=400, device=device
    )

    # Plot training results
    import matplotlib.pyplot as plt
    plt.figure(figsize=(12, 4))

    plt.subplot(1, 2, 1)
    plt.plot(train_losses, label='Train Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.title('CIFAR-10 Training and Validation Loss')

    plt.subplot(1, 2, 2)
    plt.plot(train_acc, label='Train Accuracy')
    plt.plot(val_acc, label='Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy (%)')
    plt.legend()
    plt.title('CIFAR-10 Training and Validation Accuracy')

    plt.tight_layout()
    plt.show()

    # Evaluate on the test set
    criterion = nn.CrossEntropyLoss(label_smoothing=0.1)
    test_loss, test_accuracy = evaluate(model, test_loader, criterion, device)

    # Print final metrics
    print("\nFinal Results:")
    print(f"Final Training Loss: {train_losses[-1]:.4f}")
    print(f"Final Validation Loss: {val_losses[-1]:.4f}")
    print(f"Final Training Accuracy: {train_acc[-1]:.2f}%")
    print(f"Final Validation Accuracy: {val_acc[-1]:.2f}%")
    print(f"Final Test Loss: {test_loss:.4f}")
    print(f"Final Test Accuracy: {test_accuracy:.2f}%")

if __name__ == "__main__":
    main()
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170M/170M [00:12<00:00, 13.3MB/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
# Epoch: 1/400 | Train Loss: 3.2063, Train Acc: 20.35% | Val Loss: 2.0583, Val Acc: 25.45% | Sparsity: 0.00
# Epoch: 2/400 | Train Loss: 1.9873, Train Acc: 29.71% | Val Loss: 1.9256, Val Acc: 31.97% | Sparsity: 0.00
# Epoch: 3/400 | Train Loss: 1.8708, Train Acc: 35.19% | Val Loss: 1.8305, Val Acc: 37.10% | Sparsity: 0.00
# Epoch: 4/400 | Train Loss: 1.7652, Train Acc: 40.78% | Val Loss: 1.8936, Val Acc: 36.93% | Sparsity: 0.01
# Epoch: 5/400 | Train Loss: 1.6555, Train Acc: 46.59% | Val Loss: 1.6281, Val Acc: 47.77% | Sparsity: 0.01
# Epoch: 6/400 | Train Loss: 1.5486, Train Acc: 51.86% | Val Loss: 1.7840, Val Acc: 42.28% | Sparsity: 0.01
# Epoch: 7/400 | Train Loss: 1.4652, Train Acc: 55.95% | Val Loss: 1.5192, Val Acc: 54.40% | Sparsity: 0.01
# Epoch: 8/400 | Train Loss: 1.3996, Train Acc: 59.09% | Val Loss: 1.4724, Val Acc: 56.47% | Sparsity: 0.01
# Epoch: 9/400 | Train Loss: 1.3403, Train Acc: 62.17% | Val Loss: 1.5339, Val Acc: 55.03% | Sparsity: 0.02
# Epoch: 10/400 | Train Loss: 1.2795, Train Acc: 65.11% | Val Loss: 1.4083, Val Acc: 59.85% | Sparsity: 0.02
# Epoch: 11/400 | Train Loss: 1.2291, Train Acc: 67.51% | Val Loss: 1.2643, Val Acc: 65.77% | Sparsity: 0.02
# Epoch: 12/400 | Train Loss: 1.1845, Train Acc: 69.67% | Val Loss: 1.2221, Val Acc: 68.52% | Sparsity: 0.02
# Epoch: 13/400 | Train Loss: 1.1537, Train Acc: 70.94% | Val Loss: 1.2049, Val Acc: 68.67% | Sparsity: 0.02
# Epoch: 14/400 | Train Loss: 1.1319, Train Acc: 71.97% | Val Loss: 1.3520, Val Acc: 62.75% | Sparsity: 0.03
# Epoch: 15/400 | Train Loss: 1.1079, Train Acc: 73.11% | Val Loss: 1.2013, Val Acc: 68.53% | Sparsity: 0.03
# Epoch: 16/400 | Train Loss: 1.0975, Train Acc: 73.63% | Val Loss: 1.1938, Val Acc: 70.47% | Sparsity: 0.03
# Epoch: 17/400 | Train Loss: 1.0832, Train Acc: 74.04% | Val Loss: 1.3402, Val Acc: 62.78% | Sparsity: 0.03
# Epoch: 18/400 | Train Loss: 1.0706, Train Acc: 74.88% | Val Loss: 1.2479, Val Acc: 66.75% | Sparsity: 0.03
# Epoch: 19/400 | Train Loss: 1.0590, Train Acc: 75.31% | Val Loss: 1.2649, Val Acc: 66.12% | Sparsity: 0.04
# Epoch: 20/400 | Train Loss: 1.0584, Train Acc: 75.45% | Val Loss: 1.1405, Val Acc: 71.78% | Sparsity: 0.04
# Epoch: 21/400 | Train Loss: 1.0414, Train Acc: 76.12% | Val Loss: 1.2684, Val Acc: 66.62% | Sparsity: 0.04
# Epoch: 22/400 | Train Loss: 1.0377, Train Acc: 76.39% | Val Loss: 1.1878, Val Acc: 69.60% | Sparsity: 0.04
# Epoch: 23/400 | Train Loss: 1.0336, Train Acc: 76.46% | Val Loss: 1.1313, Val Acc: 72.57% | Sparsity: 0.04
# Epoch: 24/400 | Train Loss: 1.0238, Train Acc: 76.88% | Val Loss: 1.1516, Val Acc: 71.52% | Sparsity: 0.05
# Epoch: 25/400 | Train Loss: 1.0192, Train Acc: 77.19% | Val Loss: 1.1722, Val Acc: 70.20% | Sparsity: 0.05
# Epoch: 26/400 | Train Loss: 1.0073, Train Acc: 77.83% | Val Loss: 1.1905, Val Acc: 69.23% | Sparsity: 0.05
# Epoch: 27/400 | Train Loss: 1.0101, Train Acc: 77.62% | Val Loss: 1.0999, Val Acc: 73.77% | Sparsity: 0.05
# Epoch: 28/400 | Train Loss: 1.0024, Train Acc: 78.10% | Val Loss: 1.1058, Val Acc: 73.55% | Sparsity: 0.05
# Epoch: 29/400 | Train Loss: 1.0029, Train Acc: 77.89% | Val Loss: 1.2457, Val Acc: 68.30% | Sparsity: 0.06
# Epoch: 30/400 | Train Loss: 0.9952, Train Acc: 78.12% | Val Loss: 1.1566, Val Acc: 71.77% | Sparsity: 0.06
# Epoch: 31/400 | Train Loss: 0.9929, Train Acc: 78.44% | Val Loss: 1.0473, Val Acc: 76.00% | Sparsity: 0.06
# Epoch: 32/400 | Train Loss: 0.9890, Train Acc: 78.66% | Val Loss: 1.0870, Val Acc: 73.73% | Sparsity: 0.06
# Epoch: 33/400 | Train Loss: 0.9909, Train Acc: 78.41% | Val Loss: 1.1130, Val Acc: 73.33% | Sparsity: 0.06
# Epoch: 34/400 | Train Loss: 0.9825, Train Acc: 78.99% | Val Loss: 1.0900, Val Acc: 73.67% | Sparsity: 0.07
# Epoch: 35/400 | Train Loss: 0.9844, Train Acc: 78.84% | Val Loss: 1.1010, Val Acc: 73.53% | Sparsity: 0.07
# Epoch: 36/400 | Train Loss: 0.9855, Train Acc: 78.71% | Val Loss: 1.0774, Val Acc: 74.53% | Sparsity: 0.07
# Epoch: 37/400 | Train Loss: 0.9796, Train Acc: 78.93% | Val Loss: 1.1359, Val Acc: 72.62% | Sparsity: 0.07
# Epoch: 38/400 | Train Loss: 0.9761, Train Acc: 79.26% | Val Loss: 1.0919, Val Acc: 73.88% | Sparsity: 0.07
# Epoch: 39/400 | Train Loss: 0.9709, Train Acc: 79.30% | Val Loss: 1.1089, Val Acc: 73.65% | Sparsity: 0.08
# Epoch: 40/400 | Train Loss: 0.9709, Train Acc: 79.43% | Val Loss: 1.0616, Val Acc: 74.88% | Sparsity: 0.08
# Epoch: 41/400 | Train Loss: 0.9713, Train Acc: 79.34% | Val Loss: 1.0349, Val Acc: 76.37% | Sparsity: 0.08
# Epoch: 42/400 | Train Loss: 0.9689, Train Acc: 79.44% | Val Loss: 1.0779, Val Acc: 74.50% | Sparsity: 0.08
# Epoch: 43/400 | Train Loss: 0.9660, Train Acc: 79.76% | Val Loss: 1.1353, Val Acc: 71.77% | Sparsity: 0.08
# Epoch: 44/400 | Train Loss: 0.9679, Train Acc: 79.48% | Val Loss: 1.1219, Val Acc: 73.00% | Sparsity: 0.09
# Epoch: 45/400 | Train Loss: 0.9665, Train Acc: 79.60% | Val Loss: 1.0631, Val Acc: 75.23% | Sparsity: 0.09
# Epoch: 46/400 | Train Loss: 0.9641, Train Acc: 79.63% | Val Loss: 1.0918, Val Acc: 73.63% | Sparsity: 0.09
# Epoch: 47/400 | Train Loss: 0.9596, Train Acc: 79.94% | Val Loss: 1.1037, Val Acc: 73.55% | Sparsity: 0.09
# Epoch: 48/400 | Train Loss: 0.9626, Train Acc: 79.82% | Val Loss: 1.2769, Val Acc: 67.37% | Sparsity: 0.09
# Epoch: 49/400 | Train Loss: 0.9614, Train Acc: 79.93% | Val Loss: 1.1666, Val Acc: 71.12% | Sparsity: 0.10
# Epoch: 50/400 | Train Loss: 0.9580, Train Acc: 80.00% | Val Loss: 1.1192, Val Acc: 72.33% | Sparsity: 0.10
# Epoch: 51/400 | Train Loss: 0.9614, Train Acc: 79.85% | Val Loss: 1.1990, Val Acc: 69.43% | Sparsity: 0.10
# Epoch: 52/400 | Train Loss: 0.9480, Train Acc: 80.19% | Val Loss: 1.0381, Val Acc: 75.78% | Sparsity: 0.10
# Epoch: 53/400 | Train Loss: 0.9514, Train Acc: 80.23% | Val Loss: 1.0784, Val Acc: 74.50% | Sparsity: 0.10
# Epoch: 54/400 | Train Loss: 0.9548, Train Acc: 80.23% | Val Loss: 1.0958, Val Acc: 74.13% | Sparsity: 0.11
# Epoch: 55/400 | Train Loss: 0.9578, Train Acc: 79.83% | Val Loss: 1.0368, Val Acc: 76.60% | Sparsity: 0.11
# Epoch: 56/400 | Train Loss: 0.9561, Train Acc: 80.01% | Val Loss: 1.1475, Val Acc: 71.58% | Sparsity: 0.11
# Epoch: 57/400 | Train Loss: 0.9470, Train Acc: 80.35% | Val Loss: 1.0595, Val Acc: 75.35% | Sparsity: 0.11
# Epoch: 58/400 | Train Loss: 0.9484, Train Acc: 80.17% | Val Loss: 1.0736, Val Acc: 74.25% | Sparsity: 0.11
# Epoch: 59/400 | Train Loss: 0.9420, Train Acc: 80.74% | Val Loss: 1.0329, Val Acc: 76.35% | Sparsity: 0.12
# Epoch: 60/400 | Train Loss: 0.9483, Train Acc: 80.24% | Val Loss: 1.1001, Val Acc: 73.62% | Sparsity: 0.12
# Epoch: 61/400 | Train Loss: 0.9499, Train Acc: 80.40% | Val Loss: 1.1210, Val Acc: 73.13% | Sparsity: 0.12
# Epoch: 62/400 | Train Loss: 0.9419, Train Acc: 80.85% | Val Loss: 1.2708, Val Acc: 67.63% | Sparsity: 0.12
# Epoch: 63/400 | Train Loss: 0.9475, Train Acc: 80.37% | Val Loss: 1.1665, Val Acc: 71.48% | Sparsity: 0.12
# Epoch: 64/400 | Train Loss: 0.9449, Train Acc: 80.67% | Val Loss: 1.0877, Val Acc: 74.12% | Sparsity: 0.13
# Epoch: 65/400 | Train Loss: 0.9446, Train Acc: 80.62% | Val Loss: 1.0831, Val Acc: 74.13% | Sparsity: 0.13
# Epoch: 66/400 | Train Loss: 0.9416, Train Acc: 80.59% | Val Loss: 1.1477, Val Acc: 72.88% | Sparsity: 0.13
# Epoch: 67/400 | Train Loss: 0.9409, Train Acc: 80.85% | Val Loss: 1.0227, Val Acc: 77.43% | Sparsity: 0.13
# Epoch: 68/400 | Train Loss: 0.9410, Train Acc: 80.55% | Val Loss: 1.0917, Val Acc: 74.15% | Sparsity: 0.13
# Epoch: 69/400 | Train Loss: 0.9352, Train Acc: 81.00% | Val Loss: 1.0449, Val Acc: 76.67% | Sparsity: 0.14
# Epoch: 70/400 | Train Loss: 0.9370, Train Acc: 80.91% | Val Loss: 1.0808, Val Acc: 74.62% | Sparsity: 0.14
# Epoch: 71/400 | Train Loss: 0.9363, Train Acc: 80.97% | Val Loss: 1.0782, Val Acc: 75.52% | Sparsity: 0.14
# Epoch: 72/400 | Train Loss: 0.9343, Train Acc: 81.11% | Val Loss: 1.0412, Val Acc: 76.72% | Sparsity: 0.14
# Epoch: 73/400 | Train Loss: 0.9320, Train Acc: 81.20% | Val Loss: 1.1299, Val Acc: 72.95% | Sparsity: 0.14
# Epoch: 74/400 | Train Loss: 0.9354, Train Acc: 80.88% | Val Loss: 1.0883, Val Acc: 74.67% | Sparsity: 0.15
# Epoch: 75/400 | Train Loss: 0.9316, Train Acc: 81.16% | Val Loss: 1.0112, Val Acc: 77.45% | Sparsity: 0.15
# Epoch: 76/400 | Train Loss: 0.9355, Train Acc: 80.94% | Val Loss: 1.0080, Val Acc: 77.73% | Sparsity: 0.15
# Epoch: 77/400 | Train Loss: 0.9259, Train Acc: 81.16% | Val Loss: 1.0888, Val Acc: 74.30% | Sparsity: 0.15
# Epoch: 78/400 | Train Loss: 0.9303, Train Acc: 81.13% | Val Loss: 1.0622, Val Acc: 75.20% | Sparsity: 0.15
# Epoch: 79/400 | Train Loss: 0.9315, Train Acc: 81.06% | Val Loss: 1.0236, Val Acc: 76.75% | Sparsity: 0.16
# Epoch: 80/400 | Train Loss: 0.9301, Train Acc: 81.28% | Val Loss: 1.1550, Val Acc: 72.05% | Sparsity: 0.16
# Epoch: 81/400 | Train Loss: 0.9287, Train Acc: 81.14% | Val Loss: 1.0293, Val Acc: 76.45% | Sparsity: 0.16
# Epoch: 82/400 | Train Loss: 0.9269, Train Acc: 81.27% | Val Loss: 1.0485, Val Acc: 76.33% | Sparsity: 0.16
# Epoch: 83/400 | Train Loss: 0.9286, Train Acc: 81.32% | Val Loss: 1.0118, Val Acc: 77.05% | Sparsity: 0.16
# Epoch: 84/400 | Train Loss: 0.9255, Train Acc: 81.37% | Val Loss: 1.0410, Val Acc: 75.42% | Sparsity: 0.17
# Epoch: 85/400 | Train Loss: 0.9265, Train Acc: 81.23% | Val Loss: 1.0605, Val Acc: 75.17% | Sparsity: 0.17
# Epoch: 86/400 | Train Loss: 0.9187, Train Acc: 81.70% | Val Loss: 1.0770, Val Acc: 74.73% | Sparsity: 0.17
# Epoch: 87/400 | Train Loss: 0.9235, Train Acc: 81.43% | Val Loss: 1.0782, Val Acc: 74.82% | Sparsity: 0.17
# Epoch: 88/400 | Train Loss: 0.9226, Train Acc: 81.62% | Val Loss: 1.0075, Val Acc: 77.00% | Sparsity: 0.17
# Epoch: 89/400 | Train Loss: 0.9209, Train Acc: 81.71% | Val Loss: 1.0341, Val Acc: 76.45% | Sparsity: 0.18
# Epoch: 90/400 | Train Loss: 0.9173, Train Acc: 81.79% | Val Loss: 1.0474, Val Acc: 75.95% | Sparsity: 0.18
# Epoch: 91/400 | Train Loss: 0.9190, Train Acc: 81.62% | Val Loss: 1.0409, Val Acc: 75.70% | Sparsity: 0.18
# Epoch: 92/400 | Train Loss: 0.9196, Train Acc: 81.47% | Val Loss: 1.0399, Val Acc: 76.78% | Sparsity: 0.18
# Epoch: 93/400 | Train Loss: 0.9217, Train Acc: 81.40% | Val Loss: 1.0098, Val Acc: 77.67% | Sparsity: 0.18
# Epoch: 94/400 | Train Loss: 0.9197, Train Acc: 81.87% | Val Loss: 1.0779, Val Acc: 75.70% | Sparsity: 0.19
# Epoch: 95/400 | Train Loss: 0.9193, Train Acc: 81.69% | Val Loss: 1.0526, Val Acc: 75.48% | Sparsity: 0.19
# Epoch: 96/400 | Train Loss: 0.9204, Train Acc: 81.67% | Val Loss: 1.0404, Val Acc: 76.48% | Sparsity: 0.19
# Epoch: 97/400 | Train Loss: 0.9138, Train Acc: 81.96% | Val Loss: 1.1006, Val Acc: 73.97% | Sparsity: 0.19
# Epoch: 98/400 | Train Loss: 0.9175, Train Acc: 81.71% | Val Loss: 1.0840, Val Acc: 74.47% | Sparsity: 0.19
# Epoch: 99/400 | Train Loss: 0.9118, Train Acc: 81.87% | Val Loss: 1.0663, Val Acc: 75.53% | Sparsity: 0.20
# Epoch: 100/400 | Train Loss: 0.9121, Train Acc: 82.01% | Val Loss: 1.1167, Val Acc: 73.73% | Sparsity: 0.20
# Epoch: 101/400 | Train Loss: 0.9089, Train Acc: 82.26% | Val Loss: 1.0751, Val Acc: 75.05% | Sparsity: 0.20
# Epoch: 102/400 | Train Loss: 0.9095, Train Acc: 82.17% | Val Loss: 1.0182, Val Acc: 77.37% | Sparsity: 0.20
# Epoch: 103/400 | Train Loss: 0.9094, Train Acc: 82.14% | Val Loss: 1.0325, Val Acc: 76.20% | Sparsity: 0.20
# Epoch: 104/400 | Train Loss: 0.9169, Train Acc: 81.68% | Val Loss: 0.9921, Val Acc: 78.18% | Sparsity: 0.21
# Epoch: 105/400 | Train Loss: 0.9121, Train Acc: 82.07% | Val Loss: 1.0835, Val Acc: 75.38% | Sparsity: 0.21
# Epoch: 106/400 | Train Loss: 0.9105, Train Acc: 82.03% | Val Loss: 0.9910, Val Acc: 78.50% | Sparsity: 0.21
# Epoch: 107/400 | Train Loss: 0.9057, Train Acc: 82.32% | Val Loss: 1.0189, Val Acc: 78.05% | Sparsity: 0.21
# Epoch: 108/400 | Train Loss: 0.9039, Train Acc: 82.25% | Val Loss: 0.9906, Val Acc: 78.10% | Sparsity: 0.21
# Epoch: 109/400 | Train Loss: 0.9062, Train Acc: 82.27% | Val Loss: 1.0435, Val Acc: 77.05% | Sparsity: 0.22
# Epoch: 110/400 | Train Loss: 0.9110, Train Acc: 82.02% | Val Loss: 1.0610, Val Acc: 76.03% | Sparsity: 0.22
# Epoch: 111/400 | Train Loss: 0.9048, Train Acc: 82.18% | Val Loss: 1.0410, Val Acc: 76.92% | Sparsity: 0.22
# Epoch: 112/400 | Train Loss: 0.9044, Train Acc: 82.21% | Val Loss: 1.0502, Val Acc: 76.42% | Sparsity: 0.22
# Epoch: 113/400 | Train Loss: 0.9043, Train Acc: 82.22% | Val Loss: 1.0658, Val Acc: 75.52% | Sparsity: 0.22
# Epoch: 114/400 | Train Loss: 0.9059, Train Acc: 82.27% | Val Loss: 1.0501, Val Acc: 76.42% | Sparsity: 0.23
# Epoch: 115/400 | Train Loss: 0.9047, Train Acc: 82.31% | Val Loss: 1.0870, Val Acc: 74.35% | Sparsity: 0.23
# Epoch: 116/400 | Train Loss: 0.9032, Train Acc: 82.40% | Val Loss: 1.1363, Val Acc: 73.22% | Sparsity: 0.23
# Epoch: 117/400 | Train Loss: 0.9000, Train Acc: 82.53% | Val Loss: 1.2456, Val Acc: 67.95% | Sparsity: 0.23
# Epoch: 118/400 | Train Loss: 0.8982, Train Acc: 82.61% | Val Loss: 1.0153, Val Acc: 78.02% | Sparsity: 0.23
# Epoch: 119/400 | Train Loss: 0.9013, Train Acc: 82.18% | Val Loss: 0.9952, Val Acc: 78.87% | Sparsity: 0.24
# Epoch: 120/400 | Train Loss: 0.9008, Train Acc: 82.63% | Val Loss: 0.9778, Val Acc: 78.95% | Sparsity: 0.24
# Epoch: 121/400 | Train Loss: 0.8981, Train Acc: 82.54% | Val Loss: 1.0254, Val Acc: 77.08% | Sparsity: 0.24
# Epoch: 122/400 | Train Loss: 0.9017, Train Acc: 82.39% | Val Loss: 1.0053, Val Acc: 77.77% | Sparsity: 0.24
# Epoch: 123/400 | Train Loss: 0.8952, Train Acc: 82.53% | Val Loss: 1.0235, Val Acc: 76.67% | Sparsity: 0.24
# Epoch: 124/400 | Train Loss: 0.8985, Train Acc: 82.51% | Val Loss: 1.0224, Val Acc: 77.97% | Sparsity: 0.25
# Epoch: 125/400 | Train Loss: 0.8945, Train Acc: 82.64% | Val Loss: 0.9906, Val Acc: 78.52% | Sparsity: 0.25
# Epoch: 126/400 | Train Loss: 0.8963, Train Acc: 82.66% | Val Loss: 1.0890, Val Acc: 74.35% | Sparsity: 0.25
# Epoch: 127/400 | Train Loss: 0.8977, Train Acc: 82.49% | Val Loss: 1.1127, Val Acc: 74.02% | Sparsity: 0.25
# Epoch: 128/400 | Train Loss: 0.8890, Train Acc: 83.02% | Val Loss: 0.9941, Val Acc: 78.20% | Sparsity: 0.25
# Epoch: 129/400 | Train Loss: 0.8988, Train Acc: 82.46% | Val Loss: 1.0804, Val Acc: 74.52% | Sparsity: 0.26
# Epoch: 130/400 | Train Loss: 0.8905, Train Acc: 82.86% | Val Loss: 1.0330, Val Acc: 76.77% | Sparsity: 0.26
# Epoch: 131/400 | Train Loss: 0.8908, Train Acc: 82.83% | Val Loss: 1.0235, Val Acc: 76.97% | Sparsity: 0.26
# Epoch: 132/400 | Train Loss: 0.8872, Train Acc: 82.87% | Val Loss: 1.0613, Val Acc: 75.95% | Sparsity: 0.26
# Epoch: 133/400 | Train Loss: 0.8875, Train Acc: 82.89% | Val Loss: 1.0476, Val Acc: 76.05% | Sparsity: 0.26
# Epoch: 134/400 | Train Loss: 0.8952, Train Acc: 82.61% | Val Loss: 0.9839, Val Acc: 78.52% | Sparsity: 0.27
# Epoch: 135/400 | Train Loss: 0.8871, Train Acc: 83.10% | Val Loss: 0.9371, Val Acc: 81.48% | Sparsity: 0.27
# Epoch: 136/400 | Train Loss: 0.8827, Train Acc: 83.33% | Val Loss: 0.9986, Val Acc: 78.38% | Sparsity: 0.27
# Epoch: 137/400 | Train Loss: 0.8876, Train Acc: 82.90% | Val Loss: 1.0613, Val Acc: 75.85% | Sparsity: 0.27
# Epoch: 138/400 | Train Loss: 0.8888, Train Acc: 82.94% | Val Loss: 1.0668, Val Acc: 74.98% | Sparsity: 0.27
# Epoch: 139/400 | Train Loss: 0.8855, Train Acc: 83.06% | Val Loss: 0.9877, Val Acc: 79.02% | Sparsity: 0.28
# Epoch: 140/400 | Train Loss: 0.8832, Train Acc: 83.25% | Val Loss: 0.9977, Val Acc: 78.22% | Sparsity: 0.28
# Epoch: 141/400 | Train Loss: 0.8844, Train Acc: 83.18% | Val Loss: 0.9509, Val Acc: 80.30% | Sparsity: 0.28
# Epoch: 142/400 | Train Loss: 0.8771, Train Acc: 83.51% | Val Loss: 1.0269, Val Acc: 77.18% | Sparsity: 0.28
# Epoch: 143/400 | Train Loss: 0.8813, Train Acc: 83.12% | Val Loss: 0.9767, Val Acc: 79.40% | Sparsity: 0.28
# Epoch: 144/400 | Train Loss: 0.8785, Train Acc: 83.35% | Val Loss: 0.9715, Val Acc: 78.97% | Sparsity: 0.29
# Epoch: 145/400 | Train Loss: 0.8790, Train Acc: 83.34% | Val Loss: 0.9906, Val Acc: 78.48% | Sparsity: 0.29
# Epoch: 146/400 | Train Loss: 0.8830, Train Acc: 83.13% | Val Loss: 1.0166, Val Acc: 77.35% | Sparsity: 0.29
# Epoch: 147/400 | Train Loss: 0.8762, Train Acc: 83.46% | Val Loss: 1.1309, Val Acc: 72.95% | Sparsity: 0.29
# Epoch: 148/400 | Train Loss: 0.8776, Train Acc: 83.42% | Val Loss: 1.1390, Val Acc: 72.30% | Sparsity: 0.29
# Epoch: 149/400 | Train Loss: 0.8767, Train Acc: 83.48% | Val Loss: 0.9804, Val Acc: 79.45% | Sparsity: 0.30
# Epoch: 150/400 | Train Loss: 0.8742, Train Acc: 83.65% | Val Loss: 0.9379, Val Acc: 80.80% | Sparsity: 0.30
# Epoch: 151/400 | Train Loss: 0.8789, Train Acc: 83.50% | Val Loss: 0.9946, Val Acc: 78.58% | Sparsity: 0.30
# Epoch: 152/400 | Train Loss: 0.8768, Train Acc: 83.55% | Val Loss: 0.9533, Val Acc: 79.72% | Sparsity: 0.30
# Epoch: 153/400 | Train Loss: 0.8746, Train Acc: 83.68% | Val Loss: 1.0784, Val Acc: 74.72% | Sparsity: 0.30
# Epoch: 154/400 | Train Loss: 0.8735, Train Acc: 83.64% | Val Loss: 0.9719, Val Acc: 79.50% | Sparsity: 0.31
# Epoch: 155/400 | Train Loss: 0.8720, Train Acc: 83.64% | Val Loss: 0.9326, Val Acc: 81.57% | Sparsity: 0.31
# Epoch: 156/400 | Train Loss: 0.8714, Train Acc: 83.81% | Val Loss: 0.9812, Val Acc: 79.35% | Sparsity: 0.31
# Epoch: 157/400 | Train Loss: 0.8693, Train Acc: 83.82% | Val Loss: 0.9557, Val Acc: 79.72% | Sparsity: 0.31
# Epoch: 158/400 | Train Loss: 0.8684, Train Acc: 83.86% | Val Loss: 0.9933, Val Acc: 78.53% | Sparsity: 0.31
# Epoch: 159/400 | Train Loss: 0.8670, Train Acc: 83.96% | Val Loss: 1.0783, Val Acc: 75.80% | Sparsity: 0.32
# Epoch: 160/400 | Train Loss: 0.8696, Train Acc: 83.93% | Val Loss: 0.9679, Val Acc: 79.33% | Sparsity: 0.32
# Epoch: 161/400 | Train Loss: 0.8641, Train Acc: 84.11% | Val Loss: 0.9747, Val Acc: 78.85% | Sparsity: 0.32
# Epoch: 162/400 | Train Loss: 0.8642, Train Acc: 84.09% | Val Loss: 0.9642, Val Acc: 79.58% | Sparsity: 0.32
# Epoch: 163/400 | Train Loss: 0.8700, Train Acc: 83.81% | Val Loss: 0.9235, Val Acc: 81.85% | Sparsity: 0.32
# Epoch: 164/400 | Train Loss: 0.8660, Train Acc: 84.05% | Val Loss: 0.9850, Val Acc: 78.47% | Sparsity: 0.33
# Epoch: 165/400 | Train Loss: 0.8630, Train Acc: 84.19% | Val Loss: 0.9722, Val Acc: 79.08% | Sparsity: 0.33
# Epoch: 166/400 | Train Loss: 0.8627, Train Acc: 84.05% | Val Loss: 1.0223, Val Acc: 77.20% | Sparsity: 0.33
# Epoch: 167/400 | Train Loss: 0.8577, Train Acc: 84.32% | Val Loss: 0.9673, Val Acc: 79.10% | Sparsity: 0.33
# Epoch: 168/400 | Train Loss: 0.8592, Train Acc: 84.34% | Val Loss: 0.9353, Val Acc: 80.75% | Sparsity: 0.33
# Epoch: 169/400 | Train Loss: 0.8574, Train Acc: 84.38% | Val Loss: 1.0939, Val Acc: 74.62% | Sparsity: 0.34
# Epoch: 170/400 | Train Loss: 0.8624, Train Acc: 84.12% | Val Loss: 0.9589, Val Acc: 79.70% | Sparsity: 0.34
# Epoch: 171/400 | Train Loss: 0.8584, Train Acc: 84.25% | Val Loss: 0.9275, Val Acc: 81.50% | Sparsity: 0.34
# Epoch: 172/400 | Train Loss: 0.8548, Train Acc: 84.49% | Val Loss: 0.9326, Val Acc: 81.42% | Sparsity: 0.34
# Epoch: 173/400 | Train Loss: 0.8538, Train Acc: 84.50% | Val Loss: 1.0184, Val Acc: 77.72% | Sparsity: 0.34
# Epoch: 174/400 | Train Loss: 0.8593, Train Acc: 84.41% | Val Loss: 0.9962, Val Acc: 78.40% | Sparsity: 0.35
# Epoch: 175/400 | Train Loss: 0.8539, Train Acc: 84.54% | Val Loss: 0.9917, Val Acc: 78.47% | Sparsity: 0.35
# Epoch: 176/400 | Train Loss: 0.8498, Train Acc: 84.77% | Val Loss: 0.9582, Val Acc: 80.43% | Sparsity: 0.35
# Epoch: 177/400 | Train Loss: 0.8528, Train Acc: 84.46% | Val Loss: 0.9779, Val Acc: 79.08% | Sparsity: 0.35
# Epoch: 178/400 | Train Loss: 0.8490, Train Acc: 84.78% | Val Loss: 0.9316, Val Acc: 81.27% | Sparsity: 0.35
# Epoch: 179/400 | Train Loss: 0.8498, Train Acc: 84.68% | Val Loss: 0.9304, Val Acc: 81.18% | Sparsity: 0.36
# Epoch: 180/400 | Train Loss: 0.8503, Train Acc: 84.61% | Val Loss: 0.9549, Val Acc: 79.75% | Sparsity: 0.36
# Epoch: 181/400 | Train Loss: 0.8492, Train Acc: 84.72% | Val Loss: 0.9641, Val Acc: 79.65% | Sparsity: 0.36
# Epoch: 182/400 | Train Loss: 0.8503, Train Acc: 84.72% | Val Loss: 0.9844, Val Acc: 78.40% | Sparsity: 0.36
# Epoch: 183/400 | Train Loss: 0.8436, Train Acc: 84.92% | Val Loss: 0.8959, Val Acc: 82.43% | Sparsity: 0.36
# Epoch: 184/400 | Train Loss: 0.8447, Train Acc: 84.82% | Val Loss: 0.9610, Val Acc: 79.42% | Sparsity: 0.37
# Epoch: 185/400 | Train Loss: 0.8470, Train Acc: 84.90% | Val Loss: 0.9986, Val Acc: 78.10% | Sparsity: 0.37
# Epoch: 186/400 | Train Loss: 0.8429, Train Acc: 84.91% | Val Loss: 0.9755, Val Acc: 79.17% | Sparsity: 0.37
# Epoch: 187/400 | Train Loss: 0.8440, Train Acc: 84.90% | Val Loss: 0.9966, Val Acc: 78.52% | Sparsity: 0.37
# Epoch: 188/400 | Train Loss: 0.8449, Train Acc: 84.88% | Val Loss: 0.9457, Val Acc: 80.47% | Sparsity: 0.37
# Epoch: 189/400 | Train Loss: 0.8366, Train Acc: 85.14% | Val Loss: 1.0273, Val Acc: 77.67% | Sparsity: 0.38
# Epoch: 190/400 | Train Loss: 0.8386, Train Acc: 85.23% | Val Loss: 0.9256, Val Acc: 81.33% | Sparsity: 0.38
# Epoch: 191/400 | Train Loss: 0.8381, Train Acc: 85.29% | Val Loss: 0.9761, Val Acc: 79.47% | Sparsity: 0.38
# Epoch: 192/400 | Train Loss: 0.8366, Train Acc: 85.46% | Val Loss: 0.9648, Val Acc: 80.10% | Sparsity: 0.38
# Epoch: 193/400 | Train Loss: 0.8375, Train Acc: 85.28% | Val Loss: 0.9216, Val Acc: 81.05% | Sparsity: 0.38
# Epoch: 194/400 | Train Loss: 0.8357, Train Acc: 85.25% | Val Loss: 1.0160, Val Acc: 78.10% | Sparsity: 0.39
# Epoch: 195/400 | Train Loss: 0.8362, Train Acc: 85.22% | Val Loss: 0.9398, Val Acc: 80.47% | Sparsity: 0.39
# Epoch: 196/400 | Train Loss: 0.8344, Train Acc: 85.33% | Val Loss: 1.0959, Val Acc: 74.10% | Sparsity: 0.39
# Epoch: 197/400 | Train Loss: 0.8325, Train Acc: 85.55% | Val Loss: 0.9985, Val Acc: 78.62% | Sparsity: 0.39
# Epoch: 198/400 | Train Loss: 0.8312, Train Acc: 85.51% | Val Loss: 0.9593, Val Acc: 80.13% | Sparsity: 0.39
# Epoch: 199/400 | Train Loss: 0.8317, Train Acc: 85.59% | Val Loss: 0.9749, Val Acc: 79.55% | Sparsity: 0.40
# Epoch: 200/400 | Train Loss: 0.8280, Train Acc: 85.59% | Val Loss: 0.9370, Val Acc: 80.50% | Sparsity: 0.40
# Epoch: 201/400 | Train Loss: 0.8320, Train Acc: 85.54% | Val Loss: 0.9503, Val Acc: 80.07% | Sparsity: 0.40
# Epoch: 202/400 | Train Loss: 0.8270, Train Acc: 85.69% | Val Loss: 0.9513, Val Acc: 80.42% | Sparsity: 0.40
# Epoch: 203/400 | Train Loss: 0.8259, Train Acc: 85.72% | Val Loss: 0.9550, Val Acc: 80.13% | Sparsity: 0.40
# Epoch: 204/400 | Train Loss: 0.8274, Train Acc: 85.64% | Val Loss: 0.9920, Val Acc: 78.42% | Sparsity: 0.41
# Epoch: 205/400 | Train Loss: 0.8240, Train Acc: 85.78% | Val Loss: 0.9217, Val Acc: 81.72% | Sparsity: 0.41
# Epoch: 206/400 | Train Loss: 0.8241, Train Acc: 85.92% | Val Loss: 0.9626, Val Acc: 79.93% | Sparsity: 0.41
# Epoch: 207/400 | Train Loss: 0.8246, Train Acc: 85.77% | Val Loss: 0.9710, Val Acc: 79.47% | Sparsity: 0.41
# Epoch: 208/400 | Train Loss: 0.8208, Train Acc: 85.95% | Val Loss: 0.9356, Val Acc: 80.35% | Sparsity: 0.41
# Epoch: 209/400 | Train Loss: 0.8179, Train Acc: 86.21% | Val Loss: 0.9967, Val Acc: 78.07% | Sparsity: 0.42
# Epoch: 210/400 | Train Loss: 0.8173, Train Acc: 86.10% | Val Loss: 0.8839, Val Acc: 83.35% | Sparsity: 0.42
# Epoch: 211/400 | Train Loss: 0.8176, Train Acc: 86.09% | Val Loss: 0.9896, Val Acc: 78.65% | Sparsity: 0.42
# Epoch: 212/400 | Train Loss: 0.8210, Train Acc: 85.87% | Val Loss: 0.9605, Val Acc: 79.45% | Sparsity: 0.42
# Epoch: 213/400 | Train Loss: 0.8178, Train Acc: 86.13% | Val Loss: 1.0092, Val Acc: 77.75% | Sparsity: 0.42
# Epoch: 214/400 | Train Loss: 0.8162, Train Acc: 86.19% | Val Loss: 0.8983, Val Acc: 82.60% | Sparsity: 0.43
# Epoch: 215/400 | Train Loss: 0.8116, Train Acc: 86.32% | Val Loss: 0.9405, Val Acc: 81.15% | Sparsity: 0.43
# Epoch: 216/400 | Train Loss: 0.8125, Train Acc: 86.28% | Val Loss: 0.9541, Val Acc: 79.37% | Sparsity: 0.43
# Epoch: 217/400 | Train Loss: 0.8160, Train Acc: 85.91% | Val Loss: 0.9574, Val Acc: 80.77% | Sparsity: 0.43
# Epoch: 218/400 | Train Loss: 0.8106, Train Acc: 86.34% | Val Loss: 0.9645, Val Acc: 79.85% | Sparsity: 0.43
# Epoch: 219/400 | Train Loss: 0.8130, Train Acc: 86.34% | Val Loss: 0.9078, Val Acc: 82.02% | Sparsity: 0.44
# Epoch: 220/400 | Train Loss: 0.8123, Train Acc: 86.15% | Val Loss: 0.9329, Val Acc: 80.85% | Sparsity: 0.44
# Epoch: 221/400 | Train Loss: 0.8068, Train Acc: 86.57% | Val Loss: 0.9559, Val Acc: 80.50% | Sparsity: 0.44
# Epoch: 222/400 | Train Loss: 0.8063, Train Acc: 86.57% | Val Loss: 0.9691, Val Acc: 79.95% | Sparsity: 0.44
# Epoch: 223/400 | Train Loss: 0.8081, Train Acc: 86.49% | Val Loss: 0.8988, Val Acc: 82.33% | Sparsity: 0.44
# Epoch: 224/400 | Train Loss: 0.8085, Train Acc: 86.55% | Val Loss: 0.9853, Val Acc: 79.20% | Sparsity: 0.45
# Epoch: 225/400 | Train Loss: 0.7996, Train Acc: 86.95% | Val Loss: 0.8955, Val Acc: 82.37% | Sparsity: 0.45
# Epoch: 226/400 | Train Loss: 0.8046, Train Acc: 86.64% | Val Loss: 0.9527, Val Acc: 80.17% | Sparsity: 0.45
# Epoch: 227/400 | Train Loss: 0.8038, Train Acc: 86.71% | Val Loss: 0.8871, Val Acc: 82.95% | Sparsity: 0.45
# Epoch: 228/400 | Train Loss: 0.8011, Train Acc: 86.81% | Val Loss: 0.9192, Val Acc: 81.25% | Sparsity: 0.45
# Epoch: 229/400 | Train Loss: 0.8034, Train Acc: 86.71% | Val Loss: 0.9464, Val Acc: 81.45% | Sparsity: 0.46
# Epoch: 230/400 | Train Loss: 0.7965, Train Acc: 87.03% | Val Loss: 0.9120, Val Acc: 81.43% | Sparsity: 0.46
# Epoch: 231/400 | Train Loss: 0.7958, Train Acc: 87.18% | Val Loss: 0.9235, Val Acc: 81.35% | Sparsity: 0.46
# Epoch: 232/400 | Train Loss: 0.7974, Train Acc: 86.98% | Val Loss: 0.8758, Val Acc: 83.37% | Sparsity: 0.46
# Epoch: 233/400 | Train Loss: 0.7965, Train Acc: 87.05% | Val Loss: 0.9804, Val Acc: 78.72% | Sparsity: 0.46
# Epoch: 234/400 | Train Loss: 0.7906, Train Acc: 87.33% | Val Loss: 0.9074, Val Acc: 81.92% | Sparsity: 0.47
# Epoch: 235/400 | Train Loss: 0.7882, Train Acc: 87.35% | Val Loss: 0.8965, Val Acc: 83.30% | Sparsity: 0.47
# Epoch: 236/400 | Train Loss: 0.7966, Train Acc: 87.10% | Val Loss: 0.9775, Val Acc: 79.23% | Sparsity: 0.47
# Epoch: 237/400 | Train Loss: 0.7894, Train Acc: 87.30% | Val Loss: 0.9233, Val Acc: 81.58% | Sparsity: 0.47
# Epoch: 238/400 | Train Loss: 0.7883, Train Acc: 87.45% | Val Loss: 0.9248, Val Acc: 81.73% | Sparsity: 0.47
# Epoch: 239/400 | Train Loss: 0.7887, Train Acc: 87.38% | Val Loss: 0.8814, Val Acc: 83.22% | Sparsity: 0.48
# Epoch: 240/400 | Train Loss: 0.7823, Train Acc: 87.60% | Val Loss: 0.8963, Val Acc: 82.65% | Sparsity: 0.48
# Epoch: 241/400 | Train Loss: 0.7841, Train Acc: 87.48% | Val Loss: 0.9329, Val Acc: 81.47% | Sparsity: 0.48
# Epoch: 242/400 | Train Loss: 0.7880, Train Acc: 87.50% | Val Loss: 0.9085, Val Acc: 81.75% | Sparsity: 0.48
# Epoch: 243/400 | Train Loss: 0.7808, Train Acc: 87.76% | Val Loss: 0.9080, Val Acc: 81.70% | Sparsity: 0.48
# Epoch: 244/400 | Train Loss: 0.7808, Train Acc: 87.64% | Val Loss: 0.8958, Val Acc: 82.28% | Sparsity: 0.49
# Epoch: 245/400 | Train Loss: 0.7796, Train Acc: 87.76% | Val Loss: 0.9150, Val Acc: 81.97% | Sparsity: 0.49
# Epoch: 246/400 | Train Loss: 0.7765, Train Acc: 87.86% | Val Loss: 0.8940, Val Acc: 82.48% | Sparsity: 0.49
# Epoch: 247/400 | Train Loss: 0.7819, Train Acc: 87.67% | Val Loss: 0.8710, Val Acc: 83.38% | Sparsity: 0.49
# Epoch: 248/400 | Train Loss: 0.7744, Train Acc: 88.08% | Val Loss: 0.9115, Val Acc: 82.05% | Sparsity: 0.49
# Epoch: 249/400 | Train Loss: 0.7780, Train Acc: 87.90% | Val Loss: 0.8634, Val Acc: 83.75% | Sparsity: 0.50
# Epoch: 250/400 | Train Loss: 0.7729, Train Acc: 88.11% | Val Loss: 0.8928, Val Acc: 83.13% | Sparsity: 0.50
# Epoch: 251/400 | Train Loss: 0.7733, Train Acc: 88.01% | Val Loss: 0.8603, Val Acc: 84.58% | Sparsity: 0.50
# Epoch: 252/400 | Train Loss: 0.7734, Train Acc: 87.94% | Val Loss: 0.8569, Val Acc: 84.42% | Sparsity: 0.50
# Epoch: 253/400 | Train Loss: 0.7693, Train Acc: 88.30% | Val Loss: 0.8806, Val Acc: 83.22% | Sparsity: 0.50
# Epoch: 254/400 | Train Loss: 0.7687, Train Acc: 88.27% | Val Loss: 0.8551, Val Acc: 84.57% | Sparsity: 0.51
# Epoch: 255/400 | Train Loss: 0.7686, Train Acc: 88.24% | Val Loss: 0.8808, Val Acc: 83.35% | Sparsity: 0.51
# Epoch: 256/400 | Train Loss: 0.7692, Train Acc: 88.19% | Val Loss: 0.8695, Val Acc: 83.82% | Sparsity: 0.51
# Epoch: 257/400 | Train Loss: 0.7661, Train Acc: 88.36% | Val Loss: 0.9187, Val Acc: 81.80% | Sparsity: 0.51
# Epoch: 258/400 | Train Loss: 0.7651, Train Acc: 88.36% | Val Loss: 0.9086, Val Acc: 82.07% | Sparsity: 0.51
# Epoch: 259/400 | Train Loss: 0.7650, Train Acc: 88.38% | Val Loss: 0.9012, Val Acc: 82.47% | Sparsity: 0.52
# Epoch: 260/400 | Train Loss: 0.7672, Train Acc: 88.24% | Val Loss: 0.8778, Val Acc: 83.82% | Sparsity: 0.52
# Epoch: 261/400 | Train Loss: 0.7617, Train Acc: 88.46% | Val Loss: 0.8652, Val Acc: 83.87% | Sparsity: 0.52
# Epoch: 262/400 | Train Loss: 0.7590, Train Acc: 88.58% | Val Loss: 0.8382, Val Acc: 85.07% | Sparsity: 0.52
# Epoch: 263/400 | Train Loss: 0.7600, Train Acc: 88.58% | Val Loss: 0.8779, Val Acc: 83.57% | Sparsity: 0.52
# Epoch: 264/400 | Train Loss: 0.7557, Train Acc: 88.86% | Val Loss: 0.8801, Val Acc: 83.27% | Sparsity: 0.53
# Epoch: 265/400 | Train Loss: 0.7582, Train Acc: 88.69% | Val Loss: 0.8580, Val Acc: 84.68% | Sparsity: 0.53
# Epoch: 266/400 | Train Loss: 0.7581, Train Acc: 88.67% | Val Loss: 0.8726, Val Acc: 83.72% | Sparsity: 0.53
# Epoch: 267/400 | Train Loss: 0.7532, Train Acc: 88.98% | Val Loss: 0.8637, Val Acc: 83.93% | Sparsity: 0.53
# Epoch: 268/400 | Train Loss: 0.7520, Train Acc: 88.93% | Val Loss: 0.8666, Val Acc: 84.22% | Sparsity: 0.53
# Epoch: 269/400 | Train Loss: 0.7499, Train Acc: 89.08% | Val Loss: 0.8433, Val Acc: 84.80% | Sparsity: 0.54
# Epoch: 270/400 | Train Loss: 0.7508, Train Acc: 89.00% | Val Loss: 0.8399, Val Acc: 85.25% | Sparsity: 0.54
# Epoch: 271/400 | Train Loss: 0.7503, Train Acc: 89.21% | Val Loss: 0.8666, Val Acc: 84.25% | Sparsity: 0.54
# Epoch: 272/400 | Train Loss: 0.7486, Train Acc: 89.06% | Val Loss: 0.8582, Val Acc: 84.63% | Sparsity: 0.54
# Epoch: 273/400 | Train Loss: 0.7439, Train Acc: 89.41% | Val Loss: 0.8590, Val Acc: 84.72% | Sparsity: 0.54
# Epoch: 274/400 | Train Loss: 0.7444, Train Acc: 89.29% | Val Loss: 0.8532, Val Acc: 84.72% | Sparsity: 0.55
# Epoch: 275/400 | Train Loss: 0.7464, Train Acc: 89.19% | Val Loss: 0.8509, Val Acc: 84.75% | Sparsity: 0.55
# Epoch: 276/400 | Train Loss: 0.7429, Train Acc: 89.28% | Val Loss: 0.8574, Val Acc: 84.83% | Sparsity: 0.55
# Epoch: 277/400 | Train Loss: 0.7415, Train Acc: 89.59% | Val Loss: 0.8590, Val Acc: 84.27% | Sparsity: 0.55
# Epoch: 278/400 | Train Loss: 0.7395, Train Acc: 89.56% | Val Loss: 0.8219, Val Acc: 85.62% | Sparsity: 0.55
# Epoch: 279/400 | Train Loss: 0.7376, Train Acc: 89.56% | Val Loss: 0.8475, Val Acc: 85.08% | Sparsity: 0.56
# Epoch: 280/400 | Train Loss: 0.7349, Train Acc: 89.84% | Val Loss: 0.8738, Val Acc: 83.75% | Sparsity: 0.56
# Epoch: 281/400 | Train Loss: 0.7369, Train Acc: 89.61% | Val Loss: 0.8912, Val Acc: 82.73% | Sparsity: 0.56
# Epoch: 282/400 | Train Loss: 0.7317, Train Acc: 89.89% | Val Loss: 0.8384, Val Acc: 85.22% | Sparsity: 0.56
# Epoch: 283/400 | Train Loss: 0.7316, Train Acc: 89.75% | Val Loss: 0.8572, Val Acc: 84.40% | Sparsity: 0.56
# Epoch: 284/400 | Train Loss: 0.7302, Train Acc: 90.04% | Val Loss: 0.8496, Val Acc: 84.95% | Sparsity: 0.57
# Epoch: 285/400 | Train Loss: 0.7305, Train Acc: 90.09% | Val Loss: 0.8215, Val Acc: 86.05% | Sparsity: 0.57
# Epoch: 286/400 | Train Loss: 0.7294, Train Acc: 89.98% | Val Loss: 0.8660, Val Acc: 83.98% | Sparsity: 0.57
# Epoch: 287/400 | Train Loss: 0.7248, Train Acc: 90.20% | Val Loss: 0.8691, Val Acc: 83.83% | Sparsity: 0.57
# Epoch: 288/400 | Train Loss: 0.7271, Train Acc: 90.10% | Val Loss: 0.8440, Val Acc: 85.52% | Sparsity: 0.57
# Epoch: 289/400 | Train Loss: 0.7213, Train Acc: 90.36% | Val Loss: 0.8269, Val Acc: 85.77% | Sparsity: 0.58
# Epoch: 290/400 | Train Loss: 0.7179, Train Acc: 90.51% | Val Loss: 0.8247, Val Acc: 85.75% | Sparsity: 0.58
# Epoch: 291/400 | Train Loss: 0.7188, Train Acc: 90.43% | Val Loss: 0.8171, Val Acc: 86.35% | Sparsity: 0.58
# Epoch: 292/400 | Train Loss: 0.7157, Train Acc: 90.64% | Val Loss: 0.8313, Val Acc: 85.12% | Sparsity: 0.58
# Epoch: 293/400 | Train Loss: 0.7223, Train Acc: 90.23% | Val Loss: 0.8476, Val Acc: 84.88% | Sparsity: 0.58
# Epoch: 294/400 | Train Loss: 0.7169, Train Acc: 90.55% | Val Loss: 0.8262, Val Acc: 85.82% | Sparsity: 0.59
# Epoch: 295/400 | Train Loss: 0.7172, Train Acc: 90.69% | Val Loss: 0.8297, Val Acc: 85.67% | Sparsity: 0.59
# Epoch: 296/400 | Train Loss: 0.7142, Train Acc: 90.57% | Val Loss: 0.8142, Val Acc: 86.75% | Sparsity: 0.59
# Epoch: 297/400 | Train Loss: 0.7097, Train Acc: 90.93% | Val Loss: 0.8761, Val Acc: 83.73% | Sparsity: 0.59
# Epoch: 298/400 | Train Loss: 0.7110, Train Acc: 90.85% | Val Loss: 0.8375, Val Acc: 85.07% | Sparsity: 0.59
# Epoch: 299/400 | Train Loss: 0.7076, Train Acc: 90.99% | Val Loss: 0.8147, Val Acc: 86.05% | Sparsity: 0.60
# Epoch: 300/400 | Train Loss: 0.7052, Train Acc: 91.11% | Val Loss: 0.8158, Val Acc: 86.25% | Sparsity: 0.60
# Epoch: 301/400 | Train Loss: 0.7042, Train Acc: 91.13% | Val Loss: 0.8428, Val Acc: 84.95% | Sparsity: 0.60
# Epoch: 302/400 | Train Loss: 0.7011, Train Acc: 91.33% | Val Loss: 0.8199, Val Acc: 86.10% | Sparsity: 0.60
# Epoch: 303/400 | Train Loss: 0.7047, Train Acc: 91.02% | Val Loss: 0.8097, Val Acc: 86.62% | Sparsity: 0.60
# Epoch: 304/400 | Train Loss: 0.7024, Train Acc: 91.19% | Val Loss: 0.8222, Val Acc: 86.45% | Sparsity: 0.61
# Epoch: 305/400 | Train Loss: 0.6967, Train Acc: 91.46% | Val Loss: 0.8296, Val Acc: 85.37% | Sparsity: 0.61
# Epoch: 306/400 | Train Loss: 0.6950, Train Acc: 91.47% | Val Loss: 0.8344, Val Acc: 85.37% | Sparsity: 0.61
# Epoch: 307/400 | Train Loss: 0.6946, Train Acc: 91.53% | Val Loss: 0.8235, Val Acc: 86.00% | Sparsity: 0.61
# Epoch: 308/400 | Train Loss: 0.6940, Train Acc: 91.54% | Val Loss: 0.8148, Val Acc: 86.37% | Sparsity: 0.61
# Epoch: 309/400 | Train Loss: 0.6917, Train Acc: 91.63% | Val Loss: 0.8127, Val Acc: 86.40% | Sparsity: 0.62
# Epoch: 310/400 | Train Loss: 0.6870, Train Acc: 91.86% | Val Loss: 0.8237, Val Acc: 85.78% | Sparsity: 0.62
# Epoch: 311/400 | Train Loss: 0.6876, Train Acc: 91.90% | Val Loss: 0.7989, Val Acc: 87.23% | Sparsity: 0.62
# Epoch: 312/400 | Train Loss: 0.6901, Train Acc: 91.76% | Val Loss: 0.8120, Val Acc: 86.42% | Sparsity: 0.62
# Epoch: 313/400 | Train Loss: 0.6850, Train Acc: 92.06% | Val Loss: 0.8151, Val Acc: 86.58% | Sparsity: 0.62
# Epoch: 314/400 | Train Loss: 0.6821, Train Acc: 92.09% | Val Loss: 0.8050, Val Acc: 86.88% | Sparsity: 0.63
# Epoch: 315/400 | Train Loss: 0.6814, Train Acc: 92.14% | Val Loss: 0.7896, Val Acc: 87.58% | Sparsity: 0.63
# Epoch: 316/400 | Train Loss: 0.6793, Train Acc: 92.28% | Val Loss: 0.7896, Val Acc: 87.60% | Sparsity: 0.63
# Epoch: 317/400 | Train Loss: 0.6777, Train Acc: 92.24% | Val Loss: 0.8093, Val Acc: 86.12% | Sparsity: 0.63
# Epoch: 318/400 | Train Loss: 0.6739, Train Acc: 92.46% | Val Loss: 0.8128, Val Acc: 86.90% | Sparsity: 0.63
# Epoch: 319/400 | Train Loss: 0.6759, Train Acc: 92.45% | Val Loss: 0.8162, Val Acc: 86.43% | Sparsity: 0.64
# Epoch: 320/400 | Train Loss: 0.6747, Train Acc: 92.38% | Val Loss: 0.7886, Val Acc: 87.40% | Sparsity: 0.64
# Epoch: 321/400 | Train Loss: 0.6690, Train Acc: 92.68% | Val Loss: 0.7864, Val Acc: 87.77% | Sparsity: 0.64
# Epoch: 322/400 | Train Loss: 0.6667, Train Acc: 92.78% | Val Loss: 0.7962, Val Acc: 87.32% | Sparsity: 0.64
# Epoch: 323/400 | Train Loss: 0.6666, Train Acc: 92.84% | Val Loss: 0.8197, Val Acc: 86.20% | Sparsity: 0.64
# Epoch: 324/400 | Train Loss: 0.6688, Train Acc: 92.71% | Val Loss: 0.7625, Val Acc: 88.67% | Sparsity: 0.65
# Epoch: 325/400 | Train Loss: 0.6658, Train Acc: 92.87% | Val Loss: 0.7859, Val Acc: 87.40% | Sparsity: 0.65
# Epoch: 326/400 | Train Loss: 0.6592, Train Acc: 93.08% | Val Loss: 0.7827, Val Acc: 87.85% | Sparsity: 0.65
# Epoch: 327/400 | Train Loss: 0.6592, Train Acc: 93.11% | Val Loss: 0.7829, Val Acc: 87.37% | Sparsity: 0.65
# Epoch: 328/400 | Train Loss: 0.6576, Train Acc: 93.19% | Val Loss: 0.7777, Val Acc: 88.38% | Sparsity: 0.65
# Epoch: 329/400 | Train Loss: 0.6580, Train Acc: 93.11% | Val Loss: 0.7842, Val Acc: 87.82% | Sparsity: 0.66
# Epoch: 330/400 | Train Loss: 0.6508, Train Acc: 93.56% | Val Loss: 0.7762, Val Acc: 88.03% | Sparsity: 0.66
# Epoch: 331/400 | Train Loss: 0.6510, Train Acc: 93.60% | Val Loss: 0.7721, Val Acc: 88.38% | Sparsity: 0.66
# Epoch: 332/400 | Train Loss: 0.6434, Train Acc: 93.74% | Val Loss: 0.7856, Val Acc: 88.22% | Sparsity: 0.66
# Epoch: 333/400 | Train Loss: 0.6440, Train Acc: 93.93% | Val Loss: 0.7627, Val Acc: 88.82% | Sparsity: 0.66
# Epoch: 334/400 | Train Loss: 0.6392, Train Acc: 94.01% | Val Loss: 0.7899, Val Acc: 87.52% | Sparsity: 0.67
# Epoch: 335/400 | Train Loss: 0.6437, Train Acc: 93.76% | Val Loss: 0.7725, Val Acc: 88.57% | Sparsity: 0.67
# Epoch: 336/400 | Train Loss: 0.6393, Train Acc: 94.06% | Val Loss: 0.7693, Val Acc: 88.57% | Sparsity: 0.67
# Epoch: 337/400 | Train Loss: 0.6358, Train Acc: 94.16% | Val Loss: 0.7673, Val Acc: 88.62% | Sparsity: 0.67
# Epoch: 338/400 | Train Loss: 0.6371, Train Acc: 94.07% | Val Loss: 0.7647, Val Acc: 88.97% | Sparsity: 0.67
# Epoch: 339/400 | Train Loss: 0.6338, Train Acc: 94.28% | Val Loss: 0.7756, Val Acc: 88.15% | Sparsity: 0.68
# Epoch: 340/400 | Train Loss: 0.6294, Train Acc: 94.40% | Val Loss: 0.7678, Val Acc: 88.60% | Sparsity: 0.68
# Epoch: 341/400 | Train Loss: 0.6291, Train Acc: 94.46% | Val Loss: 0.7729, Val Acc: 88.40% | Sparsity: 0.68
# Epoch: 342/400 | Train Loss: 0.6265, Train Acc: 94.58% | Val Loss: 0.7461, Val Acc: 89.42% | Sparsity: 0.68
# Epoch: 343/400 | Train Loss: 0.6238, Train Acc: 94.76% | Val Loss: 0.7687, Val Acc: 89.15% | Sparsity: 0.68
# Epoch: 344/400 | Train Loss: 0.6211, Train Acc: 94.89% | Val Loss: 0.7534, Val Acc: 89.32% | Sparsity: 0.69
# Epoch: 345/400 | Train Loss: 0.6210, Train Acc: 94.75% | Val Loss: 0.7609, Val Acc: 88.80% | Sparsity: 0.69
# Epoch: 346/400 | Train Loss: 0.6166, Train Acc: 95.05% | Val Loss: 0.7496, Val Acc: 89.57% | Sparsity: 0.69
# Epoch: 347/400 | Train Loss: 0.6156, Train Acc: 95.17% | Val Loss: 0.7461, Val Acc: 89.80% | Sparsity: 0.69
# Epoch: 348/400 | Train Loss: 0.6136, Train Acc: 95.26% | Val Loss: 0.7572, Val Acc: 88.70% | Sparsity: 0.69
# Epoch: 349/400 | Train Loss: 0.6117, Train Acc: 95.26% | Val Loss: 0.7424, Val Acc: 89.43% | Sparsity: 0.70
# Epoch: 350/400 | Train Loss: 0.6104, Train Acc: 95.39% | Val Loss: 0.7465, Val Acc: 89.78% | Sparsity: 0.70
# Epoch: 351/400 | Train Loss: 0.6032, Train Acc: 95.70% | Val Loss: 0.7619, Val Acc: 89.15% | Sparsity: 0.70
# Epoch: 352/400 | Train Loss: 0.6048, Train Acc: 95.51% | Val Loss: 0.7398, Val Acc: 89.98% | Sparsity: 0.70
# Epoch: 353/400 | Train Loss: 0.6025, Train Acc: 95.71% | Val Loss: 0.7413, Val Acc: 89.72% | Sparsity: 0.70
# Epoch: 354/400 | Train Loss: 0.5984, Train Acc: 95.93% | Val Loss: 0.7382, Val Acc: 89.98% | Sparsity: 0.71
# Epoch: 355/400 | Train Loss: 0.5976, Train Acc: 95.88% | Val Loss: 0.7290, Val Acc: 90.22% | Sparsity: 0.71
# Epoch: 356/400 | Train Loss: 0.5978, Train Acc: 95.98% | Val Loss: 0.7260, Val Acc: 90.50% | Sparsity: 0.71
# Epoch: 357/400 | Train Loss: 0.5961, Train Acc: 95.96% | Val Loss: 0.7356, Val Acc: 89.88% | Sparsity: 0.71
# Epoch: 358/400 | Train Loss: 0.5920, Train Acc: 96.20% | Val Loss: 0.7332, Val Acc: 90.25% | Sparsity: 0.71
# Epoch: 359/400 | Train Loss: 0.5890, Train Acc: 96.35% | Val Loss: 0.7336, Val Acc: 90.10% | Sparsity: 0.72
# Epoch: 360/400 | Train Loss: 0.5886, Train Acc: 96.33% | Val Loss: 0.7333, Val Acc: 90.02% | Sparsity: 0.72
# Epoch: 361/400 | Train Loss: 0.5884, Train Acc: 96.26% | Val Loss: 0.7328, Val Acc: 90.27% | Sparsity: 0.72
# Epoch: 362/400 | Train Loss: 0.5858, Train Acc: 96.50% | Val Loss: 0.7201, Val Acc: 90.62% | Sparsity: 0.72
# Epoch: 363/400 | Train Loss: 0.5866, Train Acc: 96.42% | Val Loss: 0.7283, Val Acc: 90.37% | Sparsity: 0.72
# Epoch: 364/400 | Train Loss: 0.5816, Train Acc: 96.61% | Val Loss: 0.7146, Val Acc: 90.75% | Sparsity: 0.73
# Epoch: 365/400 | Train Loss: 0.5804, Train Acc: 96.71% | Val Loss: 0.7123, Val Acc: 91.27% | Sparsity: 0.73
# Epoch: 366/400 | Train Loss: 0.5767, Train Acc: 96.87% | Val Loss: 0.7197, Val Acc: 90.78% | Sparsity: 0.73
# Epoch: 367/400 | Train Loss: 0.5774, Train Acc: 96.85% | Val Loss: 0.7153, Val Acc: 90.78% | Sparsity: 0.73
# Epoch: 368/400 | Train Loss: 0.5758, Train Acc: 96.95% | Val Loss: 0.7092, Val Acc: 91.05% | Sparsity: 0.73
# Epoch: 369/400 | Train Loss: 0.5741, Train Acc: 96.92% | Val Loss: 0.7185, Val Acc: 90.92% | Sparsity: 0.74
# Epoch: 370/400 | Train Loss: 0.5735, Train Acc: 97.03% | Val Loss: 0.7065, Val Acc: 91.32% | Sparsity: 0.74
# Epoch: 371/400 | Train Loss: 0.5687, Train Acc: 97.32% | Val Loss: 0.7131, Val Acc: 91.03% | Sparsity: 0.74
# Epoch: 372/400 | Train Loss: 0.5696, Train Acc: 97.17% | Val Loss: 0.7205, Val Acc: 90.68% | Sparsity: 0.74
# Epoch: 373/400 | Train Loss: 0.5689, Train Acc: 97.24% | Val Loss: 0.7182, Val Acc: 91.00% | Sparsity: 0.74
# Epoch: 374/400 | Train Loss: 0.5701, Train Acc: 97.12% | Val Loss: 0.7195, Val Acc: 90.95% | Sparsity: 0.75
# Epoch: 375/400 | Train Loss: 0.5653, Train Acc: 97.41% | Val Loss: 0.7159, Val Acc: 90.95% | Sparsity: 0.75
# Epoch: 376/400 | Train Loss: 0.5663, Train Acc: 97.32% | Val Loss: 0.7127, Val Acc: 91.10% | Sparsity: 0.75
# Epoch: 377/400 | Train Loss: 0.5646, Train Acc: 97.31% | Val Loss: 0.7096, Val Acc: 91.62% | Sparsity: 0.75
# Epoch: 378/400 | Train Loss: 0.5656, Train Acc: 97.34% | Val Loss: 0.7078, Val Acc: 91.30% | Sparsity: 0.75
# Epoch: 379/400 | Train Loss: 0.5631, Train Acc: 97.55% | Val Loss: 0.7117, Val Acc: 91.23% | Sparsity: 0.76
# Epoch: 380/400 | Train Loss: 0.5627, Train Acc: 97.48% | Val Loss: 0.7057, Val Acc: 91.10% | Sparsity: 0.76
# Epoch: 381/400 | Train Loss: 0.5625, Train Acc: 97.43% | Val Loss: 0.6999, Val Acc: 91.63% | Sparsity: 0.76
# Epoch: 382/400 | Train Loss: 0.5623, Train Acc: 97.47% | Val Loss: 0.6959, Val Acc: 91.73% | Sparsity: 0.76
# Epoch: 383/400 | Train Loss: 0.5623, Train Acc: 97.46% | Val Loss: 0.6981, Val Acc: 92.05% | Sparsity: 0.76
# Epoch: 384/400 | Train Loss: 0.5621, Train Acc: 97.50% | Val Loss: 0.7114, Val Acc: 91.35% | Sparsity: 0.77
# Epoch: 385/400 | Train Loss: 0.5605, Train Acc: 97.56% | Val Loss: 0.6980, Val Acc: 91.75% | Sparsity: 0.77
# Epoch: 386/400 | Train Loss: 0.5619, Train Acc: 97.52% | Val Loss: 0.7073, Val Acc: 91.38% | Sparsity: 0.77
# Epoch: 387/400 | Train Loss: 0.5588, Train Acc: 97.69% | Val Loss: 0.6962, Val Acc: 92.08% | Sparsity: 0.77
# Epoch: 388/400 | Train Loss: 0.5568, Train Acc: 97.74% | Val Loss: 0.7060, Val Acc: 91.48% | Sparsity: 0.77
# Epoch: 389/400 | Train Loss: 0.5554, Train Acc: 97.78% | Val Loss: 0.7027, Val Acc: 91.58% | Sparsity: 0.78
# Epoch: 390/400 | Train Loss: 0.5562, Train Acc: 97.76% | Val Loss: 0.7156, Val Acc: 91.08% | Sparsity: 0.78
# Epoch: 391/400 | Train Loss: 0.5566, Train Acc: 97.76% | Val Loss: 0.7042, Val Acc: 91.50% | Sparsity: 0.78
# Epoch: 392/400 | Train Loss: 0.5580, Train Acc: 97.74% | Val Loss: 0.7092, Val Acc: 90.97% | Sparsity: 0.78
# Epoch: 393/400 | Train Loss: 0.5553, Train Acc: 97.84% | Val Loss: 0.7096, Val Acc: 91.42% | Sparsity: 0.78
# Epoch: 394/400 | Train Loss: 0.5568, Train Acc: 97.70% | Val Loss: 0.6947, Val Acc: 91.83% | Sparsity: 0.79
# Epoch: 395/400 | Train Loss: 0.5564, Train Acc: 97.83% | Val Loss: 0.6999, Val Acc: 91.72% | Sparsity: 0.79
# Epoch: 396/400 | Train Loss: 0.5565, Train Acc: 97.77% | Val Loss: 0.6978, Val Acc: 91.72% | Sparsity: 0.79
# Epoch: 397/400 | Train Loss: 0.5561, Train Acc: 97.80% | Val Loss: 0.7054, Val Acc: 91.52% | Sparsity: 0.79
# Epoch: 398/400 | Train Loss: 0.5564, Train Acc: 97.75% | Val Loss: 0.7009, Val Acc: 91.73% | Sparsity: 0.79
# Epoch: 399/400 | Train Loss: 0.5561, Train Acc: 97.77% | Val Loss: 0.7034, Val Acc: 91.63% | Sparsity: 0.80
# Epoch: 400/400 | Train Loss: 0.5579, Train Acc: 97.69% | Val Loss: 0.6998, Val Acc: 91.50% | Sparsity: 0.80
# Final Results:
# Final Training Loss: 0.5579
# Final Validation Loss: 0.6998
# Final Training Accuracy: 97.69%
# Final Validation Accuracy: 91.50%
# Final Test Loss: 0.7041
# Final Test Accuracy: 91.42%
